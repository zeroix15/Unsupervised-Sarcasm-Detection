# %% [markdown]
# # Introduction
#
# Sarcasm is a sophisticated language phenomenon, which would cause much confusion to exist sentiment classification systems.
# So sarcasm detection, a task of predicting whether a given text contains sarcasm, has received much research attention.
#
# Recently, many methods have been proposed for sarcasm detection, which could be broadly classified into two categories.
# One is the text-only method which only concentrate on the utterance itself, such as exploiting incongruity expressions to detect the sarcasm text.
# Another direction is based on extra information, which exploits external knowledge to assist the detection procedure, such as user history, and common sense knowledge.

# %% [markdown]
# We propose an unsupervised sarcasm detection method.
#
# First, we leverage the external sentiment knowledge to mask prominent tokens. Then the masked texts are fed into the pre-trained generation model, which follows the remaining logic structure to generate texts.
# There is a good chance that these reborn texts would not be sarcastic or make more sense.
#
# Second, after obtaining the similarity score between the generated sentence and the original one, features beneath the scores will be extracted to decide whether a sentence is sarcasm.
#
# Then, we construct several unsupervised baselines and conduct experiments on IAC-V2 dataset.

# %% [markdown]
# # Imports and Reading Data

# %%
# !pip install senticnet

# %%
import numpy as np
import pandas as pd

# from senticnet.senticnet import SenticNet

import nltk
from nltk.corpus import stopwords
nltk.download('punkt')
nltk.download('stopwords')
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

from transformers import AutoTokenizer, AutoModel
from transformers import BartTokenizer, BartForConditionalGeneration
import torch

from sklearn.metrics.pairwise import cosine_similarity
from sklearn.metrics import accuracy_score, precision_score, f1_score
from sklearn.metrics import confusion_matrix
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv("/content/drive/My Drive/AlifResearch/twitter_indonesia_sarcastic/data/test.csv")

# %%
df['class'] = df['label'].map({0: 'notsarc', 1: 'sarc'})

# %%
# Drop the old 'label' column and rename 'tweet' to 'text'
df = df.drop(columns=['label'])
df = df.rename(columns={'tweet': 'text'})

# %%
df = df[['class', 'text']]
df
# Out:
#        class                                               text
# 0       sarc  saraswati pintar sekali tida belajar dari peng...
# 1    notsarc  Menag bicara sola celana cingkrang gak bisa ik...
# 2    notsarc  Koruptor dihukum berat bukannya dikasih kering...
# 3    notsarc  Belum jadi pemimpin udah bikin hoax gmn kalau ...
# 4       sarc  Karena JUJUR membuatku malu dan merasa bersala...
# ..       ...                                                ...
# 533     sarc  Ciyee petani bawang nih :D :D Udahlah yaa sand...
# 534  notsarc  <username> <username> yg gue tangkep itu antar...
# 535     sarc  <username> Wuih pak capres memang keren kalau ...
# 536     sarc  <username> Welcome to Indonesia!!!! Sedih bang...
# 537     sarc  terimakasih sudah dikasih liburan gratis <hash...
#
# [538 rows x 2 columns]

# %%
import re
# Function to remove text inside <>
def remove_brackets(text):
    return re.sub(r'<.*?>', '', text).strip()

# Apply the function to the 'text' column
df['text'] = df['text'].apply(remove_brackets)
df
# Out:
#        class                                               text
# 0       sarc  saraswati pintar sekali tida belajar dari peng...
# 1    notsarc  Menag bicara sola celana cingkrang gak bisa ik...
# 2    notsarc  Koruptor dihukum berat bukannya dikasih kering...
# 3    notsarc  Belum jadi pemimpin udah bikin hoax gmn kalau ...
# 4       sarc  Karena JUJUR membuatku malu dan merasa bersala...
# ..       ...                                                ...
# 533     sarc  Ciyee petani bawang nih :D :D Udahlah yaa sand...
# 534  notsarc  yg gue tangkep itu antara apart-nya serem dia ...
# 535     sarc  Wuih pak capres memang keren kalau pakai jas ....
# 536     sarc  Welcome to Indonesia!!!! Sedih bangetttt!!! Si...
# 537     sarc           terimakasih sudah dikasih liburan gratis
#
# [538 rows x 2 columns]

# %%
def clean_text(text, encoding):
    try:
        # Decode text using the specified encoding with error handling
        return text.encode(encoding, 'ignore').decode('utf-8', 'ignore')
    except Exception as e:
        # Handle any errors during encoding/decoding
        print(f"Error processing text with {encoding}: {e}")
        return text

# List of encodings to try
encodings = ['utf-8', 'latin1', 'cp1252', 'ascii']

# Apply cleaning function with different encodings
for encoding in encodings:
    print(f"Trying encoding: {encoding}")
    df['text'] = df['text'].apply(lambda x: clean_text(x, encoding))
    print(df)

# Optionally, remove non-ASCII characters after trying different encodings
def remove_non_ascii(text):
    return re.sub(r'[^\x00-\x7F]', '', text)

# Apply non-ASCII removal
df['text'] = df['text'].apply(remove_non_ascii)

# Display the cleaned DataFrame
print(df)
# Out:
# Trying encoding: utf-8
#        class                                               text
# 0       sarc  saraswati pintar sekali tida belajar dari peng...
# 1    notsarc  Menag bicara sola celana cingkrang gak bisa ik...
# 2    notsarc  Koruptor dihukum berat bukannya dikasih kering...
# 3    notsarc  Belum jadi pemimpin udah bikin hoax gmn kalau ...
# 4       sarc  Karena JUJUR membuatku malu dan merasa bersala...
# ..       ...                                                ...
# 533     sarc  Ciyee petani bawang nih :D :D Udahlah yaa sand...
# 534  notsarc  yg gue tangkep itu antara apart-nya serem dia ...
# 535     sarc  Wuih pak capres memang keren kalau pakai jas ....
# 536     sarc  Welcome to Indonesia!!!! Sedih bangetttt!!! Si...
# 537     sarc           terimakasih sudah dikasih liburan gratis
#
# [538 rows x 2 columns]
# Trying encoding: latin1
#        class                                               text
# 0       sarc  saraswati pintar sekali tida belajar dari peng...
# 1    notsarc  Menag bicara sola celana cingkrang gak bisa ik...
# 2    notsarc  Koruptor dihukum berat bukannya dikasih kering...
# 3    notsarc  Belum jadi pemimpin udah bikin hoax gmn kalau ...
# 4       sarc  Karena JUJUR membuatku malu dan merasa bersala...
# ..       ...                                                ...
# 533     sarc  Ciyee petani bawang nih :D :D Udahlah yaa sand...
# 534  notsarc  yg gue tangkep itu antara apart-nya serem dia ...
# 535     sarc  Wuih pak capres memang keren kalau pakai jas ....
# 536     sarc  Welcome to Indonesia!!!! Sedih bangetttt!!! Si...
# 537     sarc           terimakasih sudah dikasih liburan gratis
#
# [538 rows x 2 columns]
# Trying encoding: cp1252
#        class                                               text
# 0       sarc  saraswati pintar sekali tida belajar dari peng...
# 1    notsarc  Menag bicara sola celana cingkrang gak bisa ik...
# 2    notsarc  Koruptor dihukum berat bukannya dikasih kering...
# 3    notsarc  Belum jadi pemimpin udah bikin hoax gmn kalau ...
# 4       sarc  Karena JUJUR membuatku malu dan merasa bersala...
# ..       ...                                                ...
# 533     sarc  Ciyee petani bawang nih :D :D Udahlah yaa sand...
# 534  notsarc  yg gue tangkep itu antara apart-nya serem dia ...
# 535     sarc  Wuih pak capres memang keren kalau pakai jas ....
# 536     sarc  Welcome to Indonesia!!!! Sedih bangetttt!!! Si...
# 537     sarc           terimakasih sudah dikasih liburan gratis
#
# [538 rows x 2 columns]
# Trying encoding: ascii
#        class                                               text
# tapi para wartawan ada yangvsuka klo doi berkomentar smoga ga jadi pimpinan dpr lgi zonk
# bapak kapolri idham aziz .  media aja selalu di awasi dan di jaga sepenuh hati . apa lagi aku
# perihbahasa jaman old .lempar batu sembunyi tangan jaman now .lempar batu yang disembunyikan di ambulance gerindra
# nyawa itu berharga karena ada batasnya . dan batas itulah yang membuat kita berjuang
# kamu cantik bgt tapi kamu anjing tai babi
# hasil itjima ulama keagamaannya nihil .. orang dekatnya  malah menghina ulama dengan puisinya ..kubu sebelah memang sudah rusak ..
# sontoloyo
# well jadi unfaedah :d:d
# ciyee petani bawang nih :d :d udahlah yaa sandiwaramu fazdlizonk muluu
# yg gue tangkep itu antara apart-nya serem dia digangguin setan sm dia diikutin nyi roro kidul
# wuih pak capres memang keren kalau pakai jas .... besok saya pilih deh yang pakai jas
# welcome to indonesia!!!! sedih bangetttt!!! siap siap bakal ada lagi kasus sama seperti ini karna gapernah adaaa hukuman untuk pelaku bullying??????
# terimakasih sudah dikasih liburan gratis

# %%
label_data = list(df['class'])
print(*label_data, sep = "\n")
# Out:
# sarc
# notsarc
# notsarc
# notsarc
# sarc
# notsarc
# sarc
# sarc
# sarc
# notsarc
# notsarc
# notsarc
# sarc
# notsarc
# notsarc
# sarc
# sarc
# notsarc
# notsarc
# notsarc
# notsarc
# sarc
# notsarc
# sarc
# notsarc
# notsarc
# notsarc
# notsarc
# sarc
# notsarc
# notsarc
# sarc
# notsarc
# sarc
# notsarc
# notsarc
# sarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# sarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# sarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# sarc
# notsarc
# notsarc
# sarc
# notsarc
# sarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# sarc
# notsarc
# notsarc
# sarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# sarc
# notsarc
# notsarc
# notsarc
# sarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# sarc
# notsarc
# notsarc
# sarc
# notsarc
# notsarc
# sarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# sarc
# sarc
# notsarc
# notsarc
# notsarc
# sarc
# notsarc
# notsarc
# notsarc
# sarc
# notsarc
# sarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# sarc
# notsarc
# notsarc
# sarc
# sarc
# notsarc
# sarc
# notsarc
# sarc
# notsarc
# notsarc
# sarc
# notsarc
# notsarc
# sarc
# notsarc
# notsarc
# notsarc
# sarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# sarc
# notsarc
# notsarc
# sarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# sarc
# notsarc
# notsarc
# sarc
# notsarc
# sarc
# sarc
# sarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# sarc
# notsarc
# notsarc
# sarc
# notsarc
# notsarc
# notsarc
# sarc
# sarc
# notsarc
# sarc
# sarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# sarc
# notsarc
# notsarc
# notsarc
# sarc
# notsarc
# sarc
# notsarc
# notsarc
# notsarc
# notsarc
# sarc
# notsarc
# notsarc
# sarc
# notsarc
# sarc
# notsarc
# notsarc
# sarc
# sarc
# notsarc
# sarc
# notsarc
# notsarc
# sarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# sarc
# notsarc
# notsarc
# notsarc
# notsarc
# sarc
# notsarc
# notsarc
# sarc
# notsarc
# sarc
# sarc
# notsarc
# notsarc
# notsarc
# notsarc
# sarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# sarc
# sarc
# sarc
# notsarc
# notsarc
# notsarc
# notsarc
# sarc
# sarc
# notsarc
# sarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# sarc
# notsarc
# notsarc
# notsarc
# sarc
# sarc
# notsarc
# notsarc
# notsarc
# notsarc
# sarc
# notsarc
# sarc
# notsarc
# sarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# sarc
# notsarc
# notsarc
# notsarc
# sarc
# sarc
# sarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# sarc
# sarc
# notsarc
# notsarc
# notsarc
# notsarc
# sarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# sarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# sarc
# notsarc
# sarc
# notsarc
# notsarc
# notsarc
# sarc
# notsarc
# sarc
# notsarc
# notsarc
# sarc
# notsarc
# sarc
# notsarc
# notsarc
# notsarc
# notsarc
# sarc
# notsarc
# sarc
# notsarc
# notsarc
# notsarc
# sarc
# notsarc
# notsarc
# sarc
# sarc
# notsarc
# sarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# sarc
# notsarc
# notsarc
# sarc
# notsarc
# sarc
# notsarc
# sarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# sarc
# sarc
# sarc
# notsarc
# notsarc
# sarc
# sarc
# sarc
# notsarc
# sarc
# notsarc
# notsarc
# sarc
# notsarc
# notsarc
# notsarc
# sarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# sarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# sarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# sarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# sarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# sarc
# notsarc
# notsarc
# notsarc
# sarc
# notsarc
# notsarc
# notsarc
# notsarc
# sarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# sarc
# sarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# sarc
# sarc
# notsarc
# sarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# sarc
# sarc
# notsarc
# notsarc
# notsarc
# sarc
# sarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# notsarc
# sarc
# notsarc
# notsarc
# sarc
# notsarc
# sarc
# sarc
# sarc

# %% [markdown]
# # Overview
#
# The proposed framework contains three main components:
#
# 1) Sentences mask and generation.
# This procedure first recognizes main components of sentences which will be properly masked to cause more impact on original sentences, and then fulfills the texts generation work;
#
# 2) Sentences representation.
# It is expected to calculate dense vectors of sentences;
#
# 3) Sarcastic utterances detection leverages.
# the similarity scores between original and regenerated sentences to detect whether an utterance is sarcastic.

# %% [markdown]
# # Sentences Mask and Generation
# ## 1)
# "First, we use the sentiment common knowledge retrieved from SenticNet to recognize affective words in the sentence 𝑥,
# and split those words into two sets according to its sentiment polarities:
# PW = {pw1, pw2, ..., pwh} and
# NW = {nw1, nw2, ..., nwk},
# h + k <= n."

# %%
# def tokenize_sentence(sentence):
#     tokens = word_tokenize(sentence)

#     lemmatizer = WordNetLemmatizer()

#     clean_tokens = []
#     for tok in tokens:
#         clean_tok = lemmatizer.lemmatize(tok).lower().strip()
#         clean_tokens.append(clean_tok)

#     return clean_tokens

# %%
# !pip install nlp-id
# Out:
# Requirement already satisfied: nlp-id in /usr/local/lib/python3.10/dist-packages (0.1.16.0)
# Requirement already satisfied: huggingface-hub==0.23.4 in /usr/local/lib/python3.10/dist-packages (from nlp-id) (0.23.4)
# Requirement already satisfied: nltk==3.8.1 in /usr/local/lib/python3.10/dist-packages (from nlp-id) (3.8.1)
# Requirement already satisfied: numpy==1.26.4 in /usr/local/lib/python3.10/dist-packages (from nlp-id) (1.26.4)
# Requirement already satisfied: scikit-learn==1.5.1 in /usr/local/lib/python3.10/dist-packages (from nlp-id) (1.5.1)
# Requirement already satisfied: scipy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from nlp-id) (1.13.1)
# Requirement already satisfied: wget==3.2 in /usr/local/lib/python3.10/dist-packages (from nlp-id) (3.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub==0.23.4->nlp-id) (3.15.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub==0.23.4->nlp-id) (2023.6.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub==0.23.4->nlp-id) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub==0.23.4->nlp-id) (6.0.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub==0.23.4->nlp-id) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub==0.23.4->nlp-id) (4.66.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub==0.23.4->nlp-id) (4.12.2)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk==3.8.1->nlp-id) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk==3.8.1->nlp-id) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk==3.8.1->nlp-id) (2024.5.15)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn==1.5.1->nlp-id) (3.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub==0.23.4->nlp-id) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub==0.23.4->nlp-id) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub==0.23.4->nlp-id) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub==0.23.4->nlp-id) (2024.7.4)

# %%
from nlp_id import Tokenizer, Lemmatizer

def tokenize_sentence(sentence):
    # Initialize the tokenizer and lemmatizer
    tokenizer = Tokenizer()
    lemmatizer = Lemmatizer()

    # Tokenize the sentence
    tokens = tokenizer.tokenize(sentence)

    # Lemmatize each token
    clean_tokens = [lemmatizer.lemmatize(token).lower().strip() for token in tokens]

    return clean_tokens

# %%
# def get_sentiment_polarity_from_senticnet(word):
#     sn = SenticNet()

#     word = word.lower()

#     try:
#         return sn.polarity_label(word)
#     except:
#         return "neutral"

# %%
# !pip install sentiws
# Out:
# ERROR: Could not find a version that satisfies the requirement sentiws (from versions: none)
# ERROR: No matching distribution found for sentiws

# %%
from sentiws import SentiWS
from nlp_id.tokenizer import Tokenizer
from nlp_id.lemmatizer import Lemmatizer

# Initialize SentiWS sentiment analyzer
senti_ws = SentiWS()

def get_sentiment_polarity(word):
    word = word.lower()

    try:
        sentiment_result = senti_ws.get_sentiment(word)
        # Determine the sentiment based on the compound score
        if sentiment_result > 0:
            return "positive"
        elif sentiment_result < 0:
            return "negative"
        else:
            return "neutral"
    except:
        return "neutral"
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-18-8d5114a7efaf> in <cell line: 1>()
# ----> 1 from sentiws import SentiWS
#       2 from nlp_id.tokenizer import Tokenizer
#       3 from nlp_id.lemmatizer import Lemmatizer
#       4
#       5 # Initialize SentiWS sentiment analyzer
#
# ModuleNotFoundError: No module named 'sentiws'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# def analyze_sentiment(sentences):
#     positive_words = []
#     negative_words = []

#     for sentence in sentences:
#         words = tokenize_sentence(sentence)

#         PW = set()
#         NW = set()

#         for word in words:
#             sentiment_polarity = get_sentiment_polarity_from_senticnet(word)
#             if sentiment_polarity == "positive":
#                 PW.add(word.lower())
#             elif sentiment_polarity == "negative":
#                 NW.add(word.lower())

#         positive_words.append(PW)
#         negative_words.append(NW)

#     return positive_words, negative_words

# %%
def analyze_sentiment(sentences):
    positive_words = []
    negative_words = []

    for sentence in sentences:
        words = tokenize_sentence(sentence)

        PW = set()
        NW = set()

        for word in words:
            sentiment_polarity = get_sentiment_polarity(word)
            if sentiment_polarity == "positive":
                PW.add(word.lower())
            elif sentiment_polarity == "negative":
                NW.add(word.lower())

        positive_words.append(PW)
        negative_words.append(NW)

    return positive_words, negative_words

# %%
# import nltk
# nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
# positive_words, negative_words = analyze_sentiment(text_data)

# for i, sentence in enumerate(text_data):
#     print(f"Sentence: {sentence}")
#     print(f"Positive Words: {positive_words[i]}")
#     print(f"Negative Words: {negative_words[i]}")
#     print("- - - - - - - - - -")
# Out:
# Streaming output truncated to the last 5000 lines.
# Negative Words: {'catholic'}
# - - - - - - - - - -
# Sentence: yet according to pp themselves, they provide far more abortions and ec services than any of their other services. :pppfa services (2002-2003)surgical abortions: 227,385 emergency contraception: 633,756 prenatal care: 15,860 adoption referrals: 1,963 (source: www.plannedparenthood.org)
# Positive Words: {'surgical', 'adoption', 'contraception', 'provide', 'care', 'referral'}
# Negative Words: {'emergency', 'prenatal', 'abortion'}
# - - - - - - - - - -
# Sentence: well, if burglars want to steal guns then it makes sense that they would be likely to target the homes of gun owners. and the source is from the recently published book evaluating gun policy which you can read and review. the source is listed at the bottom.
# Positive Words: {'published', 'review'}
# Negative Words: {'steal', 'bottom', 'target', 'listed', 'burglar', 'policy'}
# - - - - - - - - - -
# Sentence: but the fact remains that guns are, by design, weapons.
# Positive Words: {'design'}
# Negative Words: {'weapon'}
# - - - - - - - - - -
# Sentence: no it doesn't!it cost way more money in appeals than it does to excute someone. we the taxpayers pay for legal represenatation for them and us, plus the cost of keeping them in jail. the appelas process alone costs the tax payers millions.it is far more expensive to kill them than to leave them in jail with no chance of parole.
# Positive Words: {'chance', 'legal', 'appeal', 'expensive', 'plus', 'money', 'doe'}
# Negative Words: {'alone', 'cost', 'jail', 'kill', 'parole'}
# - - - - - - - - - -
# Sentence: again, true. but that doesn't take into account that there are two populations under consideration.
# Positive Words: {'true', 'doe'}
# Negative Words: {'population'}
# - - - - - - - - - -
# Sentence: evolution doesn't explain the event. the event is an example of evolution - a change in the frequency of alleles in a populatioin over time. the explanation may or may not be evolution by natural selection. you merely asserted that based on your imagined case.
# Positive Words: {'explanation', 'evolution', 'selection', 'example', 'explain', 'natural', 'asserted', 'doe', 'frequency', 'change'}
# Negative Words: {'allele'}
# - - - - - - - - - -
# Sentence: but then, you are obviously scientifically illiterate. why don't you think that the panal of scientists who were hired to write the standards know better than you? it is, after all, their field.
# Positive Words: {'standard', 'write', 'better'}
# Negative Words: {'illiterate'}
# - - - - - - - - - -
# Sentence: i'm sorry, but that's not what my version said."no one who has been emasculated by crushing or cutting may enter the assembly of the lord ." emasculated = castrated emasculation was not an accident. (what this verse has to do with the death penalty is beyond me.)
# Positive Words: {'lord', 'enter', 'verse'}
# Negative Words: {'assembly', 'crushing', 'accident', 'sorry', 'emasculation', 'penalty', 'death'}
# - - - - - - - - - -
# Sentence: well be cynical if you want, if someone in your family had done as you ascribed you wouldn't be here to be so glib. nor would the human race or any other species where penile-vaginal sex takes place. i guess all those years of biological reproduction show it. you will also notice i didn't make it an absolute statement. i said "minimal or negligable physical damage".i understand that female biology undergoes truama too during sex, the fact is the trauma of vaginal sex i.....1. more forgiving and 2. obviously possible of greater/important final result. and um, like with lesbian activities, the size of the "peg" also matters so how do you know lesbian activities are a lot less harmful.
# Positive Words: {'specie', 'reproduction', 'lesbian', 'family', 'physical', 'understand', 'minimal', 'peg', 'biological', 'possible', 'size', 'result', 'activity', 'glib', 'sex'}
# Negative Words: {'harmful', 'trauma', 'cynical', 'biology', 'damage'}
# - - - - - - - - - -
# Sentence: i think you are entirely correct. from the page vor linked:
# Positive Words: set()
# Negative Words: {'correct'}
# - - - - - - - - - -
# Sentence: why don't we do the same for straight marriages then?why doesn't a straight couple that gets married in colorado, and then moves to virginia, have to get their divorce "remotely" from virginia.or maybe you should start thinking about what authority colorado has to grant a divorce to virginian residents.
# Positive Words: {'authority', 'married', 'grant', 'marriage', 'doe'}
# Negative Words: {'divorce', 'resident'}
# - - - - - - - - - -
# Sentence: actually, it hasn't. phylogenetic analysis has no relevance to occam's razor. further, dna for all organisms is the same until you examine specific sequences. it isn't that the dna is different, what matters is the the sequence of the bases is different.
# Positive Words: {'analysis', 'relevance'}
# Negative Words: {'phylogenetic', 'organism', 'razor', 'specific'}
# - - - - - - - - - -
# Sentence: and he has still yet to provide one. if more gun-control means more lives saved then more gun-control means more self preservation.
# Positive Words: {'self', 'provide'}
# Negative Words: set()
# - - - - - - - - - -
# Sentence: the purpose of the bill of rights.
# preamble to the bill of rights
# Positive Words: {'purpose', 'preamble'}
# Negative Words: set()
# - - - - - - - - - -
# Sentence: i dunno... we already have enough fundies thinking that the big bang is part of evolution...
# Positive Words: {'bang', 'evolution', 'big'}
# Negative Words: set()
# - - - - - - - - - -
# Sentence: i see. then you are attempting to define evolution out of existance. by your definition (not that of evolutionary biologists) evolution requires an increase in information. an unsupported creationist argument. define information in a meaningful way. please apply your definition to genetics and show why all genetic changes are a decrease in information.
# Positive Words: {'change', 'meaningful', 'evolutionary', 'evolution', 'genetic', 'existance', 'information', 'increase', 'definition'}
# Negative Words: {'argument', 'biologist', 'creationist', 'decrease', 'unsupported'}
# - - - - - - - - - -
# Sentence: sounds like a fact which has been blown out of all proportion - possibly by the pro-gun side attempting to ridicule it. it is a fact, however, that the presence of a gun can increase aggression levels in individuals.see other times i have brought this up, here (to the end of the thread) and here (again, that post till the end of the thread).
# Positive Words: {'brought', 'presence', 'aggression', 'proportion', 'increase'}
# Negative Words: {'thread', 'ridicule'}
# - - - - - - - - - -
# Sentence: and if we can actually doing anything about it. from what i hear on the fringes, the debate should not be about how to change or stop it, but how to change to deal with it and what we should expect as society adapts to a change in climate.
# Positive Words: {'deal', 'change'}
# Negative Words: {'stop'}
# - - - - - - - - - -
# Sentence: what else would you expect from the people who created a god in their own image?
#
#  your thinking here is right, religion has a long history of being egocentric.
# Positive Words: {'image', 'religion'}
# Negative Words: {'egocentric'}
# - - - - - - - - - -
# Sentence: well, first, i did say "the fact that you and i cannot understand this doesn't make it impossible." secondly, how is no god possible? third, a person being 100% something and 100% something else isn't entirely impossible. there are people all over the world who change from 100% idiotic to 100% non-idiotic all the time. lastly, there are many things we don't understand... so what's your point in restating what i said?
# Positive Words: {'secondly', 'possible', 'doe', 'understand', 'change'}
# Negative Words: {'impossible', 'idiotic'}
# - - - - - - - - - -
# Sentence: bet the crime rate skyrockets,but i wonder what happens if you (officers)just
#  put a bullet in them, you know for resisting arrest?
#
#  who does that pinhead mayor remind you of?emoticon_rolleyes
# Positive Words: {'officer', 'arrest', 'wonder', 'remind', 'doe'}
# Negative Words: {'skyrocket', 'rate', 'pinhead', 'crime'}
# - - - - - - - - - -
# Sentence: that is what supersport is hoping to do... however, assuming that you are correct in your interpretation, he has no chance of doing it so well.
# Positive Words: {'supersport', 'chance'}
# Negative Words: {'correct', 'interpretation'}
# - - - - - - - - - -
# Sentence: yes, to follow his commandments to love god and to love one another.
# Positive Words: {'follow', 'love'}
# Negative Words: set()
# - - - - - - - - - -
# Sentence: you have a habit of constantly posting statements by anti-gun officials. and when these statements and theories are called into question and challenged, you have nothing to post in defense.
# Positive Words: {'defense'}
# Negative Words: {'habit', 'constantly', 'nothing'}
# - - - - - - - - - -
# Sentence: agreed that they are still the same species, much like the "13 species" of darwin's finches, and i have no problem with evolution in that respect. i can even see the plausibility of different subspecies evolving eventually into different species if they are geographically separated for a sufficiently long time. but i still don't see where evolution, in that sense of the term, can account for dozens of species of monkeys occupying the same patch of rainforest, or dozens of species of gazelles occupying the same patch of grassland.
# Positive Words: {'agreed', 'specie', 'respect', 'sufficiently', 'evolution', 'plausibility', 'eventually', 'geographically', 'patch'}
# Negative Words: {'problem', 'finch', 'grassland', 'gazelle', 'monkey', 'separated'}
# - - - - - - - - - -
# Sentence: no, it requires pretty much the same amount of faith, as if faith could be quantified.
#
#  .
# Positive Words: {'amount', 'faith'}
# Negative Words: set()
# - - - - - - - - - -
# Sentence: again that is a poor analogy. congress does not have any powers not included in the constitution. quite the opposite, it specifically says that any powers not included in the constitution is defaulted to the states and congress is additionally prohibited from taking any more authority not named in the constitution.since there is no specific naming article saying congress does not have the power to ban manufacturing weapons, in fact it does not. according to the 10th amendment:the powers not delegated to the united states by the constitution, nor prohibited by it to the states, are reserved to the states respectively, or to the people.thus you have another poor analogy. congress does not have the right to ban manufacture of guns.
# Positive Words: {'authority', 'additionally', 'naming', 'constitution', 'specifically', 'power', 'doe', 'saying'}
# Negative Words: {'ban', 'specific', 'poor', 'weapon', 'amendment', 'analogy', 'opposite', 'manufacture'}
# - - - - - - - - - -
# Sentence: see above. nothing has been demonstrated that convinces me that god has been ruled out of all these issues. he probably isn't active in all situations, but there's nothing that says he (or even satan) are totally inconsequential either.
# Positive Words: {'active'}
# Negative Words: {'satan', 'nothing', 'inconsequential'}
# - - - - - - - - - -
# Sentence: i think shortej is not a creationist. he/she never said so, and started off by saying he/she accepts evolution and maintains her catholic beliefs. (i have a hunch its "she")
# Positive Words: {'belief', 'saying', 'evolution'}
# Negative Words: {'creationist', 'catholic', 'hunch'}
# - - - - - - - - - -
# Sentence: because apes, monkeys and chimps are on different paths. you wouldn't expect a shark to evolve into a barracuda-like animal. things evolve to fill niches, we currently fill a niche, there is nothing pushing apes, chimps or other primates to fill a niche that is occupied.
# Positive Words: {'pushing', 'niche', 'fill'}
# Negative Words: {'nothing', 'chimp', 'ape', 'monkey', 'shark'}
# - - - - - - - - - -
# Sentence: so what if he dislikes science? if he believes something else, he has the right to believe that way. my problem here is that he shows more closed-mindedness to the viewpoints of others.
# Positive Words: {'belief', 'science', 'believe'}
# Negative Words: {'dislike', 'problem'}
# - - - - - - - - - -
# Sentence: this isn't discrimination because the adult once did have have the right to live in a womb until it could live otherwise. once out of the womb and living on his/her own this right has been exhausted because there is no need to be living in the womb. much like you can drive but this 'right' is exhausted when you are drunk or too old to see anything.
# Positive Words: {'adult', 'womb', 'drive'}
# Negative Words: {'discrimination', 'old', 'drunk', 'exhausted'}
# - - - - - - - - - -
# Sentence: it depends on your intention and your methods. of course, things that don't have some sort of physical manifestation that can be measured can't be studied by science. science is naturalistic. scientific data can only include that which can be observed and quantified by natural means. i read it in a book of mythology isn't scientific.
# Positive Words: {'method', 'naturalistic', 'include', 'intention', 'science', 'physical', 'measured', 'natural'}
# Negative Words: set()
# - - - - - - - - - -
# Sentence: when someone lacks the ability to understand and the ganas to try, then it doesn't make sense. however, if you understood any of it, it would be different. after all, you repeat over and over again how you don't understand.
# Positive Words: {'ability', 'repeat', 'doe', 'understand'}
# Negative Words: {'lack'}
# - - - - - - - - - -
# Sentence: cars are a privilege, your gun isn't. show me evidence that would support the registration of your first amendment rights being constitutional.
# Positive Words: {'privilege', 'registration', 'constitutional', 'support'}
# Negative Words: {'amendment'}
# - - - - - - - - - -
# Sentence: and you just did what you chastise me for in your next sentence
# Positive Words: set()
# Negative Words: {'chastise'}
# - - - - - - - - - -
# Sentence: the original molecule had some lipolytic function, but removing some amino acids from it, in the right place, made it fit better into the substrate, and thereby greatly increased its functionality. barbarian observes:we thought it would take roughly a million years for bacteria to evolve enzymes capable of digesting nylon (because the compound is so different than any they were able to digest) but it took less than a century. .
# Positive Words: {'original', 'bacteria', 'functionality', 'enzyme', 'substrate', 'greatly', 'capable', 'nylon', 'compound', 'molecule', 'better', 'thereby', 'digest'}
# Negative Words: {'function', 'roughly', 'acid', 'removing', 'barbarian'}
# - - - - - - - - - -
# Sentence: hundreds of thousands of atheist scientists do too, since common ancestry with apes harmonizes perfectly with the absence of a creator. they're seldom asked to answer about that confusion, however.
# Positive Words: {'ancestry', 'perfectly'}
# Negative Words: {'atheist', 'absence', 'confusion', 'ape'}
# - - - - - - - - - -
# Sentence: i think that the bad guys will be happy if any gun control law goes into effect, because then there will be less chance of the victum having a weapon for their defense, and the crime rate will rise!!!!!!!!!!!!!!!!!!!!!!
# Positive Words: {'control', 'chance', 'rise', 'happy', 'effect', 'defense'}
# Negative Words: {'bad', 'crime', 'rate', 'weapon'}
# - - - - - - - - - -
# Sentence: because....expansion occurs after heat is added. how can a expansion occur with a prior cause? you're saying the reaction and cause happen at the same time. show me an example that does that.
# Positive Words: {'doe', 'saying', 'heat', 'example'}
# Negative Words: {'reaction', 'occur'}
# - - - - - - - - - -
# Sentence: and we do. in some phyla, most of the partially-formed examples still exist. you can find them in mollusks, for example.
#
#  http://www.pnas.org/content/vol104/suppl_1/images/large/zpq0120756920001.jpeg
# Positive Words: {'example'}
# Negative Words: {'mollusk', 'phylum'}
# - - - - - - - - - -
# Sentence: actually, i can not accept that claim. before then, the absolutely youngest ever surviving fetus was deliver at 19 weeks, 6 days. 12 weeks would be a worldwide sensation. i would recommend that you double-check your source. viability is still defined as the age at which 50% survive, which still is at around 24 weeks gestation/26 weeks pregnancy.
# Positive Words: {'recommend', 'youngest', 'deliver', 'survive', 'accept', 'viability', 'fetus', 'age', 'worldwide'}
# Negative Words: {'pregnancy', 'defined'}
# - - - - - - - - - -
# Sentence: if that were true, why are there millions of miscarriages each year? i don't believe a word of it.
# Positive Words: {'true', 'believe'}
# Negative Words: {'miscarriage'}
# - - - - - - - - - -
# Sentence: it's not a literal account unless you interpret it that way.
# Positive Words: {'interpret'}
# Negative Words: set()
# - - - - - - - - - -
# Sentence: if! but here's the thing, mexico is making absolutely no attempt to truly stomp out the drug cartels, they're catering to them! various political figures and police officers are on the take, they're getting massive amounts of bribe money from the cartels, stopping them would prove detrimental.
# Positive Words: {'amount', 'officer', 'attempt', 'prove', 'bribe', 'money', 'cartel'}
# Negative Words: {'massive', 'stomp', 'detrimental', 'drug', 'political', 'various'}
# - - - - - - - - - -
# Sentence: well, if they've re-established control in new orleans(and it seems they have), then taking a gun away from someone carrying it on the street would be what the police normally do in any city. if they were taking it away from peoples' homes, and not letting them keep them, that would be over and above what they normally do. (i'm very pro-2nd amendment, so don't get me wrong here. i'm just pointing out that taking guns away from people happens in every city every day)i also think that it's kind of disingenuous to complain about the military coming in--just a week ago everyone was criticizing the govt. for not sending in the military. now people are criticizing them for doing it???
# Positive Words: {'control', 'disingenuous', 'new'}
# Negative Words: {'complain', 'amendment', 'wrong'}
# - - - - - - - - - -
# Sentence: because if you let gays marry because it is an alternitve way the equal protection says that if you let one happen you have to let the others have that right to. but that is not really my point my real point is that if we let this happend it will ruin marriage in this country, marriage is a bond between a man and a women and if we let gays marry this country will be ruining that tradition thus making this country more secular then it all ready is. and we have to stop that.
# Positive Words: {'protection', 'secular', 'marry', 'ready', 'real', 'gay', 'marriage', 'tradition'}
# Negative Words: {'stop', 'ruin', 'ruining'}
# - - - - - - - - - -
# Sentence: just isn't the case in countries with nationalised health care, yet those countries also have a large number of pharmaceutical companies that are based there.
# Positive Words: {'large', 'care', 'health'}
# Negative Words: {'pharmaceutical'}
# - - - - - - - - - -
# Sentence: are you saying that an argument that is inconsistent with science should not be called unscientific, or are you saying that it should not be rejected because it is unscientific?
# Positive Words: {'saying', 'science'}
# Negative Words: {'argument', 'inconsistent', 'unscientific', 'rejected'}
# - - - - - - - - - -
# Sentence: you have to remember that those christians believe that the laws of god superceed those of man. that thier allegiance is to god and his laws above those of the constitution. they also believe that all should be subject to gods by force if nesesary.
# Positive Words: {'force', 'believe', 'constitution', 'remember'}
# Negative Words: {'allegiance'}
# - - - - - - - - - -
# Sentence: it is all repeated time after time, and time again then again. but you are correct. here is one of the links to those studies. emoticonxsmilie http://www.4forums.com/political/gun...tml#post354115but what do we do about this? http://works.bepress.com/cgi/viewcon...dennis_culhane which is a study of criminals shooting criminals but it is hoped that people will think it is about law abiding concealed carry. this is not representative of law-abiding concealed carry or legal gun ownership in any way. and we have this.guns and death - firearms research - harvard injury control research center - harvard school of public healthso lets look at the actual crime figures to see if any of this holds water.  according to this 1999 article  there were 250 million guns in circulation in 1999.   total nics background checks november 30, 1998 - june 30, 2009
# Positive Words: {'control', 'research', 'link', 'carry', 'legal', 'ownership', 'actual', 'background', 'water', 'check'}
# Negative Words: {'representative', 'correct', 'injury', 'shooting', 'criminal', 'crime', 'death', 'firearm', 'repeated'}
# - - - - - - - - - -
# Sentence: okay, you are right... we need a definition for a 'hole,' as it is a bit of a subjective concept. allow me to define 'hole' like this: the void created by the intentional destruction of something already in existence. using 'hole' with this definition makes alcorn's statement (minus the word 'terrible') a true fact in the physical realm. and it precludes any of your other ideas from creating 'holes,' since they all deal with potentiality, not reality.
# Positive Words: {'true', 'potentiality', 'subjective', 'physical', 'okay', 'existence', 'reality', 'deal', 'intentional', 'definition'}
# Negative Words: {'destruction'}
# - - - - - - - - - -
# Sentence: religion: commitment or devotion to religious faith or observance
#
#  religious: relating to or manifesting faithful devotion to an acknowledged ultimate reality or diety
#
#  therefore we can conclude that atheism and agnosticism are religions.
# Positive Words: {'diety', 'religion', 'observance', 'devotion', 'commitment', 'conclude', 'agnosticism', 'reality', 'faith', 'ultimate'}
# Negative Words: {'faithful', 'atheism'}
# - - - - - - - - - -
# Sentence: i'd say there were a lot of stones going both ways.
#
#  do you know the rev. well enough to be able to make that claim, that he's a bigot? or is it he represents the system?
# Positive Words: {'stone', 'rev'}
# Negative Words: {'bigot'}
# - - - - - - - - - -
# Sentence: i know exactly what you were saying. and it seems i was right, you have nothing to back up your claim that people were betting that it would fail. it's just something you're "sure" of, i.e. something you made up. like i figured.
# Positive Words: {'saying', 'sure'}
# Negative Words: {'nothing', 'fail'}
# - - - - - - - - - -
# Sentence: i think you mean to say is hunters not liberal democrat hunters. actualy i know of very few hunters that only have rifles or shot guns they usualy also have pistols to since you can hunt with them also.
# Positive Words: {'hunt', 'liberal', 'hunter', 'rifle'}
# Negative Words: {'pistol'}
# - - - - - - - - - -
# Sentence: and those pillars will be replaced by something stronger like equality and justice.
# Positive Words: {'justice', 'equality', 'stronger'}
# Negative Words: {'pillar', 'replaced'}
# - - - - - - - - - -
# Sentence: she should not have the baby in the first place, and thats what im saying. the only irresponsible move a 12 year old would be making is not having an abortion, as she is not physically and emotionally capable of raising or bearing a child.
# Positive Words: {'baby', 'emotionally', 'capable', 'child', 'raising', 'saying', 'irresponsible'}
# Negative Words: {'old', 'abortion'}
# - - - - - - - - - -
# Sentence: stop trying to muddy the waters. i asked you to back up your claim that gun control is racist. that is not asking others to do my work for me. that is asking you to back up a claim that you made.
# Positive Words: {'control', 'work', 'water'}
# Negative Words: {'muddy', 'stop', 'racist'}
# - - - - - - - - - -
# Sentence: first of all, the government cannot increase the volume and social acceptance of a drug - only the market and society can do that. government cannot even decrease the volume or social acceptance of drugs - despite the government's efforts, drug use has remained relatively constant. what hasn't remained constant is violent crime, which has gone up during the drug war as it did during alcohol prohibition.
# Positive Words: {'acceptance', 'constant', 'social', 'effort', 'alcohol', 'volume', 'increase'}
# Negative Words: {'decrease', 'drug', 'violent', 'crime', 'prohibition'}
# - - - - - - - - - -
# Sentence: well it came from somewhere and presumably changed as it went along.
# Positive Words: set()
# Negative Words: set()
# - - - - - - - - - -
# Sentence: straw man. i am not attacking the achievements of science. i am attacking the notion that you have that scientists are exempt from the catalogue of influences that affect everyone else; with only the slightest admission of a tiny possibility of cultural influence - which was quickly dismissed anyway with the false analogy of comparing evolution to aeronautical engineering.
# Positive Words: {'achievement', 'catalogue', 'evolution', 'science', 'tiny', 'cultural', 'admission'}
# Negative Words: {'attacking', 'quickly', 'straw', 'exempt', 'influence', 'false', 'dismissed', 'analogy', 'aeronautical', 'slightest'}
# - - - - - - - - - -
# Sentence: but growth is fairly irrelevant. my sperm can grow into a human too, and have mental existence, yet ejaculating isn't murder. it just becomes a huge debate on where to draw the line, therefore it is best to focus on the state that it is right now. not what it was or could possibly be.that seems reasonable to me.[/quote]
# Positive Words: {'best', 'focus', 'existence', 'grow', 'sperm', 'mental', 'growth', 'huge'}
# Negative Words: {'murder', 'irrelevant', 'reasonable'}
# - - - - - - - - - -
# Sentence: over 10,000 signatures of christian clergy have been collected, and have endorsed this letter.
# Positive Words: {'signature'}
# Negative Words: set()
# - - - - - - - - - -
# Sentence: this stat sounds more than a bit inflated. seeing as it comes from a website called "women's issues" it is probably not all that credible.
# Positive Words: {'credible', 'inflated', 'stat'}
# Negative Words: set()
# - - - - - - - - - -
# Sentence: there is a pretty huge difference.civil unions aren't nationally recognized, for one thing, since not every state has them. if you travel to a state that does not offer civil unions, then your union is not valid there.i think there's a problem with dissolving those unions as well.the big difference, though, are the rights that these unions provide. there are over 1,000 legal protections and rights that marriage provides that civil unions don't. i'll try and find a list of differences.
# Positive Words: {'protection', 'union', 'travel', 'legal', 'provides', 'provide', 'marriage', 'doe', 'big', 'valid', 'offer', 'huge'}
# Negative Words: {'problem', 'civil'}
# - - - - - - - - - -
# Sentence: that's a nice silver-lining take on the situation, but you and i both know that there are times someone who has a greater and more pressing need for the job (even to feed his family) gets put aside for someone who doesn't need it as badly. the issue here isn't "fairness." this issue is doing unto others as you'd have them do unto you. if you're going to hold the golden rule up as a rule, you have to be consistent.
# Positive Words: {'fairness', 'job', 'family', 'consistent', 'greater', 'doe', 'nice', 'rule', 'unto', 'golden'}
# Negative Words: {'badly', 'aside'}
# - - - - - - - - - -
# Sentence: no, but the roman persecution of christians, covering christians in pitch, roman garden parties, witnesses for christ being killed for their faith etc. is as irrelevant as it gets. just be careful, that's all i'm saying. there is a place for that topic.
# Positive Words: {'saying', 'faith', 'careful', 'party'}
# Negative Words: {'persecution', 'killed', 'irrelevant', 'christ'}
# - - - - - - - - - -
# Sentence: i think you just made the point that they're people after a certain degree of development takes place.
# Positive Words: {'development'}
# Negative Words: {'degree'}
# - - - - - - - - - -
# Sentence: so which is it: the action is moral, the action is immoral, or there is no answer? you seem confused.
# Positive Words: {'moral'}
# Negative Words: {'confused', 'immoral'}
# - - - - - - - - - -
# Sentence: as mach pointed out, you (montalban) are arguing with yourself here.you stated that "bacteria needing nylon to survive" is put forth as evidence for evolution. then you said that an alternate view was that there are some bacteria that need nylon to survive.anyway, an actual alternate view is that the experiments performed to determine whether the bacteria could survive on nylon alone could not have been exhaustive. there may still be a natural substance on which the bacteria survives. it may even be similar to nylon, but it has yet to be discovered. this is a big maybe, though.
# Positive Words: {'bacteria', 'experiment', 'evolution', 'alternate', 'natural', 'survive', 'nylon', 'actual', 'exhaustive', 'pointed', 'big', 'view', 'determine'}
# Negative Words: {'substance', 'alone', 'mach', 'arguing'}
# - - - - - - - - - -
# Sentence: really if this is another one of your fresh organic sample = age of decades of time capsule because they were both on top of the ground, you're officially delusional.
# Positive Words: {'fresh', 'top', 'sample', 'age', 'organic'}
# Negative Words: {'decade', 'delusional', 'capsule'}
# - - - - - - - - - -
# Sentence: pretty good considering darwin wasn't aware of genetics. too bad wells is stuck in 1859. the modern synthesis provides perfectly legitimate mechanisms.
# Positive Words: {'perfectly', 'mechanism', 'modern', 'aware', 'good', 'provides', 'synthesis', 'legitimate'}
# Negative Words: {'bad', 'stuck'}
# - - - - - - - - - -
# Sentence: you think "the unborn child is worthy of protection"..."but not more so than the mother, probably less"...yet you believe "in most circumstances the child should be carried to term?"
# Positive Words: {'protection', 'believe', 'worthy', 'unborn', 'child'}
# Negative Words: set()
# - - - - - - - - - -
# Sentence: well, i'm sincere in how i interpreted what he wrote, and i honestly believe that is what he meant.
# Positive Words: {'sincere', 'believe', 'honestly'}
# Negative Words: set()
# - - - - - - - - - -
# Sentence: if i am to believe in something even if it's scientific, i should be able to challenge the belief's of the person who's pushing it. if they don't believe in what they're selling, why should i.
# Positive Words: {'pushing', 'belief', 'believe', 'challenge'}
# Negative Words: set()
# - - - - - - - - - -
# Sentence: yet without it the vessel is just worms, mud, then dust, like rock & tree houses, not made to endure, yet, the life force, energy, back to the cosmos/source, converted, capable of being rewinded, paused, and fastfowarded, like a movie screen amongst the stars, revealing our lives.
# Positive Words: {'force', 'tree', 'endure', 'star', 'capable', 'rock', 'energy'}
# Negative Words: {'dust', 'mud', 'worm'}
# - - - - - - - - - -
# Sentence: well, man has been called the third chimpanzee. cladistics is some decades old now, and it has suplanted the old linean system. while discoveries are still assigned genus and species names, evaluation of morphological charisteristics by computer yield much more realistic evolutionary trees.
# Positive Words: {'specie', 'evaluation', 'evolutionary', 'tree', 'discovery', 'yield', 'realistic'}
# Negative Words: {'old', 'chimpanzee', 'decade'}
# - - - - - - - - - -
# Sentence: but they didn't have sexual relations. this was from a sperm bank- there was nothing that made the two people create one being. nonetheless, this is a side issue for future debates. my main point is homosexuality is a disorder that the government shouldn't be condoning. the government obviously doesn't condone pedophilia, poligamy, and incest. why is the government condoning homosexuality?
# Positive Words: {'main', 'create', 'doe', 'sperm', 'incest', 'relation'}
# Negative Words: {'sexual', 'nothing', 'homosexuality', 'disorder', 'condone', 'pedophilia'}
# - - - - - - - - - -
# Sentence: evolution's evidence is that life is similar, you won't be able to find an exception i am sure.
# Positive Words: {'sure', 'evolution'}
# Negative Words: {'exception'}
# - - - - - - - - - -
# Sentence: the us is still the closest thing to a pure capitalist country in the world. but you are correct, our system is not a pure capitalist one. we have reminants of all types of systems including socialism. in the modern world i don't think a society as large as the us is could be run under just one pure system.
# Positive Words: {'modern', 'pure', 'socialism', 'large', 'closest'}
# Negative Words: {'capitalist', 'correct'}
# - - - - - - - - - -
# Sentence: i thought i had worded my post quite clearly. i even pointed out that it appeared that dembski thought that there were only three laws of thermodynamics and claimed to have discovered a 4th (which he of course named the 4th law of thermodynamics). he seems unaware of the zeroth law.
# Positive Words: {'pointed'}
# Negative Words: {'unaware', 'zeroth'}
# - - - - - - - - - -
# Sentence: "healthy families" seems like a strange name for this group that the link is to.
# Positive Words: {'link', 'strange', 'family', 'healthy'}
# Negative Words: set()
# - - - - - - - - - -
# Sentence: the burden of a pregnancy is the woman's. it should be left up to her and her doctor to decide what is best for her.
# Positive Words: {'decide', 'best'}
# Negative Words: {'pregnancy', 'burden'}
# - - - - - - - - - -
# Sentence: because you've presented no credible evidence to support the claims that private transactions are an established and major source of firearms for criminals.
#
#  if you can't prove it's broken, you don't have grounds to call for fixing it.
# Positive Words: {'credible', 'support', 'prove'}
# Negative Words: {'firearm', 'private', 'broken', 'criminal'}
# - - - - - - - - - -
# Sentence: that's right. it merely has the capacity to make errors which sometimes slightly improves function in a particular environment. and those tend to accumulate over time.
# Positive Words: {'particular', 'environment', 'capacity'}
# Negative Words: {'error', 'function', 'accumulate'}
# - - - - - - - - - -
# Sentence: snipthis opinion piece was put forth by the violence policy center, the same people who opposed all forms of firearms safety training and gun locks, because they might encourage people to feel that they're more capable of safely operation a firearm. the violence policy center also pushed the idea of an "assault weapons ban" because it was easier than a handgun ban, claiming that the uneducated people are unable to tell what is a machine gun and what isn't a machine gun, making passage of such a law all the easier.
# Positive Words: {'encourage', 'safely', 'training', 'capable', 'passage', 'lock', 'safety', 'easier'}
# Negative Words: {'violence', 'ban', 'opposed', 'assault', 'weapon', 'uneducated', 'unable', 'firearm', 'policy', 'handgun'}
# - - - - - - - - - -
# Sentence: what's ridiculous is your mis-reading of the argument. i'm both discussing individual pharmacists, and their refusal of service to individuals based on the drug the individual wants, which is already assumed to be dispensed at that pharmacy or chain.
# Positive Words: {'individual', 'chain', 'pharmacist'}
# Negative Words: {'argument', 'ridiculous', 'drug', 'refusal', 'dispensed', 'pharmacy'}
# - - - - - - - - - -
# Sentence: because the effectiveness of other methods don't come close to that of owning a gun for personal protection. if they did then the police wouldn't have guns because it would be redundant and not cost effective.
# Positive Words: {'method', 'protection', 'effectiveness', 'effective', 'close', 'personal'}
# Negative Words: {'redundant', 'cost'}
# - - - - - - - - - -
# Sentence: "lottery"? i hope you don't mean that it is completely random in all cases...
#
#  note: did you notice that this was the position you were arguing against in the previous sentence?
# Positive Words: {'hope', 'lottery'}
# Negative Words: {'against', 'position', 'arguing'}
# - - - - - - - - - -
# Sentence: well if there can be a constitutional amendment to ban gay marriage, why not to remove marrriage from the federal government? where do they get that power constitutionally? so that would mean states can choose not to recognize any marriage constitutionally. i think that marriage is a church issue. let gays, straights, everyone get civil unions to be recognized legally. but leave marriage to the churches.
# Positive Words: {'union', 'federal', 'constitutionally', 'recognize', 'power', 'gay', 'marriage', 'constitutional', 'choose'}
# Negative Words: {'amendment', 'remove', 'ban', 'civil'}
# - - - - - - - - - -
# Sentence: well, the slavery analogy for gay rights is past it's applicability at this point--one was a property issue (also rooted in deep prejudice), the other is a morality issue. many people oppose gay marriage out of morality and not prejudice. the same can't be said for slavery. there are many ways that the analogy doesn't work and that's just one of them. in fact, it could as easily be an analogy to reverse it and say that the ones who did the enslaving were analogous to gay rights lobbyists and the abolitionists were analogous to those who seek to protect marriage. after all, the plantation owners were the ones really fighting for ill-conceived rights--rights that they shouldn't have had.
# Positive Words: {'reverse', 'seek', 'plantation', 'applicability', 'easily', 'morality', 'abolitionist', 'gay', 'marriage', 'doe', 'protect', 'deep', 'work'}
# Negative Words: {'ill-conceived', 'oppose', 'prejudice', 'slavery', 'analogy'}
# - - - - - - - - - -
# Sentence: marriage is a secular condition set up by various societies over the millenia and one of the prerequisites set out is that such a union should be between people of different genders.religion has supported this and sanctified it but did not invent it.you don't curse the church you lobby society to see if you can effect a change. people who believe the different gender aspect are entitled to lobby for no change.
# Positive Words: {'union', 'secular', 'gender', 'believe', 'effect', 'marriage', 'entitled', 'prerequisite', 'invent', 'change'}
# Negative Words: {'various', 'curse'}
# - - - - - - - - - -
# Sentence: ya know doc, it is really hard for someone to travel to a shooting sports event in another state. one would usually have to drive or go through ridiculous lengths in order to transport their firearm. i am glad to see some sanity in our laws now! although i sincerely doubt that the antis are happy about it.
# Positive Words: {'travel', 'happy', 'hard', 'sport', 'transport', 'glad', 'drive', 'sanity'}
# Negative Words: {'ridiculous', 'anti', 'doubt', 'shooting', 'sincerely', 'firearm'}
# - - - - - - - - - -
# Sentence: how is that a strawman? your challenge directly relies upon something you assume to be proven, but has not been. therefore even in a hypothetical stance, your underlying arguments are invalid, thus leading to everything else being invalid. you're not doing so well on this forum.
# Positive Words: {'leading', 'forum', 'challenge'}
# Negative Words: {'argument', 'hypothetical', 'invalid', 'directly', 'stance', 'strawman'}
# - - - - - - - - - -
# Sentence: just as soon as peddler's cheek stops stinging and he picks the glove up...
# Positive Words: {'pick'}
# Negative Words: {'glove', 'cheek', 'stop'}
# - - - - - - - - - -
# Sentence: well, to say it has no mental existence doesn't really tell the whole story. the fetus will have (more than likely) full mental existence in a very short time. it seems to me that if you "view humanity with mental existance as important" you'd also view as important that the unborn baby will indeed reach that point, in all likelihood.
# Positive Words: {'reach', 'baby', 'likelihood', 'humanity', 'full', 'existance', 'doe', 'mental', 'existence', 'view', 'fetus', 'unborn', 'important'}
# Negative Words: set()
# - - - - - - - - - -
# Sentence: any form of legislation is a voting matter. that's the way our system works.
# Positive Words: {'work'}
# Negative Words: {'legislation'}
# - - - - - - - - - -
# Sentence: i believe the earliest gospel estimation is placed around 50 ad, which is almost 30 years after jesus died.
# Positive Words: {'gospel', 'estimation', 'believe'}
# Negative Words: {'died'}
# - - - - - - - - - -
# Sentence: but then, there also is absolutely no evidence for such an intelligence.
# Positive Words: {'intelligence'}
# Negative Words: set()
# - - - - - - - - - -
# Sentence: yes. oddly, the picture makes as much sense as most creationists. :)
# Positive Words: set()
# Negative Words: set()
# - - - - - - - - - -
# Sentence: well yes that's what he did, but he did not try to present this as positive evidence for anything. the biomorphs were used to illustrate the point that random mutations are much more likely to produce beneficial results when the mutations are small. analogies always break down at some level, this analogy was used to illustrate a certain point. the assertion that dawkins was suggesting that a biomorph happening to look like a real life object were proof that evolution and natural selection could produce such creatures is false. montalban, to restore integrity i suggest you retract the conclusion you drew from snippets and quotes from dawkins as your paraphrasing was clearly not representative of dawkins' ideas.
# Positive Words: {'suggest', 'positive', 'evolution', 'quote', 'break', 'selection', 'natural', 'real', 'illustrate', 'assertion', 'suggesting', 'result', 'present', 'integrity', 'mutation', 'beneficial'}
# Negative Words: {'representative', 'creature', 'retract', 'false', 'restore', 'analogy', 'conclusion', 'proof'}
# - - - - - - - - - -
# Sentence: and i would like to know why that is. i asked the question in post #2 and got no answer. are laypersons lacking in intelligence so much that its hopeless for them to be on the same communication level with scientists? since they share the same society, put their pants on one leg at a time in the same way, eat, sleep, and share economic processes in comparable ways, it seems to me it would be beneficial for them and laypersons both to understand each other when they use identical terms. (like the word, theory)
# Positive Words: {'intelligence', 'communication', 'identical', 'understand', 'sleep', 'layperson', 'economic', 'share', 'beneficial'}
# Negative Words: {'hopeless', 'lacking', 'pant'}
# - - - - - - - - - -
# Sentence: well, at least you realize that.
#  just the way some apes became humans and some became chimps.
# Positive Words: {'realize'}
# Negative Words: {'chimp', 'ape'}
# - - - - - - - - - -
# Sentence: that interpretation is fine except that god says, "i will make a helper suitable for him." he hadn't made the animals yet in verse 18, but he created adam in verse 7.
# Positive Words: {'suitable', 'helper', 'verse', 'fine'}
# Negative Words: {'interpretation'}
# - - - - - - - - - -
# Sentence: the bible is evidence. its existence is a fact. what that fact represents is subject to interpretation. ken's argument is that choosing to believe the bible is infallible is no more or less of a presupposition than choosing to believe that logic is infallible. he's right in absolute terms, but those axioms are not equally congruent with reality.
# Positive Words: {'logic', 'axiom', 'believe', 'existence', 'equally', 'infallible', 'congruent', 'presupposition', 'reality', 'bible'}
# Negative Words: {'argument', 'interpretation'}
# - - - - - - - - - -
# Sentence: hence why this forum is essentially a joke. without pratts, creationists have nothing. go to the link in my signature for a place that cracks down on pratts.
# Positive Words: {'link', 'crack', 'hence', 'forum', 'signature'}
# Negative Words: {'joke', 'nothing'}
# - - - - - - - - - -
# Sentence: i see a subtle distinction here. creationism is concerned with the spiritual origins of people. "evolutionism" is entirely concerned with explaining the nature and history of the physical world. the conflict of opinion arises out of the importance of the detail- can genesis be accepted as a parable which contains a fundemental truth or must it be taken as a historical account?
# Positive Words: {'subtle', 'spiritual', 'physical', 'nature', 'origin', 'importance', 'truth'}
# Negative Words: {'creationism', 'concerned', 'parable', 'distinction', 'evolutionism', 'conflict'}
# - - - - - - - - - -
# Sentence: good shooting! got two illegal alien perps that had been deported for previous felonies and just committed another after illegally entering the country again.we need more joe horns and a heck of a lot less bradies!is this the only case you could find of a ccw exercising his rights (you know the law applies to any citizen of texas don't you and they need not be licensed?) completely justified in the penal code of texas. self-defense and defense of a third person or property is justified and required by law...it is your public duty.job well done mr. horn!!how come you don't post links (deleted by poster)? this is old news, almost 3 years ago to be exact. did you think it was sensational? lol
# Positive Words: {'entering', 'code', 'link', 'sensational', 'alien', 'good', 'committed', 'lol', 'exact', 'citizen', 'felony', 'defense'}
# Negative Words: {'deleted', 'illegal', 'illegally', 'penal', 'shooting', 'old', 'heck'}
# - - - - - - - - - -
# Sentence: 1) charliegone's article was a published research article.i would love to know where "narth's" editorial was published, if it even was published.2) narth's article did not show any "higher homosexual activity" because of legalized gay marriage.it thoroughly failed to show any rise in homosexuality in any "gay marriage" country. it showed some studies which were reportedly done in those countries, but that's it.
# Positive Words: {'research', 'rise', 'published', 'editorial', 'higher', 'love', 'homosexual', 'gay', 'marriage', 'activity'}
# Negative Words: {'homosexuality', 'failed'}
# - - - - - - - - - -
# Sentence: yes, everyone is a "potential" felon. fortunately most people never commit a felony. and there are many different types of weapons, all which could be used by previously law abiding citizens to commit an act of violence.
# Positive Words: {'commit', 'potential', 'citizen', 'fortunately', 'felony'}
# Negative Words: {'felon', 'violence', 'weapon'}
# - - - - - - - - - -
# Sentence: no, the question is why you let violent individuals remain free in public.
# Positive Words: {'free', 'individual'}
# Negative Words: {'remain', 'violent'}
# - - - - - - - - - -
# Sentence: i wouldn't say most cjurches, because you cannot prove that. there is a long list of churches that are accepting of gay folks.
# Positive Words: {'folk', 'gay', 'prove'}
# Negative Words: set()
# - - - - - - - - - -
# Sentence: actually you're wrong. actually you're very, very wrong. the 5th amendment, and all the other amendments in the bill of rights, only provide protections against government interference, not interference from your neighbors and people who don't have governmental jobs.but just for the sake of argument, if you want to argue how the man's rights were violated, how about we discuss the rights of the woman? doesn't she have a right to not be raped? doesn't she have a right to be secure in her own home against forced invasion?
# Positive Words: {'protection', 'governmental', 'provide', 'doe', 'secure'}
# Negative Words: {'against', 'argument', 'wrong', 'invasion', 'violated', 'amendment', 'forced', 'interference', 'argue'}
# - - - - - - - - - -
# Sentence: giving an answer to a conumdum doesn't necessarily solve it.
# Positive Words: {'solve', 'doe', 'necessarily'}
# Negative Words: set()
# - - - - - - - - - -
# Sentence: yes it is true that homosexuality was controversial, however it was not the controversy that lead to the decision being made to remove it. it was the act of one doctor who was sympathetic to homosexuals. it was the choice of one individual, based on compassion, not factual data. patently dangerous and wrong in my opinion.
# Positive Words: {'true', 'compassion', 'decision', 'patently', 'factual', 'homosexual', 'choice', 'individual', 'lead', 'sympathetic'}
# ...
# Negative Words: {'anti', 'fundamentalist', 'refuse', 'immorality'}
# - - - - - - - - - -
# Sentence: so why is this killing in dc on the news, when so many previous ones were ignored and treated like they didn't exist?   didn't the report say the police recovered a so called "assault rifle" from the suspects? something that's supposed to be banned under current dc laws? aren't magazines above 10 rounds also banned? how'd this killing happen if these two features are completely banned within dc and not available to anyone there?
# Positive Words: {'available', 'within', 'rifle', 'magazine', 'current'}
# Negative Words: {'treated', 'assault', 'killing', 'suspect'}
# - - - - - - - - - -
# Sentence: so you're kind of like a crimelord who claims to be a pacifist because he has thugs on the payroll who do the dirty work for him?   "ah well you see, my personal morality prohibits violence, but that doesn't inhibit me from financing, applauding and demanding violence be done on my behalf whenever it suits me. you see, as long as my hands don't directly commit the violence, i am pure as snow".   in other words, you're discussing when government should use violence. which according to you, is a lot of the time. especially should someone dare to defend themselves against a home invader.   you really don't see the hypocrisy in condemning someone for violence and simultaneously calling for more violence, do you?
# Positive Words: {'behalf', 'defend', 'payroll', 'morality', 'pure', 'simultaneously', 'pacifist', 'commit', 'doe', 'work', 'personal', 'suit'}
# Negative Words: {'against', 'demanding', 'violence', 'dare', 'directly', 'dirty', 'inhibit', 'hypocrisy', 'thug'}
# - - - - - - - - - -
# Sentence: so, you think doctors in the us make less than those in the uk?   take a look at this: it's called "statistics" not "wishful thinking and personal anecdotes".
# Positive Words: {'personal', 'wishful'}
# Negative Words: {'anecdote', 'statistic'}
# - - - - - - - - - -
# Sentence:  comparable to about a hundred million pages of the encyclopaedia britannica.\"18. show me some instances of mutations that add information to the genome:http://youtube.com/watch?v=zakryi3605gbonus question: (25 pts extra credit) -- show me the origin of anything." supersport wrote>4) show me one instance where science dated a dinosaur with carbon 14 to rule> out recent existence.show me a dinosaur bone that hasn't been fossilized. then we can go down to the lab together and get it dated, and you can have your nobel prize.
# Positive Words: {'credit', 'lab', 'science', 'prize', 'origin', 'supersport', 'together', 'recent', 'add', 'rule', 'extra', 'carbon', 'information', 'mutation'}
# Negative Words: {'dinosaur', 'bone'}
# - - - - - - - - - -
# Sentence: the enemies of freedom already have. the coined a new word. it is pre traumatic stress disorder.   meanwhile, 12 times as many children die from drowning than from accidental gunshot!
# Positive Words: {'freedom', 'new', 'child'}
# Negative Words: {'traumatic', 'die', 'gunshot', 'accidental', 'disorder', 'enemy', 'stress'}
# - - - - - - - - - -
# Sentence: the lovely thing about our system of justice, is, if a citizen acts, his actions are judged for appropriateness, and if found to be unlawful, he/she must stand in a court of law an be held accountable for them.   brady on the other hand, wants to skip all of that justice stuff, and hang us all, just because we follow the constitution and our laws, and dare to have the audacity to actually believe in both, and own a constitutionally recognized as inalienable right, gun!   so who is the law breaker here?
# Positive Words: {'inalienable', 'lovely', 'follow', 'constitutionally', 'believe', 'appropriateness', 'constitution', 'accountable', 'citizen', 'justice'}
# Negative Words: {'audacity', 'unlawful', 'dare', 'skip', 'hang'}
# - - - - - - - - - -
# Sentence: the stench of moral relativism is overwhelming. this terrorist act and the supporters of it should be suitably rewarded, good and hard.
# Positive Words: {'moral', 'good', 'hard', 'suitably', 'supporter'}
# Negative Words: {'stench', 'terrorist', 'relativism'}
# - - - - - - - - - -
# Sentence: they do provide many more services than providing abortions :p
# Positive Words: {'provide'}
# Negative Words: {'abortion'}
# - - - - - - - - - -
# Sentence: to the physics question: big bada boom!   to the philosophy question: i still enjoy christmas even though there's really no "sandy claws".
# Positive Words: {'christmas', 'enjoy', 'philosophy', 'big', 'boom'}
# Negative Words: {'claw', 'physic'}
# - - - - - - - - - -
# Sentence: vor - you're a rude piece of ****. don't worry, i just calls them as i sees them. if it offends you, then i'm terribly sorry that i pointed out that you were a rude piece of ****.
# Positive Words: {'pointed'}
# Negative Words: {'terribly', 'worry', 'sorry', 'rude'}
# - - - - - - - - - -
# Sentence:  it isn't real  so it can't be true. that  folks  is because like the creationist's bible  the darwinist academic literature is the source and well-spring of all possible truth.**big surprise  since i'm vastly outnumbered here  too. good thing that reality  truth  sanity  and rightness  are not matters of democratic vote and popularity contests. i guess. except among you darwinists  of course.**no  it has not  despite what you and your girlfriend say. and  whether it supports my pov  as i believe it does  is not the point. the point is that my pov is valid  scientific  and becoming increasingly accepted  while your darwinist boat  riddled with leaks and worm holes from day one  is finally being allowed to sink to the bottom without further plugging up and bailing out." wabbits should stick to wettuce... science is beyond their ability to digest!
# Positive Words: {'ability', 'true', 'good', 'surprise', 'doe', 'folk', 'allowed', 'science', 'democratic', 'academic', 'real', 'valid', 'reality', 'digest', 'truth', 'contest', 'believe', 'support', 'possible', 'big', 'stick', 'bible', 'literature', 'sanity'}
# Negative Words: {'bottom', 'worm', 'popularity', 'creationist', 'girlfriend', 'sink', 'hole', 'leak'}
# - - - - - - - - - -
# Sentence: we've posted this excellent piece before. the anti-gay crowd (even the anti-gays who surreally style themselves as "pro-gay" -- so they can bash gays and still get into heaven...they think) never respond to it, so thoroughly does it explode all their pitiful "arguments."
# Positive Words: {'crowd', 'surreally', 'respond', 'gay', 'bash', 'doe', 'heaven', 'excellent'}
# Negative Words: {'argument', 'explode', 'pitiful'}
# - - - - - - - - - -
# Sentence: well its possible i suppose that god created the apple and endowed it with low levels of cyanide for the specific purpose of punishing man should he consume too many. perhaps at the time the apple being referenced was a special one much like the one in snow white.
# Positive Words: {'purpose', 'consume', 'possible', 'special'}
# Negative Words: {'specific', 'punishing', 'low', 'cyanide'}
# - - - - - - - - - -
# Sentence: what's your evidence that the gospel prophecies are "spurious claims"? seems like you've bought into a scalding case of rational tunnel-vision (or political correctness, if you prefer).
# Positive Words: {'gospel', 'correctness', 'rational', 'prophecy', 'prefer'}
# Negative Words: {'political'}
# - - - - - - - - - -
# Sentence: whatever. the fact that the child's faith-based position is not supported by evidence is unsurprising. or is this the "out of the mouths of babes and fools" gambit?
# Positive Words: {'child', 'babe'}
# Negative Words: {'fool', 'gambit', 'position'}
# - - - - - - - - - -
# Sentence: where better to find more info on the evolutionary migration of humanity than from friendly atheist.com. keep that pure science with no agenda coming you guys.
# Positive Words: {'evolutionary', 'humanity', 'friendly', 'science', 'pure', 'info', 'better'}
# Negative Words: set()
# - - - - - - - - - -
# Sentence: where is the government in this? clinicians made a clinical decision, and hid behind a non-mandatory guideline, which was set by other more senior clinicians, expert in their field. assuming the woman's very detailed recall of the stressful series of events is accurate, perhaps it was god's way of telling this unmarried mother that after five previous miscarriages, she still wasn't getting the message.
# Positive Words: {'clinician', 'clinical', 'decision', 'accurate', 'senior', 'recall', 'detailed'}
# Negative Words: {'miscarriage', 'guideline', 'stressful'}
# - - - - - - - - - -
# Sentence: which ones? ineffective how?   i'd guess the laws weren't struck down simply because too many people broke them.
# Positive Words: set()
# Negative Words: {'broke', 'ineffective'}
# - - - - - - - - - -
# Sentence: why?   if the government made a law tomorrow that declared all brain surgeons would now be making the average wages of a high school janitor, how many brain surgeons do you think would continue their practice?
# Positive Words: {'continue', 'janitor', 'average', 'high', 'wage'}
# Negative Words: {'declared'}
# - - - - - - - - - -
# Sentence:  nonsense and lies that bertvan spewed is it that you want me to elaborate on?or did you want me to elaborate on some of the falsehoods and lies of yours that i have challenged? are you actually up to dealing with challenges to your spewed falsehoods  or will you run from that?" yes, all of that. prove it has any basis in fact and that berts claims cannot be true. talk and attacks are cheap but proof of anything substantial and real is few and far between by you. i'll see you uh, never? because all of the ridiculous assertions and claims you make are unprovable by any reasonable standard.
# Positive Words: {'true', 'prove', 'challenge', 'standard', 'elaborate', 'real', 'assertion', 'substantial'}
# Negative Words: {'lie', 'cheap', 'falsehood', 'nonsense', 'ridiculous', 'unprovable', 'proof', 'reasonable', 'attack'}
# - - - - - - - - - -
# Sentence: yeah, lets tax those rich greedy jerks!!! i mean really, why be equal when you want something for free right??? screw freedom i want my healthcare!!!
# Positive Words: {'free', 'freedom', 'rich', 'yeah', 'healthcare'}
# Negative Words: {'greedy', 'screw', 'jerk'}
# - - - - - - - - - -
# Sentence: yeah. it's snowing sooner here in the midwest. i think the next ice age is coming.
# Positive Words: {'yeah', 'age'}
# Negative Words: {'ice'}
# - - - - - - - - - -
# Sentence: you don't see protesters walking around going "i wanna marry my dog" or "beastiality rocks" do you?!
# Positive Words: {'marry', 'rock', 'walking'}
# Negative Words: {'wan', 'protester'}
# - - - - - - - - - -
# Sentence: you draw very interesting conclusions my friend.   if this is your standpoint then what is the purpose of a government?
# Positive Words: {'purpose', 'standpoint', 'interesting', 'friend'}
# Negative Words: {'conclusion'}
# - - - - - - - - - -
# Sentence: you haven't posted a challenge yet. including this post.   would i fit the bill?   sure, but about what? what's your resolution?   for instance, you might say "resolved: creation and evolution are equally valid interpretations of empirical evidence".   now, personally i'd say that's still too vague because 'creation' drags in all kinds of issues that evolution doesn't speak to (eg abiogenesis, cosmology etc), and 'evolution' could mean common descent, the theory of evolution, etc etc.   so we might kick the idea around for a bit and narrow it down to "resolved: hypotheses of special creation of species and common descent are equally well supported by empirical evidence".   or, perhaps it's the age of the earth you want to focus on: "resolved: all available evidence is consistent with a 6-10,000 year old earth"   i can't do this for you, feindslayer; make up your mind and present a proper challenge.
# Positive Words: {'special', 'evolution', 'consistent', 'mind', 'doe', 'kick', 'resolution', 'specie', 'sure', 'descent', 'challenge', 'cosmology', 'focus', 'personally', 'equally', 'present', 'valid', 'age', 'available'}
# Negative Words: {'vague', 'interpretation', 'empirical', 'old', 'narrow'}
# - - - - - - - - - -
# Sentence: you mean you are as biologically ignorant and as easily refuted as the thread originator? yes, we knew that already. why all the big letters?
# Positive Words: {'biologically', 'big', 'originator', 'easily'}
# Negative Words: {'thread', 'refuted', 'ignorant'}
# - - - - - - - - - -
# Sentence: you will soon learn, my friend, that fundies have very, very short memories when it comes to refutations of their arguments...
# Positive Words: {'refutation', 'learn', 'memory', 'friend'}
# Negative Words: {'argument'}
# - - - - - - - - - -
# Sentence: you're right, why not simply kill these people in the shortest amount of time possible. i got it! we can advertise each killing (hanging, rock slaying, guillotine, etc.) weeks in advance, kinda like moves, and show it on pay-per-view. you can buy tickets to watch the show live as well. i mean c'mon, if we're going to have the death penalty we might as well utilize in the most gruesome, cost efficient, and swift method possible. right? that is how punishment was executed a few centuries ago.   honestly, how you feel is how a lot of people culturally conceive such offenders. in regards to the death penalty debate, it falls along a continuum between morality and scientific reasoning.
# Positive Words: {'method', 'amount', 'efficient', 'swift', 'advance', 'honestly', 'hanging', 'fall', 'morality', 'rock', 'possible', 'advertise', 'conceive', 'continuum', 'culturally'}
# Negative Words: {'guillotine', 'punishment', 'gruesome', 'cost', 'regard', 'penalty', 'kill', 'slaying', 'death', 'killing', 'offender'}
# - - - - - - - - - -
# Sentence: you're the one who needs to get a grip. lots could get worse, but not for the reasons you're stating.   but i take it you're finally admitting that (actually) 50 million uninsured human beings who could die or go bankrupt is a big problem.
# Positive Words: {'reason', 'big'}
# Negative Words: {'die', 'bankrupt', 'problem', 'worse'}
# - - - - - - - - - -
# Sentence:  as their having guns doesn't serve the state.\"--heinrich himmlerfor pledging their support of nazi ideals  we proudly award \"yes\" the medal of holocaust and genocide. congratulations  you're now a supporter of hitler." and you win the pink panties award!i got news for you punk - my family fled the nazi's on foot in wwii
# Positive Words: {'congratulation', 'serve', 'win', 'family', 'support', 'pink', 'proudly', 'ideal', 'doe', 'award', 'medal', 'supporter'}
# Negative Words: {'genocide', 'punk', 'holocaust', 'hitler', 'nazi'}
# - - - - - - - - - -
# Sentence: depends on when the baby bird died.   run along little boy..let the adults debate.
# Positive Words: {'bird', 'baby', 'adult'}
# Negative Words: {'died'}
# - - - - - - - - - -
# Sentence: ok, sheesh, to clarify, women who arent aborting their babys are pregnant more oftan than not, the women who are having abortons have to have them several times a year.
# Positive Words: {'baby', 'clarify', 'ok'}
# Negative Words: {'pregnant', 'sheesh'}
# - - - - - - - - - -
# Sentence: so..   eh??   hows this sound?   will it fly with conservatives and progressives?   i think so.   -mosheh thezion
# Positive Words: {'fly', 'conservative', 'progressive'}
# Negative Words: set()
# - - - - - - - - - -
# Sentence: i think we should put to a vote, the right of the religious extremists, to vote at all. what say ye?   if the majority agrees, they have no say in anything anymore. isn't that the way steeeeeve says it should be done? put it to a vote?
# Positive Words: {'majority'}
# Negative Words: {'extremist'}
# - - - - - - - - - -
# Sentence: you have a blob of tissue in your "but(sic)"? sorry dude, that has to suck.   perhaps you're really referring to hemorrhoids? you do know that those aren't really blobs of tissue, right? they're really the swelling and inflammation of veins.
# Positive Words: {'swelling', 'tissue', 'vein'}
# Negative Words: {'inflammation', 'hemorrhoid', 'sorry', 'suck', 'blob'}
# - - - - - - - - - -

# %%
positive_words, negative_words = analyze_sentiment(text_data)

for i, sentence in enumerate(text_data):
    print(f"Sentence: {sentence}")
    print(f"Positive Words: {positive_words[i]}")
    print(f"Negative Words: {negative_words[i]}")
    print("- - - - - - - - - -")

# %%
df["PW"] = positive_words
df["NW"] = negative_words
df
# Out:
#         class                                               text  \
# 0     notsarc  If that's true, then Freedom of Speech is doom...
# 1     notsarc  Neener neener - is it time to go in from the p...
# 2     notsarc  Just like the plastic gun fear, the armour pie...
# 3     notsarc  So geology is a religion because we weren't he...
# 4     notsarc  Well done Monty. Mark that up as your first ev...
# ...       ...                                                ...
# 6515     sarc  depends on when the baby bird died.   run alon...
# 6516     sarc  ok, sheesh, to clarify, women who arent aborti...
# 6517     sarc  so..   eh??   hows this sound?   will it fly w...
# 6518     sarc  I think we should put to a vote, the right of ...
# 6519     sarc  You have a blob of tissue in your "but(sic)"? ...
#
#                                     PW  \
# 0          {freedom, true, subjective}
# 1                         {playground}
# 2                                   {}
# 3             {rock, religion, formed}
# 4                   {honest, accurate}
# ...                                ...
# 6515               {bird, baby, adult}
# 6516               {baby, clarify, ok}
# 6517  {fly, conservative, progressive}
# 6518                        {majority}
# 6519          {swelling, tissue, vein}
#
#                                                  NW
# 0                              {harassment, doomed}
# 1                                                {}
# 2             {fear, myth, misinformation, plastic}
# 3                                         {geology}
# 4                                                {}
# ...                                             ...
# 6515                                         {died}
# 6516                             {pregnant, sheesh}
# 6517                                             {}
# 6518                                    {extremist}
# 6519  {inflammation, hemorrhoid, sorry, suck, blob}
#
# [6520 rows x 4 columns]

# %% [markdown]
# ## 2)
# "Second, we analyze the sentence to get its syntax information to identify non-stop words
#      𝑆𝑊 = {𝑠𝑤1, 𝑠𝑤2, ..., 𝑠𝑤𝑚, 𝑚 ≤ 𝑛}.
# Intuitively, these words are the main components of sentences. Then we split 𝑆𝑊 into two sets which satisfy :
#      𝑆𝑊1 ∪ 𝑆𝑊2 = 𝑆𝑊 ,
#      |𝑆𝑊1| = |𝑆𝑊2|."

# %%
def extract_non_stop_words(sentence):
    words = nltk.word_tokenize(sentence)

    stop_words = set(stopwords.words("english"))

    non_stop_words = [word.lower() for word in words if word.lower() not in stop_words and word.isalpha()]

    return non_stop_words

# %%
def split_non_stop_words(non_stop_words):
    m = len(non_stop_words)
    m1 = m // 2
    SW1 = set(non_stop_words[:m1])
    SW2 = set(non_stop_words[m1:])
    return SW1, SW2

# %%
def analyze_sentences(sentences):
    all_SW1 = []
    all_SW2 = []

    for sentence in sentences:
        non_stop_words = extract_non_stop_words(sentence)
        SW1, SW2 = split_non_stop_words(non_stop_words)
        all_SW1.append(SW1)
        all_SW2.append(SW2)

    return all_SW1, all_SW2

# %%
all_SW1, all_SW2 = analyze_sentences(text_data)

for i, sentence in enumerate(text_data):
    print(f"Sentence: {sentence}")
    print(f"SW1: {all_SW1[i]}")
    print(f"SW2: {all_SW2[i]}")
    print("- - - - - - - - - -")
# Out:
# Streaming output truncated to the last 5000 lines.
# SW2: {'biased', 'catholic', 'pope'}
# - - - - - - - - - -
# Sentence: yet according to pp themselves, they provide far more abortions and ec services than any of their other services. :pppfa services (2002-2003)surgical abortions: 227,385 emergency contraception: 633,756 prenatal care: 15,860 adoption referrals: 1,963 (source: www.plannedparenthood.org)
# SW1: {'services', 'ec', 'abortions', 'provide', 'according', 'pp', 'far', 'pppfa', 'yet'}
# SW2: {'services', 'surgical', 'adoption', 'contraception', 'abortions', 'source', 'care', 'referrals', 'emergency', 'prenatal'}
# - - - - - - - - - -
# Sentence: well, if burglars want to steal guns then it makes sense that they would be likely to target the homes of gun owners. and the source is from the recently published book evaluating gun policy which you can read and review. the source is listed at the bottom.
# SW1: {'burglars', 'steal', 'makes', 'well', 'target', 'want', 'gun', 'likely', 'homes', 'guns', 'would', 'sense'}
# SW2: {'review', 'bottom', 'owners', 'book', 'gun', 'read', 'recently', 'published', 'source', 'listed', 'evaluating', 'policy'}
# - - - - - - - - - -
# Sentence: but the fact remains that guns are, by design, weapons.
# SW1: {'fact', 'remains'}
# SW2: {'design', 'guns', 'weapons'}
# - - - - - - - - - -
# Sentence: no it doesn't!it cost way more money in appeals than it does to excute someone. we the taxpayers pay for legal represenatation for them and us, plus the cost of keeping them in jail. the appelas process alone costs the tax payers millions.it is far more expensive to kill them than to leave them in jail with no chance of parole.
# SW1: {'pay', 'cost', 'legal', 'keeping', 'us', 'plus', 'way', 'someone', 'taxpayers', 'appeals', 'money', 'represenatation', 'excute'}
# SW2: {'chance', 'payers', 'alone', 'jail', 'expensive', 'tax', 'costs', 'process', 'kill', 'far', 'leave', 'parole', 'appelas'}
# - - - - - - - - - -
# Sentence: again, true. but that doesn't take into account that there are two populations under consideration.
# SW1: {'account', 'true', 'take'}
# SW2: {'consideration', 'populations', 'two'}
# - - - - - - - - - -
# Sentence: evolution doesn't explain the event. the event is an example of evolution - a change in the frequency of alleles in a populatioin over time. the explanation may or may not be evolution by natural selection. you merely asserted that based on your imagined case.
# SW1: {'evolution', 'event', 'example', 'explain', 'alleles', 'time', 'populatioin', 'frequency', 'change'}
# SW2: {'explanation', 'evolution', 'based', 'merely', 'imagined', 'selection', 'natural', 'case', 'asserted', 'may'}
# - - - - - - - - - -
# Sentence: but then, you are obviously scientifically illiterate. why don't you think that the panal of scientists who were hired to write the standards know better than you? it is, after all, their field.
# SW1: {'panal', 'obviously', 'scientifically', 'illiterate', 'scientists', 'think'}
# SW2: {'standards', 'hired', 'field', 'better', 'write', 'know'}
# - - - - - - - - - -
# Sentence: i'm sorry, but that's not what my version said."no one who has been emasculated by crushing or cutting may enter the assembly of the lord ." emasculated = castrated emasculation was not an accident. (what this verse has to do with the death penalty is beyond me.)
# SW1: {'enter', 'cutting', 'crushing', 'emasculated', 'sorry', 'may', 'one', 'version', 'said'}
# SW2: {'assembly', 'accident', 'emasculated', 'verse', 'emasculation', 'castrated', 'penalty', 'death', 'beyond', 'lord'}
# - - - - - - - - - -
# Sentence: well be cynical if you want, if someone in your family had done as you ascribed you wouldn't be here to be so glib. nor would the human race or any other species where penile-vaginal sex takes place. i guess all those years of biological reproduction show it. you will also notice i didn't make it an absolute statement. i said "minimal or negligable physical damage".i understand that female biology undergoes truama too during sex, the fact is the trauma of vaginal sex i.....1. more forgiving and 2. obviously possible of greater/important final result. and um, like with lesbian activities, the size of the "peg" also matters so how do you know lesbian activities are a lot less harmful.
# SW1: {'notice', 'family', 'cynical', 'show', 'absolute', 'guess', 'would', 'done', 'reproduction', 'sex', 'years', 'also', 'biological', 'race', 'glib', 'make', 'said', 'negligable', 'human', 'species', 'want', 'ascribed', 'place', 'statement', 'well', 'physical', 'minimal', 'someone', 'takes'}
# SW2: {'vaginal', 'trauma', 'result', 'activities', 'damage', 'forgiving', 'sex', 'final', 'um', 'also', 'less', 'truama', 'lot', 'lesbian', 'obviously', 'undergoes', 'fact', 'matters', 'female', 'harmful', 'peg', 'possible', 'like', 'biology', 'know', 'understand', 'size'}
# - - - - - - - - - -
# Sentence: i think you are entirely correct. from the page vor linked:
# SW1: {'correct', 'entirely', 'think'}
# SW2: {'vor', 'linked', 'page'}
# - - - - - - - - - -
# Sentence: why don't we do the same for straight marriages then?why doesn't a straight couple that gets married in colorado, and then moves to virginia, have to get their divorce "remotely" from virginia.or maybe you should start thinking about what authority colorado has to grant a divorce to virginian residents.
# SW1: {'colorado', 'couple', 'married', 'moves', 'marriages', 'straight', 'virginia', 'get', 'gets'}
# SW2: {'authority', 'residents', 'maybe', 'remotely', 'colorado', 'grant', 'start', 'virginian', 'divorce', 'thinking'}
# - - - - - - - - - -
# Sentence: actually, it hasn't. phylogenetic analysis has no relevance to occam's razor. further, dna for all organisms is the same until you examine specific sequences. it isn't that the dna is different, what matters is the the sequence of the bases is different.
# SW1: {'analysis', 'occam', 'relevance', 'phylogenetic', 'actually', 'organisms', 'razor', 'dna'}
# SW2: {'matters', 'specific', 'examine', 'sequence', 'different', 'bases', 'sequences', 'dna'}
# - - - - - - - - - -
# Sentence: and he has still yet to provide one. if more gun-control means more lives saved then more gun-control means more self preservation.
# SW1: {'still', 'provide', 'means', 'one', 'yet'}
# SW2: {'preservation', 'means', 'saved', 'lives', 'self'}
# - - - - - - - - - -
# Sentence: the purpose of the bill of rights.
# preamble to the bill of rights
# SW1: {'purpose', 'rights', 'bill'}
# SW2: {'rights', 'bill', 'preamble'}
# - - - - - - - - - -
# Sentence: i dunno... we already have enough fundies thinking that the big bang is part of evolution...
# SW1: {'already', 'dunno', 'enough', 'fundies'}
# SW2: {'evolution', 'part', 'bang', 'big', 'thinking'}
# - - - - - - - - - -
# Sentence: i see. then you are attempting to define evolution out of existance. by your definition (not that of evolutionary biologists) evolution requires an increase in information. an unsupported creationist argument. define information in a meaningful way. please apply your definition to genetics and show why all genetic changes are a decrease in information.
# SW1: {'definition', 'evolutionary', 'evolution', 'biologists', 'creationist', 'define', 'see', 'existance', 'information', 'unsupported', 'requires', 'increase', 'attempting'}
# SW2: {'argument', 'meaningful', 'apply', 'changes', 'decrease', 'show', 'way', 'define', 'genetic', 'please', 'genetics', 'information', 'definition'}
# - - - - - - - - - -
# Sentence: sounds like a fact which has been blown out of all proportion - possibly by the pro-gun side attempting to ridicule it. it is a fact, however, that the presence of a gun can increase aggression levels in individuals.see other times i have brought this up, here (to the end of the thread) and here (again, that post till the end of the thread).
# SW1: {'sounds', 'presence', 'side', 'possibly', 'like', 'ridicule', 'attempting', 'however', 'fact', 'proportion', 'blown'}
# SW2: {'brought', 'levels', 'post', 'till', 'aggression', 'gun', 'end', 'thread', 'times', 'increase'}
# - - - - - - - - - -
# Sentence: and if we can actually doing anything about it. from what i hear on the fringes, the debate should not be about how to change or stop it, but how to change to deal with it and what we should expect as society adapts to a change in climate.
# SW1: {'anything', 'fringes', 'stop', 'actually', 'debate', 'hear', 'change'}
# SW2: {'adapts', 'expect', 'society', 'deal', 'climate', 'change'}
# - - - - - - - - - -
# Sentence: what else would you expect from the people who created a god in their own image?
#
#  your thinking here is right, religion has a long history of being egocentric.
# SW1: {'created', 'else', 'expect', 'god', 'would', 'people'}
# SW2: {'right', 'religion', 'long', 'history', 'image', 'egocentric', 'thinking'}
# - - - - - - - - - -
# Sentence: well, first, i did say "the fact that you and i cannot understand this doesn't make it impossible." secondly, how is no god possible? third, a person being 100% something and 100% something else isn't entirely impossible. there are people all over the world who change from 100% idiotic to 100% non-idiotic all the time. lastly, there are many things we don't understand... so what's your point in restating what i said?
# SW1: {'third', 'impossible', 'something', 'person', 'well', 'say', 'secondly', 'make', 'possible', 'god', 'first', 'fact', 'understand'}
# SW2: {'impossible', 'entirely', 'said', 'else', 'many', 'things', 'world', 'understand', 'point', 'idiotic', 'time', 'lastly', 'restating', 'people', 'change'}
# - - - - - - - - - -
# Sentence: bet the crime rate skyrockets,but i wonder what happens if you (officers)just
#  put a bullet in them, you know for resisting arrest?
#
#  who does that pinhead mayor remind you of?emoticon_rolleyes
# SW1: {'skyrockets', 'rate', 'happens', 'officers', 'wonder', 'bet', 'crime'}
# SW2: {'bullet', 'put', 'arrest', 'pinhead', 'remind', 'know', 'mayor', 'resisting'}
# - - - - - - - - - -
# Sentence: that is what supersport is hoping to do... however, assuming that you are correct in your interpretation, he has no chance of doing it so well.
# SW1: {'supersport', 'however', 'assuming', 'hoping'}
# SW2: {'chance', 'correct', 'well', 'interpretation'}
# - - - - - - - - - -
# Sentence: yes, to follow his commandments to love god and to love one another.
# SW1: {'commandments', 'love', 'follow', 'yes'}
# SW2: {'another', 'god', 'love', 'one'}
# - - - - - - - - - -
# Sentence: you have a habit of constantly posting statements by anti-gun officials. and when these statements and theories are called into question and challenged, you have nothing to post in defense.
# SW1: {'posting', 'officials', 'habit', 'constantly', 'statements'}
# SW2: {'called', 'nothing', 'theories', 'post', 'question', 'challenged', 'defense'}
# - - - - - - - - - -
# Sentence: agreed that they are still the same species, much like the "13 species" of darwin's finches, and i have no problem with evolution in that respect. i can even see the plausibility of different subspecies evolving eventually into different species if they are geographically separated for a sufficiently long time. but i still don't see where evolution, in that sense of the term, can account for dozens of species of monkeys occupying the same patch of rainforest, or dozens of species of gazelles occupying the same patch of grassland.
# SW1: {'agreed', 'respect', 'much', 'problem', 'evolution', 'still', 'even', 'plausibility', 'finches', 'subspecies', 'eventually', 'species', 'geographically', 'different', 'darwin', 'see', 'like', 'evolving'}
# SW2: {'sufficiently', 'evolution', 'still', 'monkeys', 'long', 'occupying', 'patch', 'rainforest', 'species', 'gazelles', 'grassland', 'separated', 'term', 'see', 'time', 'account', 'dozens', 'sense'}
# - - - - - - - - - -
# Sentence: no, it requires pretty much the same amount of faith, as if faith could be quantified.
#
#  .
# SW1: {'pretty', 'amount', 'much', 'requires'}
# SW2: {'could', 'faith', 'quantified'}
# - - - - - - - - - -
# Sentence: again that is a poor analogy. congress does not have any powers not included in the constitution. quite the opposite, it specifically says that any powers not included in the constitution is defaulted to the states and congress is additionally prohibited from taking any more authority not named in the constitution.since there is no specific naming article saying congress does not have the power to ban manufacturing weapons, in fact it does not. according to the 10th amendment:the powers not delegated to the united states by the constitution, nor prohibited by it to the states, are reserved to the states respectively, or to the people.thus you have another poor analogy. congress does not have the right to ban manufacture of guns.
# SW1: {'prohibited', 'analogy', 'defaulted', 'opposite', 'congress', 'specifically', 'says', 'article', 'quite', 'specific', 'naming', 'named', 'saying', 'states', 'taking', 'authority', 'additionally', 'included', 'constitution', 'powers', 'poor'}
# SW2: {'ban', 'prohibited', 'power', 'amendment', 'analogy', 'manufacture', 'congress', 'according', 'united', 'manufacturing', 'right', 'delegated', 'reserved', 'guns', 'another', 'fact', 'states', 'respectively', 'constitution', 'powers', 'weapons', 'poor'}
# - - - - - - - - - -
# Sentence: see above. nothing has been demonstrated that convinces me that god has been ruled out of all these issues. he probably isn't active in all situations, but there's nothing that says he (or even satan) are totally inconsequential either.
# SW1: {'ruled', 'nothing', 'issues', 'convinces', 'demonstrated', 'see', 'god', 'probably'}
# SW2: {'even', 'nothing', 'situations', 'inconsequential', 'says', 'totally', 'active', 'satan', 'either'}
# - - - - - - - - - -
# Sentence: i think shortej is not a creationist. he/she never said so, and started off by saying he/she accepts evolution and maintains her catholic beliefs. (i have a hunch its "she")
# SW1: {'never', 'shortej', 'creationist', 'think', 'started', 'said'}
# SW2: {'evolution', 'beliefs', 'maintains', 'hunch', 'accepts', 'saying', 'catholic'}
# - - - - - - - - - -
# Sentence: because apes, monkeys and chimps are on different paths. you wouldn't expect a shark to evolve into a barracuda-like animal. things evolve to fill niches, we currently fill a niche, there is nothing pushing apes, chimps or other primates to fill a niche that is occupied.
# SW1: {'chimps', 'monkeys', 'paths', 'things', 'apes', 'expect', 'different', 'evolve', 'shark', 'would', 'animal'}
# SW2: {'primates', 'nothing', 'chimps', 'apes', 'fill', 'currently', 'occupied', 'pushing', 'niche', 'niches'}
# - - - - - - - - - -
# Sentence: so what if he dislikes science? if he believes something else, he has the right to believe that way. my problem here is that he shows more closed-mindedness to the viewpoints of others.
# SW1: {'something', 'right', 'else', 'science', 'dislikes', 'believes'}
# SW2: {'problem', 'believe', 'shows', 'way', 'others', 'viewpoints'}
# - - - - - - - - - -
# Sentence: this isn't discrimination because the adult once did have have the right to live in a womb until it could live otherwise. once out of the womb and living on his/her own this right has been exhausted because there is no need to be living in the womb. much like you can drive but this 'right' is exhausted when you are drunk or too old to see anything.
# SW1: {'discrimination', 'womb', 'right', 'adult', 'live', 'otherwise', 'could', 'living'}
# SW2: {'womb', 'much', 'anything', 'exhausted', 'drunk', 'living', 'like', 'see', 'old', 'need', 'drive'}
# - - - - - - - - - -
# Sentence: it depends on your intention and your methods. of course, things that don't have some sort of physical manifestation that can be measured can't be studied by science. science is naturalistic. scientific data can only include that which can be observed and quantified by natural means. i read it in a book of mythology isn't scientific.
# SW1: {'course', 'ca', 'intention', 'methods', 'things', 'sort', 'physical', 'measured', 'science', 'manifestation', 'studied', 'depends'}
# SW2: {'naturalistic', 'include', 'mythology', 'data', 'science', 'read', 'natural', 'quantified', 'book', 'means', 'scientific', 'observed'}
# - - - - - - - - - -
# Sentence: when someone lacks the ability to understand and the ganas to try, then it doesn't make sense. however, if you understood any of it, it would be different. after all, you repeat over and over again how you don't understand.
# SW1: {'ability', 'try', 'ganas', 'someone', 'lacks', 'make', 'understand'}
# SW2: {'repeat', 'different', 'however', 'understood', 'would', 'understand', 'sense'}
# - - - - - - - - - -
# Sentence: cars are a privilege, your gun isn't. show me evidence that would support the registration of your first amendment rights being constitutional.
# SW1: {'gun', 'show', 'evidence', 'cars', 'privilege', 'would'}
# SW2: {'registration', 'support', 'rights', 'amendment', 'constitutional', 'first'}
# - - - - - - - - - -
# Sentence: and you just did what you chastise me for in your next sentence
# SW1: {'chastise'}
# SW2: {'next', 'sentence'}
# - - - - - - - - - -
# Sentence: the original molecule had some lipolytic function, but removing some amino acids from it, in the right place, made it fit better into the substrate, and thereby greatly increased its functionality. barbarian observes:we thought it would take roughly a million years for bacteria to evolve enzymes capable of digesting nylon (because the compound is so different than any they were able to digest) but it took less than a century. .
# SW1: {'fit', 'function', 'amino', 'greatly', 'removing', 'observes', 'increased', 'functionality', 'acids', 'molecule', 'original', 'lipolytic', 'right', 'place', 'made', 'substrate', 'barbarian', 'better', 'thereby'}
# SW2: {'roughly', 'evolve', 'would', 'bacteria', 'years', 'take', 'took', 'less', 'century', 'digesting', 'capable', 'nylon', 'compound', 'different', 'million', 'enzymes', 'thought', 'digest', 'able'}
# - - - - - - - - - -
# Sentence: hundreds of thousands of atheist scientists do too, since common ancestry with apes harmonizes perfectly with the absence of a creator. they're seldom asked to answer about that confusion, however.
# SW1: {'ancestry', 'atheist', 'hundreds', 'common', 'apes', 'since', 'thousands', 'scientists'}
# SW2: {'perfectly', 'asked', 'answer', 'however', 'harmonizes', 'absence', 'creator', 'confusion', 'seldom'}
# - - - - - - - - - -
# Sentence: i think that the bad guys will be happy if any gun control law goes into effect, because then there will be less chance of the victum having a weapon for their defense, and the crime rate will rise!!!!!!!!!!!!!!!!!!!!!!
# SW1: {'control', 'goes', 'happy', 'gun', 'guys', 'bad', 'law', 'think'}
# SW2: {'chance', 'rate', 'rise', 'weapon', 'effect', 'less', 'victum', 'crime', 'defense'}
# - - - - - - - - - -
# Sentence: because....expansion occurs after heat is added. how can a expansion occur with a prior cause? you're saying the reaction and cause happen at the same time. show me an example that does that.
# SW1: {'heat', 'added', 'occurs', 'prior', 'expansion', 'occur'}
# SW2: {'reaction', 'cause', 'example', 'show', 'time', 'happen', 'saying'}
# - - - - - - - - - -
# Sentence: and we do. in some phyla, most of the partially-formed examples still exist. you can find them in mollusks, for example.
#
#  http://www.pnas.org/content/vol104/suppl_1/images/large/zpq0120756920001.jpeg
# SW1: {'phyla', 'exist', 'examples', 'still'}
# SW2: {'http', 'find', 'example', 'mollusks'}
# - - - - - - - - - -
# Sentence: actually, i can not accept that claim. before then, the absolutely youngest ever surviving fetus was deliver at 19 weeks, 6 days. 12 weeks would be a worldwide sensation. i would recommend that you double-check your source. viability is still defined as the age at which 50% survive, which still is at around 24 weeks gestation/26 weeks pregnancy.
# SW1: {'youngest', 'surviving', 'deliver', 'days', 'actually', 'accept', 'claim', 'ever', 'weeks', 'fetus', 'would', 'absolutely', 'worldwide'}
# SW2: {'recommend', 'still', 'survive', 'pregnancy', 'source', 'sensation', 'defined', 'weeks', 'around', 'age', 'would', 'viability'}
# - - - - - - - - - -
# Sentence: if that were true, why are there millions of miscarriages each year? i don't believe a word of it.
# SW1: {'millions', 'miscarriages', 'true'}
# SW2: {'year', 'believe', 'word'}
# - - - - - - - - - -
# Sentence: it's not a literal account unless you interpret it that way.
# SW1: {'account', 'literal'}
# SW2: {'interpret', 'way', 'unless'}
# - - - - - - - - - -
# Sentence: if! but here's the thing, mexico is making absolutely no attempt to truly stomp out the drug cartels, they're catering to them! various political figures and police officers are on the take, they're getting massive amounts of bribe money from the cartels, stopping them would prove detrimental.
# SW1: {'mexico', 'attempt', 'making', 'catering', 'truly', 'thing', 'stomp', 'drug', 'political', 'figures', 'various', 'absolutely', 'cartels'}
# SW2: {'would', 'prove', 'stopping', 'take', 'officers', 'massive', 'detrimental', 'bribe', 'police', 'money', 'amounts', 'cartels', 'getting'}
# - - - - - - - - - -
# Sentence: well, if they've re-established control in new orleans(and it seems they have), then taking a gun away from someone carrying it on the street would be what the police normally do in any city. if they were taking it away from peoples' homes, and not letting them keep them, that would be over and above what they normally do. (i'm very pro-2nd amendment, so don't get me wrong here. i'm just pointing out that taking guns away from people happens in every city every day)i also think that it's kind of disingenuous to complain about the military coming in--just a week ago everyone was criticizing the govt. for not sending in the military. now people are criticizing them for doing it???
# SW1: {'normally', 'wrong', 'carrying', 'letting', 'amendment', 'would', 'peoples', 'street', 'police', 'gun', 'city', 'seems', 'homes', 'orleans', 'control', 'taking', 'new', 'well', 'someone', 'keep', 'get', 'away'}
# SW2: {'day', 'disingenuous', 'happens', 'everyone', 'ago', 'kind', 'think', 'complain', 'coming', 'also', 'every', 'week', 'govt', 'people', 'criticizing', 'city', 'guns', 'sending', 'military', 'taking', 'pointing', 'away'}
# - - - - - - - - - -
# Sentence: because if you let gays marry because it is an alternitve way the equal protection says that if you let one happen you have to let the others have that right to. but that is not really my point my real point is that if we let this happend it will ruin marriage in this country, marriage is a bond between a man and a women and if we let gays marry this country will be ruining that tradition thus making this country more secular then it all ready is. and we have to stop that.
# SW1: {'protection', 'equal', 'gays', 'right', 'marry', 'point', 'real', 'alternitve', 'way', 'says', 'really', 'one', 'happen', 'others', 'let'}
# SW2: {'gays', 'ruining', 'secular', 'happend', 'marry', 'making', 'stop', 'ready', 'ruin', 'bond', 'women', 'country', 'marriage', 'tradition', 'man', 'thus', 'let'}
# - - - - - - - - - -
# Sentence: just isn't the case in countries with nationalised health care, yet those countries also have a large number of pharmaceutical companies that are based there.
# SW1: {'case', 'countries', 'care', 'health', 'nationalised', 'yet'}
# SW2: {'pharmaceutical', 'companies', 'based', 'also', 'countries', 'large', 'number'}
# - - - - - - - - - -
# Sentence: are you saying that an argument that is inconsistent with science should not be called unscientific, or are you saying that it should not be rejected because it is unscientific?
# SW1: {'argument', 'inconsistent', 'saying', 'science'}
# SW2: {'unscientific', 'saying', 'rejected', 'called'}
# - - - - - - - - - -
# Sentence: you have to remember that those christians believe that the laws of god superceed those of man. that thier allegiance is to god and his laws above those of the constitution. they also believe that all should be subject to gods by force if nesesary.
# SW1: {'laws', 'superceed', 'thier', 'remember', 'allegiance', 'christians', 'believe', 'god', 'man'}
# SW2: {'laws', 'force', 'also', 'constitution', 'believe', 'god', 'nesesary', 'gods', 'subject'}
# - - - - - - - - - -
# Sentence: it is all repeated time after time, and time again then again. but you are correct. here is one of the links to those studies. emoticonxsmilie http://www.4forums.com/political/gun...tml#post354115but what do we do about this? http://works.bepress.com/cgi/viewcon...dennis_culhane which is a study of criminals shooting criminals but it is hoped that people will think it is about law abiding concealed carry. this is not representative of law-abiding concealed carry or legal gun ownership in any way. and we have this.guns and death - firearms research - harvard injury control research center - harvard school of public healthso lets look at the actual crime figures to see if any of this holds water.  according to this 1999 article  there were 250 million guns in circulation in 1999.   total nics background checks november 30, 1998 - june 30, 2009
# SW1: {'legal', 'emoticonxsmilie', 'think', 'representative', 'abiding', 'carry', 'shooting', 'links', 'hoped', 'time', 'one', 'http', 'studies', 'people', 'repeated', 'study', 'tml', 'gun', 'law', 'criminals', 'correct', 'ownership', 'way', 'concealed'}
# SW2: {'research', 'lets', 'harvard', 'total', 'holds', 'figures', 'injury', 'firearms', 'background', 'according', 'article', 'november', 'circulation', 'school', 'see', 'million', 'water', 'guns', 'nics', 'death', 'control', 'june', 'public', 'healthso', 'center', 'look', 'checks', 'actual', 'crime'}
# - - - - - - - - - -
# Sentence: okay, you are right... we need a definition for a 'hole,' as it is a bit of a subjective concept. allow me to define 'hole' like this: the void created by the intentional destruction of something already in existence. using 'hole' with this definition makes alcorn's statement (minus the word 'terrible') a true fact in the physical realm. and it precludes any of your other ideas from creating 'holes,' since they all deal with potentiality, not reality.
# SW1: {'already', 'void', 'right', 'bit', 'created', 'destruction', 'something', 'subjective', 'existence', 'concept', 'okay', 'define', 'like', 'allow', 'need', 'intentional', 'definition'}
# SW2: {'definition', 'true', 'realm', 'statement', 'precludes', 'minus', 'ideas', 'potentiality', 'makes', 'physical', 'word', 'using', 'since', 'creating', 'reality', 'fact', 'deal', 'alcorn'}
# - - - - - - - - - -
# Sentence: religion: commitment or devotion to religious faith or observance
#
#  religious: relating to or manifesting faithful devotion to an acknowledged ultimate reality or diety
#
#  therefore we can conclude that atheism and agnosticism are religions.
# SW1: {'manifesting', 'religious', 'relating', 'religion', 'observance', 'devotion', 'commitment', 'faithful', 'faith'}
# SW2: {'diety', 'therefore', 'devotion', 'conclude', 'agnosticism', 'acknowledged', 'atheism', 'reality', 'ultimate', 'religions'}
# - - - - - - - - - -
# Sentence: i'd say there were a lot of stones going both ways.
#
#  do you know the rev. well enough to be able to make that claim, that he's a bigot? or is it he represents the system?
# SW1: {'going', 'lot', 'ways', 'rev', 'say', 'know', 'stones'}
# SW2: {'able', 'well', 'bigot', 'system', 'represents', 'claim', 'enough', 'make'}
# - - - - - - - - - -
# Sentence: i know exactly what you were saying. and it seems i was right, you have nothing to back up your claim that people were betting that it would fail. it's just something you're "sure" of, i.e. something you made up. like i figured.
# SW1: {'right', 'nothing', 'back', 'seems', 'claim', 'know', 'saying', 'people', 'exactly'}
# SW2: {'sure', 'made', 'something', 'figured', 'like', 'fail', 'would', 'betting'}
# - - - - - - - - - -
# Sentence: i think you mean to say is hunters not liberal democrat hunters. actualy i know of very few hunters that only have rifles or shot guns they usualy also have pistols to since you can hunt with them also.
# SW1: {'democrat', 'liberal', 'say', 'actualy', 'mean', 'hunters', 'know', 'think'}
# SW2: {'shot', 'pistols', 'usualy', 'hunt', 'also', 'rifles', 'since', 'guns', 'hunters'}
# - - - - - - - - - -
# Sentence: and those pillars will be replaced by something stronger like equality and justice.
# SW1: {'pillars', 'something', 'replaced'}
# SW2: {'justice', 'equality', 'like', 'stronger'}
# - - - - - - - - - -
# Sentence: she should not have the baby in the first place, and thats what im saying. the only irresponsible move a 12 year old would be making is not having an abortion, as she is not physically and emotionally capable of raising or bearing a child.
# SW1: {'baby', 'year', 'move', 'im', 'place', 'thats', 'first', 'saying', 'irresponsible'}
# SW2: {'bearing', 'physically', 'making', 'emotionally', 'abortion', 'capable', 'child', 'raising', 'old', 'would'}
# - - - - - - - - - -
# Sentence: stop trying to muddy the waters. i asked you to back up your claim that gun control is racist. that is not asking others to do my work for me. that is asking you to back up a claim that you made.
# SW1: {'trying', 'back', 'stop', 'waters', 'gun', 'asked', 'muddy', 'claim'}
# SW2: {'control', 'racist', 'back', 'asking', 'claim', 'made', 'work', 'others'}
# - - - - - - - - - -
# Sentence: first of all, the government cannot increase the volume and social acceptance of a drug - only the market and society can do that. government cannot even decrease the volume or social acceptance of drugs - despite the government's efforts, drug use has remained relatively constant. what hasn't remained constant is violent crime, which has gone up during the drug war as it did during alcohol prohibition.
# SW1: {'drugs', 'even', 'government', 'market', 'acceptance', 'decrease', 'social', 'drug', 'society', 'first', 'volume', 'increase'}
# SW2: {'war', 'use', 'constant', 'remained', 'efforts', 'relatively', 'drug', 'gone', 'violent', 'despite', 'prohibition', 'crime', 'alcohol', 'government'}
# - - - - - - - - - -
# Sentence: well it came from somewhere and presumably changed as it went along.
# SW1: {'came', 'somewhere', 'well'}
# SW2: {'presumably', 'went', 'along', 'changed'}
# - - - - - - - - - -
# Sentence: straw man. i am not attacking the achievements of science. i am attacking the notion that you have that scientists are exempt from the catalogue of influences that affect everyone else; with only the slightest admission of a tiny possibility of cultural influence - which was quickly dismissed anyway with the false analogy of comparing evolution to aeronautical engineering.
# SW1: {'catalogue', 'attacking', 'achievements', 'science', 'everyone', 'else', 'affect', 'straw', 'notion', 'exempt', 'influences', 'man', 'scientists'}
# SW2: {'anyway', 'comparing', 'evolution', 'possibility', 'quickly', 'cultural', 'tiny', 'influence', 'false', 'dismissed', 'engineering', 'admission', 'analogy', 'aeronautical', 'slightest'}
# - - - - - - - - - -
# Sentence: but growth is fairly irrelevant. my sperm can grow into a human too, and have mental existence, yet ejaculating isn't murder. it just becomes a huge debate on where to draw the line, therefore it is best to focus on the state that it is right now. not what it was or could possibly be.that seems reasonable to me.[/quote]
# SW1: {'murder', 'human', 'existence', 'grow', 'becomes', 'fairly', 'ejaculating', 'sperm', 'growth', 'mental', 'irrelevant', 'yet'}
# SW2: {'draw', 'best', 'right', 'therefore', 'focus', 'possibly', 'seems', 'could', 'state', 'debate', 'huge', 'line', 'reasonable'}
# - - - - - - - - - -
# Sentence: over 10,000 signatures of christian clergy have been collected, and have endorsed this letter.
# SW1: {'clergy', 'christian', 'signatures'}
# SW2: {'endorsed', 'collected', 'letter'}
# - - - - - - - - - -
# Sentence: this stat sounds more than a bit inflated. seeing as it comes from a website called "women's issues" it is probably not all that credible.
# SW1: {'seeing', 'inflated', 'sounds', 'comes', 'bit', 'stat'}
# SW2: {'called', 'credible', 'website', 'issues', 'women', 'probably'}
# - - - - - - - - - -
# Sentence: there is a pretty huge difference.civil unions aren't nationally recognized, for one thing, since not every state has them. if you travel to a state that does not offer civil unions, then your union is not valid there.i think there's a problem with dissolving those unions as well.the big difference, though, are the rights that these unions provide. there are over 1,000 legal protections and rights that marriage provides that civil unions don't. i'll try and find a list of differences.
# SW1: {'union', 'valid', 'travel', 'problem', 'nationally', 'every', 'since', 'unions', 'pretty', 'thing', 'recognized', 'civil', 'one', 'state', 'offer', 'huge', 'think'}
# SW2: {'try', 'differences', 'difference', 'legal', 'though', 'provides', 'provide', 'unions', 'rights', 'marriage', 'list', 'dissolving', 'big', 'civil', 'protections', 'find'}
# - - - - - - - - - -
# Sentence: that's a nice silver-lining take on the situation, but you and i both know that there are times someone who has a greater and more pressing need for the job (even to feed his family) gets put aside for someone who doesn't need it as badly. the issue here isn't "fairness." this issue is doing unto others as you'd have them do unto you. if you're going to hold the golden rule up as a rule, you have to be consistent.
# SW1: {'feed', 'pressing', 'even', 'job', 'put', 'take', 'family', 'need', 'someone', 'situation', 'greater', 'nice', 'times', 'gets', 'know'}
# SW2: {'badly', 'unto', 'fairness', 'going', 'hold', 'issue', 'golden', 'consistent', 'someone', 'aside', 'rule', 'need', 'others'}
# - - - - - - - - - -
# Sentence: no, but the roman persecution of christians, covering christians in pitch, roman garden parties, witnesses for christ being killed for their faith etc. is as irrelevant as it gets. just be careful, that's all i'm saying. there is a place for that topic.
# SW1: {'pitch', 'covering', 'persecution', 'christians', 'parties', 'garden', 'roman', 'witnesses'}
# SW2: {'careful', 'christ', 'topic', 'killed', 'etc', 'saying', 'place', 'gets', 'faith', 'irrelevant'}
# - - - - - - - - - -
# Sentence: i think you just made the point that they're people after a certain degree of development takes place.
# SW1: {'point', 'people', 'think', 'made'}
# SW2: {'degree', 'certain', 'place', 'takes', 'development'}
# - - - - - - - - - -
# Sentence: so which is it: the action is moral, the action is immoral, or there is no answer? you seem confused.
# SW1: {'action', 'moral'}
# SW2: {'seem', 'answer', 'immoral', 'confused'}
# - - - - - - - - - -
# Sentence: as mach pointed out, you (montalban) are arguing with yourself here.you stated that "bacteria needing nylon to survive" is put forth as evidence for evolution. then you said that an alternate view was that there are some bacteria that need nylon to survive.anyway, an actual alternate view is that the experiments performed to determine whether the bacteria could survive on nylon alone could not have been exhaustive. there may still be a natural substance on which the bacteria survives. it may even be similar to nylon, but it has yet to be discovered. this is a big maybe, though.
# SW1: {'evolution', 'montalban', 'pointed', 'mach', 'view', 'forth', 'bacteria', 'alternate', 'needing', 'arguing', 'said', 'put', 'nylon', 'survive', 'experiments', 'need', 'performed', 'stated', 'actual', 'evidence'}
# SW2: {'whether', 'could', 'determine', 'similar', 'bacteria', 'alone', 'may', 'discovered', 'maybe', 'though', 'survive', 'nylon', 'substance', 'even', 'still', 'natural', 'survives', 'exhaustive', 'big', 'yet'}
# - - - - - - - - - -
# Sentence: really if this is another one of your fresh organic sample = age of decades of time capsule because they were both on top of the ground, you're officially delusional.
# SW1: {'fresh', 'really', 'one', 'sample', 'another', 'age', 'organic'}
# SW2: {'ground', 'top', 'decades', 'time', 'delusional', 'officially', 'capsule'}
# - - - - - - - - - -
# Sentence: pretty good considering darwin wasn't aware of genetics. too bad wells is stuck in 1859. the modern synthesis provides perfectly legitimate mechanisms.
# SW1: {'considering', 'aware', 'good', 'pretty', 'darwin', 'bad', 'genetics'}
# SW2: {'perfectly', 'wells', 'modern', 'provides', 'mechanisms', 'stuck', 'synthesis', 'legitimate'}
# - - - - - - - - - -
# Sentence: you think "the unborn child is worthy of protection"..."but not more so than the mother, probably less"...yet you believe "in most circumstances the child should be carried to term?"
# SW1: {'protection', 'worthy', 'unborn', 'child', 'probably', 'think', 'mother'}
# SW2: {'circumstances', 'carried', 'believe', 'term', 'less', 'child', 'yet'}
# - - - - - - - - - -
# Sentence: well, i'm sincere in how i interpreted what he wrote, and i honestly believe that is what he meant.
# SW1: {'sincere', 'well', 'interpreted'}
# SW2: {'meant', 'believe', 'honestly', 'wrote'}
# - - - - - - - - - -
# Sentence: if i am to believe in something even if it's scientific, i should be able to challenge the belief's of the person who's pushing it. if they don't believe in what they're selling, why should i.
# SW1: {'even', 'able', 'something', 'believe', 'scientific'}
# SW2: {'belief', 'challenge', 'person', 'believe', 'selling', 'pushing'}
# - - - - - - - - - -
# Sentence: yet without it the vessel is just worms, mud, then dust, like rock & tree houses, not made to endure, yet, the life force, energy, back to the cosmos/source, converted, capable of being rewinded, paused, and fastfowarded, like a movie screen amongst the stars, revealing our lives.
# SW1: {'dust', 'tree', 'life', 'vessel', 'endure', 'rock', 'like', 'houses', 'worms', 'made', 'without', 'mud', 'yet'}
# SW2: {'amongst', 'screen', 'back', 'force', 'rewinded', 'fastfowarded', 'capable', 'movie', 'stars', 'energy', 'lives', 'like', 'revealing', 'paused', 'converted'}
# - - - - - - - - - -
# Sentence: well, man has been called the third chimpanzee. cladistics is some decades old now, and it has suplanted the old linean system. while discoveries are still assigned genus and species names, evaluation of morphological charisteristics by computer yield much more realistic evolutionary trees.
# SW1: {'suplanted', 'chimpanzee', 'called', 'well', 'linean', 'system', 'discoveries', 'decades', 'old', 'cladistics', 'third', 'man'}
# SW2: {'evaluation', 'genus', 'much', 'charisteristics', 'still', 'evolutionary', 'computer', 'trees', 'species', 'names', 'yield', 'realistic', 'assigned', 'morphological'}
# - - - - - - - - - -
# Sentence: but they didn't have sexual relations. this was from a sperm bank- there was nothing that made the two people create one being. nonetheless, this is a side issue for future debates. my main point is homosexuality is a disorder that the government shouldn't be condoning. the government obviously doesn't condone pedophilia, poligamy, and incest. why is the government condoning homosexuality?
# SW1: {'sexual', 'debates', 'nothing', 'relations', 'two', 'issue', 'one', 'side', 'create', 'sperm', 'made', 'future', 'nonetheless', 'people'}
# SW2: {'main', 'obviously', 'point', 'homosexuality', 'disorder', 'condoning', 'incest', 'condone', 'pedophilia', 'poligamy', 'government'}
# - - - - - - - - - -
# Sentence: evolution's evidence is that life is similar, you won't be able to find an exception i am sure.
# SW1: {'evidence', 'life', 'similar', 'evolution'}
# SW2: {'wo', 'sure', 'able', 'exception', 'find'}
# - - - - - - - - - -
# Sentence: the us is still the closest thing to a pure capitalist country in the world. but you are correct, our system is not a pure capitalist one. we have reminants of all types of systems including socialism. in the modern world i don't think a society as large as the us is could be run under just one pure system.
# SW1: {'correct', 'still', 'pure', 'us', 'world', 'system', 'thing', 'one', 'country', 'closest', 'reminants', 'capitalist'}
# SW2: {'run', 'modern', 'systems', 'world', 'us', 'socialism', 'large', 'could', 'one', 'society', 'pure', 'system', 'including', 'types', 'think'}
# - - - - - - - - - -
# Sentence: i thought i had worded my post quite clearly. i even pointed out that it appeared that dembski thought that there were only three laws of thermodynamics and claimed to have discovered a 4th (which he of course named the 4th law of thermodynamics). he seems unaware of the zeroth law.
# SW1: {'appeared', 'even', 'post', 'dembski', 'pointed', 'worded', 'three', 'quite', 'thought', 'clearly'}
# SW2: {'course', 'claimed', 'laws', 'discovered', 'seems', 'law', 'named', 'unaware', 'zeroth', 'thermodynamics'}
# - - - - - - - - - -
# Sentence: "healthy families" seems like a strange name for this group that the link is to.
# SW1: {'seems', 'like', 'healthy', 'families'}
# SW2: {'name', 'group', 'strange', 'link'}
# - - - - - - - - - -
# Sentence: the burden of a pregnancy is the woman's. it should be left up to her and her doctor to decide what is best for her.
# SW1: {'pregnancy', 'burden', 'woman'}
# SW2: {'doctor', 'decide', 'left', 'best'}
# - - - - - - - - - -
# Sentence: because you've presented no credible evidence to support the claims that private transactions are an established and major source of firearms for criminals.
#
#  if you can't prove it's broken, you don't have grounds to call for fixing it.
# SW1: {'transactions', 'claims', 'credible', 'support', 'presented', 'established', 'evidence', 'major', 'private'}
# SW2: {'grounds', 'ca', 'prove', 'firearms', 'fixing', 'source', 'criminals', 'call', 'broken'}
# - - - - - - - - - -
# Sentence: that's right. it merely has the capacity to make errors which sometimes slightly improves function in a particular environment. and those tend to accumulate over time.
# SW1: {'sometimes', 'right', 'capacity', 'merely', 'slightly', 'errors', 'make'}
# SW2: {'accumulate', 'improves', 'function', 'particular', 'time', 'tend', 'environment'}
# - - - - - - - - - -
# Sentence: snipthis opinion piece was put forth by the violence policy center, the same people who opposed all forms of firearms safety training and gun locks, because they might encourage people to feel that they're more capable of safely operation a firearm. the violence policy center also pushed the idea of an "assault weapons ban" because it was easier than a handgun ban, claiming that the uneducated people are unable to tell what is a machine gun and what isn't a machine gun, making passage of such a law all the easier.
# SW1: {'encourage', 'forms', 'safety', 'policy', 'forth', 'opinion', 'firearms', 'people', 'violence', 'put', 'opposed', 'training', 'might', 'gun', 'capable', 'firearm', 'safely', 'operation', 'piece', 'feel', 'center', 'locks', 'snipthis'}
# SW2: {'pushed', 'ban', 'assault', 'uneducated', 'tell', 'policy', 'handgun', 'machine', 'making', 'also', 'passage', 'people', 'violence', 'gun', 'law', 'center', 'idea', 'weapons', 'claiming', 'unable', 'easier'}
# - - - - - - - - - -
# Sentence: what's ridiculous is your mis-reading of the argument. i'm both discussing individual pharmacists, and their refusal of service to individuals based on the drug the individual wants, which is already assumed to be dispensed at that pharmacy or chain.
# SW1: {'argument', 'ridiculous', 'individuals', 'discussing', 'refusal', 'service', 'individual', 'pharmacists'}
# SW2: {'already', 'based', 'wants', 'drug', 'individual', 'dispensed', 'chain', 'assumed', 'pharmacy'}
# - - - - - - - - - -
# Sentence: because the effectiveness of other methods don't come close to that of owning a gun for personal protection. if they did then the police wouldn't have guns because it would be redundant and not cost effective.
# SW1: {'effectiveness', 'come', 'methods', 'owning', 'gun', 'close', 'personal'}
# SW2: {'protection', 'cost', 'effective', 'redundant', 'police', 'guns', 'would'}
# - - - - - - - - - -
# Sentence: "lottery"? i hope you don't mean that it is completely random in all cases...
#
#  note: did you notice that this was the position you were arguing against in the previous sentence?
# SW1: {'hope', 'cases', 'random', 'lottery', 'completely', 'mean'}
# SW2: {'note', 'sentence', 'notice', 'position', 'previous', 'arguing'}
# - - - - - - - - - -
# Sentence: well if there can be a constitutional amendment to ban gay marriage, why not to remove marrriage from the federal government? where do they get that power constitutionally? so that would mean states can choose not to recognize any marriage constitutionally. i think that marriage is a church issue. let gays, straights, everyone get civil unions to be recognized legally. but leave marriage to the churches.
# SW1: {'marrriage', 'federal', 'ban', 'constitutionally', 'well', 'recognize', 'amendment', 'gay', 'marriage', 'remove', 'constitutional', 'power', 'get', 'mean', 'choose', 'would', 'states', 'government'}
# SW2: {'gays', 'constitutionally', 'get', 'legally', 'everyone', 'churches', 'unions', 'church', 'marriage', 'recognized', 'civil', 'straights', 'leave', 'issue', 'think', 'let'}
# - - - - - - - - - -
# Sentence: well, the slavery analogy for gay rights is past it's applicability at this point--one was a property issue (also rooted in deep prejudice), the other is a morality issue. many people oppose gay marriage out of morality and not prejudice. the same can't be said for slavery. there are many ways that the analogy doesn't work and that's just one of them. in fact, it could as easily be an analogy to reverse it and say that the ones who did the enslaving were analogous to gay rights lobbyists and the abolitionists were analogous to those who seek to protect marriage. after all, the plantation owners were the ones really fighting for ill-conceived rights--rights that they shouldn't have had.
# SW1: {'applicability', 'ca', 'slavery', 'analogy', 'rooted', 'point', 'also', 'past', 'gay', 'one', 'oppose', 'people', 'said', 'rights', 'issue', 'property', 'morality', 'many', 'well', 'prejudice', 'marriage', 'deep'}
# SW2: {'reverse', 'could', 'really', 'analogy', 'work', 'ones', 'analogous', 'gay', 'protect', 'one', 'lobbyists', 'plantation', 'easily', 'owners', 'rights', 'abolitionists', 'fact', 'seek', 'ways', 'enslaving', 'say', 'marriage', 'fighting'}
# - - - - - - - - - -
# Sentence: marriage is a secular condition set up by various societies over the millenia and one of the prerequisites set out is that such a union should be between people of different genders.religion has supported this and sanctified it but did not invent it.you don't curse the church you lobby society to see if you can effect a change. people who believe the different gender aspect are entitled to lobby for no change.
# SW1: {'union', 'sanctified', 'secular', 'millenia', 'condition', 'supported', 'different', 'prerequisites', 'societies', 'marriage', 'one', 'various', 'set', 'people'}
# SW2: {'lobby', 'gender', 'believe', 'curse', 'effect', 'different', 'church', 'aspect', 'see', 'society', 'people', 'entitled', 'invent', 'change'}
# - - - - - - - - - -
# Sentence: ya know doc, it is really hard for someone to travel to a shooting sports event in another state. one would usually have to drive or go through ridiculous lengths in order to transport their firearm. i am glad to see some sanity in our laws now! although i sincerely doubt that the antis are happy about it.
# SW1: {'ya', 'travel', 'usually', 'sports', 'event', 'shooting', 'hard', 'someone', 'really', 'doc', 'one', 'state', 'another', 'know', 'would'}
# SW2: {'go', 'laws', 'happy', 'ridiculous', 'doubt', 'although', 'antis', 'sincerely', 'lengths', 'see', 'transport', 'order', 'glad', 'firearm', 'drive', 'sanity'}
# - - - - - - - - - -
# Sentence: how is that a strawman? your challenge directly relies upon something you assume to be proven, but has not been. therefore even in a hypothetical stance, your underlying arguments are invalid, thus leading to everything else being invalid. you're not doing so well on this forum.
# SW1: {'even', 'something', 'challenge', 'therefore', 'hypothetical', 'relies', 'directly', 'upon', 'assume', 'strawman', 'proven'}
# SW2: {'leading', 'else', 'invalid', 'arguments', 'well', 'everything', 'stance', 'underlying', 'forum', 'thus'}
# - - - - - - - - - -
# ...
# SW2: {'die', 'gunshot', 'many', 'accidental', 'disorder', 'drowning', 'times', 'children', 'meanwhile'}
# - - - - - - - - - -
# Sentence: the lovely thing about our system of justice, is, if a citizen acts, his actions are judged for appropriateness, and if found to be unlawful, he/she must stand in a court of law an be held accountable for them.   brady on the other hand, wants to skip all of that justice stuff, and hang us all, just because we follow the constitution and our laws, and dare to have the audacity to actually believe in both, and own a constitutionally recognized as inalienable right, gun!   so who is the law breaker here?
# SW1: {'judged', 'acts', 'lovely', 'court', 'thing', 'justice', 'hand', 'held', 'actions', 'law', 'stand', 'must', 'unlawful', 'appropriateness', 'system', 'accountable', 'citizen', 'found', 'brady'}
# SW2: {'audacity', 'actually', 'recognized', 'laws', 'us', 'justice', 'right', 'dare', 'stuff', 'gun', 'wants', 'law', 'skip', 'breaker', 'inalienable', 'follow', 'constitutionally', 'believe', 'constitution', 'hang'}
# - - - - - - - - - -
# Sentence: the stench of moral relativism is overwhelming. this terrorist act and the supporters of it should be suitably rewarded, good and hard.
# SW1: {'stench', 'terrorist', 'moral', 'overwhelming', 'relativism'}
# SW2: {'act', 'good', 'rewarded', 'hard', 'supporters', 'suitably'}
# - - - - - - - - - -
# Sentence: they do provide many more services than providing abortions :p
# SW1: {'services', 'many', 'provide'}
# SW2: {'abortions', 'p', 'providing'}
# - - - - - - - - - -
# Sentence: to the physics question: big bada boom!   to the philosophy question: i still enjoy christmas even though there's really no "sandy claws".
# SW1: {'bada', 'question', 'big', 'physics', 'philosophy', 'boom'}
# SW2: {'even', 'still', 'though', 'christmas', 'enjoy', 'really', 'sandy', 'claws'}
# - - - - - - - - - -
# Sentence: vor - you're a rude piece of ****. don't worry, i just calls them as i sees them. if it offends you, then i'm terribly sorry that i pointed out that you were a rude piece of ****.
# SW1: {'sees', 'piece', 'worry', 'vor', 'rude', 'calls'}
# SW2: {'piece', 'terribly', 'sorry', 'pointed', 'rude', 'offends'}
# - - - - - - - - - -
# Sentence:  it isn't real  so it can't be true. that  folks  is because like the creationist's bible  the darwinist academic literature is the source and well-spring of all possible truth.**big surprise  since i'm vastly outnumbered here  too. good thing that reality  truth  sanity  and rightness  are not matters of democratic vote and popularity contests. i guess. except among you darwinists  of course.**no  it has not  despite what you and your girlfriend say. and  whether it supports my pov  as i believe it does  is not the point. the point is that my pov is valid  scientific  and becoming increasingly accepted  while your darwinist boat  riddled with leaks and worm holes from day one  is finally being allowed to sink to the bottom without further plugging up and bailing out." wabbits should stick to wettuce... science is beyond their ability to digest!
# SW1: {'true', 'ca', 'outnumbered', 'good', 'darwinists', 'since', 'guess', 'except', 'surprise', 'vastly', 'among', 'despite', 'creationist', 'thing', 'rightness', 'democratic', 'academic', 'course', 'contests', 'vote', 'darwinist', 'popularity', 'real', 'source', 'reality', 'truth', 'matters', 'folks', 'possible', 'like', 'big', 'bible', 'literature', 'sanity'}
# SW2: {'day', 'ability', 'whether', 'increasingly', 'bailing', 'scientific', 'finally', 'allowed', 'wettuce', 'becoming', 'worm', 'point', 'science', 'girlfriend', 'sink', 'pov', 'one', 'holes', 'riddled', 'bottom', 'supports', 'darwinist', 'wabbits', 'accepted', 'valid', 'without', 'digest', 'plugging', 'believe', 'say', 'boat', 'stick', 'beyond', 'leaks'}
# - - - - - - - - - -
# Sentence: we've posted this excellent piece before. the anti-gay crowd (even the anti-gays who surreally style themselves as "pro-gay" -- so they can bash gays and still get into heaven...they think) never respond to it, so thoroughly does it explode all their pitiful "arguments."
# SW1: {'gays', 'even', 'crowd', 'piece', 'style', 'surreally', 'bash', 'posted', 'excellent'}
# SW2: {'never', 'still', 'explode', 'pitiful', 'thoroughly', 'arguments', 'respond', 'get', 'heaven', 'think'}
# - - - - - - - - - -
# Sentence: well its possible i suppose that god created the apple and endowed it with low levels of cyanide for the specific purpose of punishing man should he consume too many. perhaps at the time the apple being referenced was a special one much like the one in snow white.
# SW1: {'punishing', 'created', 'levels', 'cyanide', 'specific', 'endowed', 'well', 'suppose', 'low', 'possible', 'god', 'purpose', 'apple'}
# SW2: {'referenced', 'special', 'consume', 'much', 'many', 'perhaps', 'like', 'time', 'snow', 'one', 'man', 'apple', 'white'}
# - - - - - - - - - -
# Sentence: what's your evidence that the gospel prophecies are "spurious claims"? seems like you've bought into a scalding case of rational tunnel-vision (or political correctness, if you prefer).
# SW1: {'spurious', 'claims', 'gospel', 'prophecies', 'seems', 'like', 'evidence'}
# SW2: {'scalding', 'bought', 'correctness', 'rational', 'case', 'political', 'prefer'}
# - - - - - - - - - -
# Sentence: whatever. the fact that the child's faith-based position is not supported by evidence is unsurprising. or is this the "out of the mouths of babes and fools" gambit?
# SW1: {'supported', 'whatever', 'position', 'child', 'fact'}
# SW2: {'gambit', 'babes', 'mouths', 'unsurprising', 'fools', 'evidence'}
# - - - - - - - - - -
# Sentence: where better to find more info on the evolutionary migration of humanity than from friendly atheist.com. keep that pure science with no agenda coming you guys.
# SW1: {'evolutionary', 'migration', 'humanity', 'info', 'better', 'find'}
# SW2: {'agenda', 'friendly', 'coming', 'science', 'pure', 'guys', 'keep'}
# - - - - - - - - - -
# Sentence: where is the government in this? clinicians made a clinical decision, and hid behind a non-mandatory guideline, which was set by other more senior clinicians, expert in their field. assuming the woman's very detailed recall of the stressful series of events is accurate, perhaps it was god's way of telling this unmarried mother that after five previous miscarriages, she still wasn't getting the message.
# SW1: {'behind', 'clinical', 'decision', 'assuming', 'expert', 'field', 'senior', 'hid', 'woman', 'guideline', 'made', 'set', 'clinicians', 'government', 'detailed'}
# SW2: {'getting', 'unmarried', 'still', 'miscarriages', 'accurate', 'events', 'perhaps', 'telling', 'way', 'previous', 'message', 'series', 'god', 'stressful', 'five', 'recall', 'mother'}
# - - - - - - - - - -
# Sentence: which ones? ineffective how?   i'd guess the laws weren't struck down simply because too many people broke them.
# SW1: {'guess', 'laws', 'ones', 'ineffective'}
# SW2: {'struck', 'many', 'broke', 'simply', 'people'}
# - - - - - - - - - -
# Sentence: why?   if the government made a law tomorrow that declared all brain surgeons would now be making the average wages of a high school janitor, how many brain surgeons do you think would continue their practice?
# SW1: {'tomorrow', 'average', 'making', 'declared', 'surgeons', 'brain', 'law', 'made', 'would', 'government'}
# SW2: {'continue', 'janitor', 'school', 'surgeons', 'many', 'brain', 'practice', 'think', 'wages', 'would', 'high'}
# - - - - - - - - - -
# Sentence:  nonsense and lies that bertvan spewed is it that you want me to elaborate on?or did you want me to elaborate on some of the falsehoods and lies of yours that i have challenged? are you actually up to dealing with challenges to your spewed falsehoods  or will you run from that?" yes, all of that. prove it has any basis in fact and that berts claims cannot be true. talk and attacks are cheap but proof of anything substantial and real is few and far between by you. i'll see you uh, never? because all of the ridiculous assertions and claims you make are unprovable by any reasonable standard.
# SW1: {'run', 'spewed', 'basis', 'nonsense', 'prove', 'bertvan', 'elaborate', 'want', 'falsehoods', 'yes', 'actually', 'challenges', 'lies', 'dealing', 'fact', 'challenged'}
# SW2: {'true', 'ridiculous', 'standard', 'substantial', 'assertions', 'far', 'proof', 'cheap', 'anything', 'unprovable', 'attacks', 'reasonable', 'make', 'never', 'berts', 'real', 'see', 'uh', 'claims', 'talk'}
# - - - - - - - - - -
# Sentence: yeah, lets tax those rich greedy jerks!!! i mean really, why be equal when you want something for free right??? screw freedom i want my healthcare!!!
# SW1: {'lets', 'tax', 'greedy', 'mean', 'jerks', 'really', 'rich', 'yeah'}
# SW2: {'equal', 'screw', 'something', 'right', 'want', 'free', 'freedom', 'healthcare'}
# - - - - - - - - - -
# Sentence: yeah. it's snowing sooner here in the midwest. i think the next ice age is coming.
# SW1: {'sooner', 'yeah', 'snowing', 'midwest'}
# SW2: {'coming', 'next', 'ice', 'age', 'think'}
# - - - - - - - - - -
# Sentence: you don't see protesters walking around going "i wanna marry my dog" or "beastiality rocks" do you?!
# SW1: {'going', 'protesters', 'see', 'walking', 'around'}
# SW2: {'beastiality', 'na', 'marry', 'dog', 'rocks', 'wan'}
# - - - - - - - - - -
# Sentence: you draw very interesting conclusions my friend.   if this is your standpoint then what is the purpose of a government?
# SW1: {'conclusions', 'interesting', 'draw'}
# SW2: {'purpose', 'standpoint', 'friend', 'government'}
# - - - - - - - - - -
# Sentence: you haven't posted a challenge yet. including this post.   would i fit the bill?   sure, but about what? what's your resolution?   for instance, you might say "resolved: creation and evolution are equally valid interpretations of empirical evidence".   now, personally i'd say that's still too vague because 'creation' drags in all kinds of issues that evolution doesn't speak to (eg abiogenesis, cosmology etc), and 'evolution' could mean common descent, the theory of evolution, etc etc.   so we might kick the idea around for a bit and narrow it down to "resolved: hypotheses of special creation of species and common descent are equally well supported by empirical evidence".   or, perhaps it's the age of the earth you want to focus on: "resolved: all available evidence is consistent with a 6-10,000 year old earth"   i can't do this for you, feindslayer; make up your mind and present a proper challenge.
# SW1: {'fit', 'evolution', 'theory', 'could', 'instance', 'mean', 'resolution', 'would', 'sure', 'eg', 'descent', 'challenge', 'cosmology', 'posted', 'including', 'resolved', 'speak', 'might', 'bill', 'kinds', 'personally', 'abiogenesis', 'common', 'equally', 'etc', 'empirical', 'valid', 'interpretations', 'drags', 'post', 'still', 'issues', 'say', 'evidence', 'vague', 'creation', 'yet'}
# SW2: {'special', 'evolution', 'ca', 'supported', 'consistent', 'mind', 'old', 'kick', 'narrow', 'descent', 'challenge', 'year', 'feindslayer', 'hypotheses', 'make', 'resolved', 'focus', 'might', 'species', 'common', 'want', 'equally', 'etc', 'empirical', 'around', 'present', 'age', 'proper', 'available', 'idea', 'bit', 'well', 'perhaps', 'evidence', 'earth', 'creation'}
# - - - - - - - - - -
# Sentence: you mean you are as biologically ignorant and as easily refuted as the thread originator? yes, we knew that already. why all the big letters?
# SW1: {'easily', 'biologically', 'refuted', 'thread', 'mean', 'ignorant'}
# SW2: {'already', 'letters', 'knew', 'yes', 'big', 'originator'}
# - - - - - - - - - -
# Sentence: you will soon learn, my friend, that fundies have very, very short memories when it comes to refutations of their arguments...
# SW1: {'soon', 'learn', 'fundies', 'friend'}
# SW2: {'short', 'comes', 'memories', 'arguments', 'refutations'}
# - - - - - - - - - -
# Sentence: you're right, why not simply kill these people in the shortest amount of time possible. i got it! we can advertise each killing (hanging, rock slaying, guillotine, etc.) weeks in advance, kinda like moves, and show it on pay-per-view. you can buy tickets to watch the show live as well. i mean c'mon, if we're going to have the death penalty we might as well utilize in the most gruesome, cost efficient, and swift method possible. right? that is how punishment was executed a few centuries ago.   honestly, how you feel is how a lot of people culturally conceive such offenders. in regards to the death penalty debate, it falls along a continuum between morality and scientific reasoning.
# SW1: {'going', 'show', 'moves', 'mean', 'weeks', 'advertise', 'simply', 'slaying', 'tickets', 'killing', 'time', 'kill', 'got', 'people', 'buy', 'advance', 'right', 'hanging', 'live', 'shortest', 'rock', 'etc', 'death', 'amount', 'guillotine', 'well', 'watch', 'possible', 'like', 'kinda'}
# SW2: {'executed', 'gruesome', 'cost', 'ago', 'centuries', 'punishment', 'culturally', 'scientific', 'method', 'efficient', 'regards', 'people', 'continuum', 'along', 'swift', 'lot', 'right', 'honestly', 'might', 'utilize', 'debate', 'conceive', 'offenders', 'death', 'reasoning', 'feel', 'morality', 'well', 'falls', 'possible', 'penalty'}
# - - - - - - - - - -
# Sentence: you're the one who needs to get a grip. lots could get worse, but not for the reasons you're stating.   but i take it you're finally admitting that (actually) 50 million uninsured human beings who could die or go bankrupt is a big problem.
# SW1: {'needs', 'reasons', 'take', 'lots', 'worse', 'grip', 'could', 'one', 'get', 'stating', 'finally'}
# SW2: {'go', 'uninsured', 'problem', 'die', 'human', 'bankrupt', 'beings', 'actually', 'million', 'could', 'big', 'admitting'}
# - - - - - - - - - -
# Sentence:  as their having guns doesn't serve the state.\"--heinrich himmlerfor pledging their support of nazi ideals  we proudly award \"yes\" the medal of holocaust and genocide. congratulations  you're now a supporter of hitler." and you win the pink panties award!i got news for you punk - my family fled the nazi's on foot in wwii
# SW1: {'himmlerfor', 'ideals', 'genocide', 'serve', 'support', 'congratulations', 'holocaust', 'proudly', 'guns', 'pledging', 'nazi', 'award', 'heinrich', 'medal'}
# SW2: {'punk', 'wwii', 'win', 'family', 'panties', 'pink', 'fled', 'foot', 'hitler', 'nazi', 'got', 'award', 'news', 'supporter'}
# - - - - - - - - - -
# Sentence: depends on when the baby bird died.   run along little boy..let the adults debate.
# SW1: {'baby', 'run', 'bird', 'died', 'depends'}
# SW2: {'along', 'boy', 'adults', 'little', 'debate', 'let'}
# - - - - - - - - - -
# Sentence: ok, sheesh, to clarify, women who arent aborting their babys are pregnant more oftan than not, the women who are having abortons have to have them several times a year.
# SW1: {'babys', 'sheesh', 'aborting', 'arent', 'women', 'clarify', 'ok'}
# SW2: {'year', 'women', 'times', 'pregnant', 'several', 'oftan', 'abortons'}
# - - - - - - - - - -
# Sentence: so..   eh??   hows this sound?   will it fly with conservatives and progressives?   i think so.   -mosheh thezion
# SW1: {'sound', 'hows', 'fly', 'eh'}
# SW2: {'conservatives', 'thezion', 'progressives', 'think'}
# - - - - - - - - - -
# Sentence: i think we should put to a vote, the right of the religious extremists, to vote at all. what say ye?   if the majority agrees, they have no say in anything anymore. isn't that the way steeeeeve says it should be done? put it to a vote?
# SW1: {'majority', 'vote', 'right', 'put', 'extremists', 'say', 'ye', 'religious', 'think'}
# SW2: {'anything', 'vote', 'steeeeeve', 'put', 'say', 'way', 'anymore', 'says', 'agrees', 'done'}
# - - - - - - - - - -
# Sentence: you have a blob of tissue in your "but(sic)"? sorry dude, that has to suck.   perhaps you're really referring to hemorrhoids? you do know that those aren't really blobs of tissue, right? they're really the swelling and inflammation of veins.
# SW1: {'dude', 'referring', 'perhaps', 'sorry', 'tissue', 'really', 'sic', 'suck', 'blob'}
# SW2: {'hemorrhoids', 'right', 'veins', 'swelling', 'blobs', 'inflammation', 'tissue', 'really', 'know'}
# - - - - - - - - - -

# %%
df["SW1"] = all_SW1
df["SW2"] = all_SW2
df
# Out:
#         class                                               text  \
# 0     notsarc  If that's true, then Freedom of Speech is doom...
# 1     notsarc  Neener neener - is it time to go in from the p...
# 2     notsarc  Just like the plastic gun fear, the armour pie...
# 3     notsarc  So geology is a religion because we weren't he...
# 4     notsarc  Well done Monty. Mark that up as your first ev...
# ...       ...                                                ...
# 6515     sarc  depends on when the baby bird died.   run alon...
# 6516     sarc  ok, sheesh, to clarify, women who arent aborti...
# 6517     sarc  so..   eh??   hows this sound?   will it fly w...
# 6518     sarc  I think we should put to a vote, the right of ...
# 6519     sarc  You have a blob of tissue in your "but(sic)"? ...
#
#                                     PW  \
# 0          {freedom, true, subjective}
# 1                         {playground}
# 2                                   {}
# 3             {rock, religion, formed}
# 4                   {honest, accurate}
# ...                                ...
# 6515               {bird, baby, adult}
# 6516               {baby, clarify, ok}
# 6517  {fly, conservative, progressive}
# 6518                        {majority}
# 6519          {swelling, tissue, vein}
#
#                                                  NW  \
# 0                              {harassment, doomed}
# 1                                                {}
# 2             {fear, myth, misinformation, plastic}
# 3                                         {geology}
# 4                                                {}
# ...                                             ...
# 6515                                         {died}
# 6516                             {pregnant, sheesh}
# 6517                                             {}
# 6518                                    {extremist}
# 6519  {inflammation, hemorrhoid, sorry, suck, blob}
#
#                                                     SW1  \
# 0           {true, speech, harassment, doomed, freedom}
# 1                                        {neener, time}
# 2          {armour, piercing, gun, fear, like, plastic}
# 3                              {see, geology, religion}
# 4                             {monty, well, done, mark}
# ...                                                 ...
# 6515                   {baby, run, bird, died, depends}
# 6516  {babys, sheesh, aborting, arent, women, clarif...
# 6517                             {sound, hows, fly, eh}
# 6518  {majority, vote, right, put, extremists, say, ...
# 6519  {dude, referring, perhaps, sorry, tissue, real...
#
#                                                     SW2
# 0     {subjective, book, like, claim, harassing, ban...
# 1                                 {go, playground, yet}
# 2     {bullet, built, upon, fear, myth, misinformation}
# 3                                     {rock, x, formed}
# 4                 {post, accurate, honest, ever, first}
# ...                                                 ...
# 6515          {along, boy, adults, little, debate, let}
# 6516  {year, women, times, pregnant, several, oftan,...
# 6517      {conservatives, thezion, progressives, think}
# 6518  {anything, vote, steeeeeve, put, say, way, any...
# 6519  {hemorrhoids, right, veins, swelling, blobs, i...
#
# [6520 rows x 6 columns]

# %% [markdown]
# ## 3)
# "Here, 𝑃𝑊 ∪ 𝑆𝑊1 and 𝑁𝑊 ∪ 𝑆𝑊2 are used to mask original sentence respectively. So, we will obtain two masked sentences
# 𝑥𝑚1 = { [𝑚]1, 𝑥2, ..., [𝑚]𝑛} and
# 𝑥𝑚2 = {𝑥1, [𝑚]2, ..., 𝑥𝑛}."

# %%
def construct_union(sentences, PW, NW, all_SW1, all_SW2):
    union_PW_SW1 = []
    union_NW_SW2 = []

    for i, sentence in enumerate(sentences):
        SW1 = all_SW1[i]
        SW2 = all_SW2[i]

        union_PW_SW1.append(PW[i].union(SW1))
        union_NW_SW2.append(NW[i].union(SW2))

    return union_PW_SW1, union_NW_SW2

# %%
union_PW_SW1, union_NW_SW2 = construct_union(text_data, positive_words, negative_words, all_SW1, all_SW2)
print(union_PW_SW1)
print(union_NW_SW2)
# Out:
# [{'true', 'speech', 'subjective', 'harassment', 'doomed', 'freedom'}, {'playground', 'neener', 'time'}, {'armour', 'piercing', 'fear', 'like', 'plastic', 'gun'}, {'rock', 'formed', 'see', 'religion', 'geology'}, {'well', 'monty', 'honest', 'mark', 'accurate', 'done'}, {'majority', 'laws', 'job', 'decide', 'constitution', 'using', 'process', 'whole', 'check', 'clear', 'set', 'done', 'courts'}, {'financially', 'would', 'penalize'}, {'baby', 'non', 'existent', 'realize', 'imaginary', 'iow', 'us', 'doe', 'intelligent', 'wow', 'saying', 'enough'}, {'evolution', 'prove', 'referring', 'mexican', 'extinction', 'create', 'doe', 'mass', 'work', 'order', 'described', 'basin', 'example', 'effectively', 'effect', 'crater', 'flood', 'probably', 'besides', 'bible', 'asteroid'}, {'matters', 'something', 'year', 'agree', 'science', 'atheism', 'discovers', 'seems', 'tell'}, {'leaf', 'front'}, {'really', 'please', 'know', 'talking', 'thanks', 'think', 'provide'}, {'human'}, {'likely', 'would'}, {'incredible', 'crowd', 
ars', 'use', 'work'}, {'beliefs', 'set', 'pagans', 'pagan', 'many', 'heathen', 'though', 'particular', 'know'}, {'scenes', 'take', 'mean', 'nativity'}, {'henceforth', 'unwilling', 'right', 'obviously', 'vindicated', 'thread', 'show', 'chihuahua', 'ignoring', 'refer', 'somebody', 'done', 'clearly', 'run', 'nothing', 'challenge', 'everything', 'evidence', 'claiming', 'unable', 'supposedly'}, {'day', 'lot', 'middle', 'specific', 'single', 'every', 'kind', 'busy', 'trained', 'deal', 'parking'}, {'against', 'vendors', 'killed', 'hangings', 'rope'}, {'appear', 'magic', 'knowing', 'created', 'unknowable', 'poofed', 'everything', 'existance', 'evidence', 'make'}, {'saving', 'lives', 'childrens', 'guns', 'decide'}, {'going', 'function', 'bla', 'oh', 'tortured', 'pain', 'death', 'tend', 'think', 'always', 'go', 'baby', 'cmon', 'disturb', 'nervous', 'mother'}, {'rate', 'victim', 'alright', 'helpless', 'arguing', 'anything', 'acceptable', 'many', 'level', 'crime', 'unable', 'people', 'dangerous'}, {'taught', 'nonsense', 'doubt', 'school', 'class', 'covered', 'hole', 'biology', 'time',  ...

# %%
df["union_PW_SW1"] = union_PW_SW1
df["union_NW_SW2"] = union_NW_SW2
df
# Out:
#         class                                               text  \
# 0     notsarc  If that's true, then Freedom of Speech is doom...
# 1     notsarc  Neener neener - is it time to go in from the p...
# 2     notsarc  Just like the plastic gun fear, the armour pie...
# 3     notsarc  So geology is a religion because we weren't he...
# 4     notsarc  Well done Monty. Mark that up as your first ev...
# ...       ...                                                ...
# 6515     sarc  depends on when the baby bird died.   run alon...
# 6516     sarc  ok, sheesh, to clarify, women who arent aborti...
# 6517     sarc  so..   eh??   hows this sound?   will it fly w...
# 6518     sarc  I think we should put to a vote, the right of ...
# 6519     sarc  You have a blob of tissue in your "but(sic)"? ...
#
#                                     PW  \
# 0          {freedom, true, subjective}
# 1                         {playground}
# 2                                   {}
# 3             {rock, religion, formed}
# 4                   {honest, accurate}
# ...                                ...
# 6515               {bird, baby, adult}
# 6516               {baby, clarify, ok}
# 6517  {fly, conservative, progressive}
# 6518                        {majority}
# 6519          {swelling, tissue, vein}
#
#                                                  NW  \
# 0                              {harassment, doomed}
# 1                                                {}
# 2             {fear, myth, misinformation, plastic}
# 3                                         {geology}
# 4                                                {}
# ...                                             ...
# 6515                                         {died}
# 6516                             {pregnant, sheesh}
# 6517                                             {}
# 6518                                    {extremist}
# 6519  {inflammation, hemorrhoid, sorry, suck, blob}
#
#                                                     SW1  \
# 0           {true, speech, harassment, doomed, freedom}
# 1                                        {neener, time}
# 2          {armour, piercing, gun, fear, like, plastic}
# 3                              {see, geology, religion}
# 4                             {monty, well, done, mark}
# ...                                                 ...
# 6515                   {baby, run, bird, died, depends}
# 6516  {babys, sheesh, aborting, arent, women, clarif...
# 6517                             {sound, hows, fly, eh}
# 6518  {majority, vote, right, put, extremists, say, ...
# 6519  {dude, referring, perhaps, sorry, tissue, real...
#
#                                                     SW2  \
# 0     {subjective, book, like, claim, harassing, ban...
# 1                                 {go, playground, yet}
# 2     {bullet, built, upon, fear, myth, misinformation}
# 3                                     {rock, x, formed}
# 4                 {post, accurate, honest, ever, first}
# ...                                                 ...
# 6515          {along, boy, adults, little, debate, let}
# 6516  {year, women, times, pregnant, several, oftan,...
# 6517      {conservatives, thezion, progressives, think}
# 6518  {anything, vote, steeeeeve, put, say, way, any...
# 6519  {hemorrhoids, right, veins, swelling, blobs, i...
#
#                                            union_PW_SW1  \
# 0     {true, speech, subjective, harassment, doomed,...
# 1                            {playground, neener, time}
# 2          {armour, piercing, fear, like, plastic, gun}
# 3                {rock, formed, see, religion, geology}
# 4           {well, monty, honest, mark, accurate, done}
# ...                                                 ...
# 6515            {baby, run, adult, bird, died, depends}
# 6516  {baby, babys, sheesh, aborting, arent, women, ...
# 6517  {sound, conservative, progressive, fly, hows, eh}
# 6518  {majority, religious, vote, right, put, say, y...
# 6519  {dude, referring, perhaps, swelling, sorry, ti...
#
#                                            union_NW_SW2
# 0     {subjective, book, like, harassment, doomed, c...
# 1                                 {go, playground, yet}
# 2     {bullet, built, upon, fear, myth, plastic, mis...
# 3                            {rock, x, geology, formed}
# 4                 {honest, post, ever, first, accurate}
# ...                                                 ...
# 6515    {died, along, adults, little, debate, boy, let}
# 6516  {year, sheesh, women, times, pregnant, several...
# 6517      {conservatives, thezion, progressives, think}
# 6518  {anything, vote, steeeeeve, put, say, way, any...
# 6519  {hemorrhoids, right, veins, inflammation, hemo...
#
# [6520 rows x 8 columns]

# %%
def mask_sentence(sentence, mask_words, max_mask_count = 5):
    masked_sentence = []

    for word in sentence.split():
        if word in mask_words and max_mask_count > 0:
            masked_sentence.append("<mask>")
            max_mask_count -= 1
        else:
            masked_sentence.append(word)

    return " ".join(masked_sentence)

# %%
def construct_masked_sentences(sentences, union_PW_SW1, union_NW_SW2):
    masked_pos_sentences = []
    masked_neg_sentences = []

    for i, sentence in enumerate(sentences):

        masked_pos_sentence = mask_sentence(sentence, union_PW_SW1[i])
        masked_pos_sentences.append(masked_pos_sentence)

        masked_neg_sentence = mask_sentence(sentence, union_NW_SW2[i])
        masked_neg_sentences.append(masked_neg_sentence)

    return masked_pos_sentences, masked_neg_sentences

# %%
masked_pos_sentences, masked_neg_sentences = construct_masked_sentences(text_data, union_PW_SW1, union_NW_SW2)

for i, sentence in enumerate(text_data):
    print(f"Original Sentence: {sentence}")
    print(f"Masked Positive Sentence: {masked_pos_sentences[i]}")
    print(f"Masked Negative Sentence: {masked_neg_sentences[i]}")
    print("- - - - - - - - - -")
# Out:
# Streaming output truncated to the last 5000 lines.
# Masked Negative Sentence: i think her point was that the <mask> is <mask> because he's catholic.
# - - - - - - - - - -
# Original Sentence: yet according to pp themselves, they provide far more abortions and ec services than any of their other services. :pppfa services (2002-2003)surgical abortions: 227,385 emergency contraception: 633,756 prenatal care: 15,860 adoption referrals: 1,963 (source: www.plannedparenthood.org)
# Masked Positive Sentence: <mask> <mask> to <mask> themselves, they <mask> <mask> more abortions and ec services than any of their other services. :pppfa services (2002-2003)surgical abortions: 227,385 emergency contraception: 633,756 prenatal care: 15,860 adoption referrals: 1,963 (source: www.plannedparenthood.org)
# Masked Negative Sentence: yet according to pp themselves, they provide far more <mask> and ec <mask> than any of their other services. :pppfa <mask> (2002-2003)surgical abortions: 227,385 <mask> contraception: 633,756 <mask> care: 15,860 adoption referrals: 1,963 (source: www.plannedparenthood.org)
# - - - - - - - - - -
# Original Sentence: well, if burglars want to steal guns then it makes sense that they would be likely to target the homes of gun owners. and the source is from the recently published book evaluating gun policy which you can read and review. the source is listed at the bottom.
# Masked Positive Sentence: well, if <mask> <mask> to <mask> <mask> then it <mask> sense that they would be likely to target the homes of gun owners. and the source is from the recently published book evaluating gun policy which you can read and review. the source is listed at the bottom.
# Masked Negative Sentence: well, if burglars want to <mask> guns then it makes sense that they would be likely to <mask> the homes of <mask> owners. and the <mask> is from the <mask> published book evaluating gun policy which you can read and review. the source is listed at the bottom.
# - - - - - - - - - -
# Original Sentence: but the fact remains that guns are, by design, weapons.
# Masked Positive Sentence: but the <mask> <mask> that guns are, by design, weapons.
# Masked Negative Sentence: but the fact remains that <mask> are, by design, weapons.
# - - - - - - - - - -
# Original Sentence: no it doesn't!it cost way more money in appeals than it does to excute someone. we the taxpayers pay for legal represenatation for them and us, plus the cost of keeping them in jail. the appelas process alone costs the tax payers millions.it is far more expensive to kill them than to leave them in jail with no chance of parole.
# Masked Positive Sentence: no it doesn't!it <mask> <mask> more <mask> in <mask> than it does to <mask> someone. we the taxpayers pay for legal represenatation for them and us, plus the cost of keeping them in jail. the appelas process alone costs the tax payers millions.it is far more expensive to kill them than to leave them in jail with no chance of parole.
# Masked Negative Sentence: no it doesn't!it <mask> way more money in appeals than it does to excute someone. we the taxpayers pay for legal represenatation for them and us, plus the <mask> of keeping them in jail. the <mask> <mask> <mask> costs the tax payers millions.it is far more expensive to kill them than to leave them in jail with no chance of parole.
# - - - - - - - - - -
# Original Sentence: again, true. but that doesn't take into account that there are two populations under consideration.
# Masked Positive Sentence: again, true. but that doesn't <mask> into <mask> that there are two populations under consideration.
# Masked Negative Sentence: again, true. but that doesn't take into account that there are <mask> <mask> under consideration.
# - - - - - - - - - -
# Original Sentence: evolution doesn't explain the event. the event is an example of evolution - a change in the frequency of alleles in a populatioin over time. the explanation may or may not be evolution by natural selection. you merely asserted that based on your imagined case.
# Masked Positive Sentence: <mask> doesn't <mask> the event. the <mask> is an <mask> of <mask> - a change in the frequency of alleles in a populatioin over time. the explanation may or may not be evolution by natural selection. you merely asserted that based on your imagined case.
# Masked Negative Sentence: <mask> doesn't explain the event. the event is an example of <mask> - a change in the frequency of alleles in a populatioin over time. the <mask> <mask> or <mask> not be evolution by natural selection. you merely asserted that based on your imagined case.
# - - - - - - - - - -
# Original Sentence: but then, you are obviously scientifically illiterate. why don't you think that the panal of scientists who were hired to write the standards know better than you? it is, after all, their field.
# Masked Positive Sentence: but then, you are <mask> <mask> illiterate. why don't you <mask> that the <mask> of <mask> who were hired to write the standards know better than you? it is, after all, their field.
# Masked Negative Sentence: but then, you are obviously scientifically illiterate. why don't you think that the panal of scientists who were <mask> to <mask> the <mask> <mask> <mask> than you? it is, after all, their field.
# - - - - - - - - - -
# Original Sentence: i'm sorry, but that's not what my version said."no one who has been emasculated by crushing or cutting may enter the assembly of the lord ." emasculated = castrated emasculation was not an accident. (what this verse has to do with the death penalty is beyond me.)
# Masked Positive Sentence: i'm sorry, but that's not what my <mask> said."no <mask> who has been <mask> by <mask> or <mask> may enter the assembly of the lord ." emasculated = castrated emasculation was not an accident. (what this verse has to do with the death penalty is beyond me.)
# Masked Negative Sentence: i'm sorry, but that's not what my version said."no one who has been <mask> by <mask> or cutting may enter the <mask> of the <mask> ." <mask> = castrated emasculation was not an accident. (what this verse has to do with the death penalty is beyond me.)
# - - - - - - - - - -
# Original Sentence: well be cynical if you want, if someone in your family had done as you ascribed you wouldn't be here to be so glib. nor would the human race or any other species where penile-vaginal sex takes place. i guess all those years of biological reproduction show it. you will also notice i didn't make it an absolute statement. i said "minimal or negligable physical damage".i understand that female biology undergoes truama too during sex, the fact is the trauma of vaginal sex i.....1. more forgiving and 2. obviously possible of greater/important final result. and um, like with lesbian activities, the size of the "peg" also matters so how do you know lesbian activities are a lot less harmful.
# Masked Positive Sentence: <mask> be <mask> if you want, if <mask> in your <mask> had <mask> as you ascribed you wouldn't be here to be so glib. nor would the human race or any other species where penile-vaginal sex takes place. i guess all those years of biological reproduction show it. you will also notice i didn't make it an absolute statement. i said "minimal or negligable physical damage".i understand that female biology undergoes truama too during sex, the fact is the trauma of vaginal sex i.....1. more forgiving and 2. obviously possible of greater/important final result. and um, like with lesbian activities, the size of the "peg" also matters so how do you know lesbian activities are a lot less harmful.
# Masked Negative Sentence: well be <mask> if you want, if someone in your family had done as you ascribed you wouldn't be here to be so glib. nor would the human race or any other species where penile-vaginal <mask> takes place. i guess all those years of biological reproduction show it. you will <mask> notice i didn't make it an absolute statement. i said "minimal or negligable physical damage".i <mask> that <mask> biology undergoes truama too during sex, the fact is the trauma of vaginal sex i.....1. more forgiving and 2. obviously possible of greater/important final result. and um, like with lesbian activities, the size of the "peg" also matters so how do you know lesbian activities are a lot less harmful.
# - - - - - - - - - -
# Original Sentence: i think you are entirely correct. from the page vor linked:
# Masked Positive Sentence: i <mask> you are <mask> correct. from the page vor linked:
# Masked Negative Sentence: i think you are entirely correct. from the <mask> <mask> linked:
# - - - - - - - - - -
# Original Sentence: why don't we do the same for straight marriages then?why doesn't a straight couple that gets married in colorado, and then moves to virginia, have to get their divorce "remotely" from virginia.or maybe you should start thinking about what authority colorado has to grant a divorce to virginian residents.
# Masked Positive Sentence: why don't we do the same for <mask> <mask> then?why doesn't a <mask> <mask> that <mask> married in colorado, and then moves to virginia, have to get their divorce "remotely" from virginia.or maybe you should start thinking about what authority colorado has to grant a divorce to virginian residents.
# Masked Negative Sentence: why don't we do the same for straight marriages then?why doesn't a straight couple that gets married in colorado, and then moves to virginia, have to get their <mask> "remotely" from virginia.or <mask> you should <mask> <mask> about what <mask> colorado has to grant a divorce to virginian residents.
# - - - - - - - - - -
# Original Sentence: actually, it hasn't. phylogenetic analysis has no relevance to occam's razor. further, dna for all organisms is the same until you examine specific sequences. it isn't that the dna is different, what matters is the the sequence of the bases is different.
# Masked Positive Sentence: actually, it hasn't. <mask> <mask> has no <mask> to occam's razor. further, <mask> for all <mask> is the same until you examine specific sequences. it isn't that the dna is different, what matters is the the sequence of the bases is different.
# Masked Negative Sentence: actually, it hasn't. <mask> analysis has no relevance to occam's razor. further, <mask> for all organisms is the same until you <mask> <mask> sequences. it isn't that the <mask> is different, what matters is the the sequence of the bases is different.
# - - - - - - - - - -
# Original Sentence: and he has still yet to provide one. if more gun-control means more lives saved then more gun-control means more self preservation.
# Masked Positive Sentence: and he has <mask> <mask> to <mask> one. if more gun-control <mask> more lives saved then more gun-control <mask> more self preservation.
# Masked Negative Sentence: and he has still yet to provide one. if more gun-control <mask> more <mask> <mask> then more gun-control <mask> more <mask> preservation.
# - - - - - - - - - -
# Original Sentence: the purpose of the bill of rights.
# preamble to the bill of rights
# Masked Positive Sentence: the <mask> of the <mask> of rights. <mask> to the <mask> of <mask>
# Masked Negative Sentence: the purpose of the <mask> of rights. <mask> to the <mask> of <mask>
# - - - - - - - - - -
# Original Sentence: i dunno... we already have enough fundies thinking that the big bang is part of evolution...
# Masked Positive Sentence: i dunno... we <mask> have <mask> <mask> thinking that the <mask> <mask> is part of evolution...
# Masked Negative Sentence: i dunno... we already have enough fundies <mask> that the <mask> <mask> is <mask> of evolution...
# - - - - - - - - - -
# Original Sentence: i see. then you are attempting to define evolution out of existance. by your definition (not that of evolutionary biologists) evolution requires an increase in information. an unsupported creationist argument. define information in a meaningful way. please apply your definition to genetics and show why all genetic changes are a decrease in information.
# Masked Positive Sentence: i see. then you are <mask> to <mask> <mask> out of existance. by your <mask> (not that of <mask> biologists) evolution requires an increase in information. an unsupported creationist argument. define information in a meaningful way. please apply your definition to genetics and show why all genetic changes are a decrease in information.
# Masked Negative Sentence: i see. then you are attempting to <mask> evolution out of existance. by your <mask> (not that of evolutionary biologists) evolution requires an increase in information. an <mask> <mask> argument. <mask> information in a meaningful way. please apply your definition to genetics and show why all genetic changes are a decrease in information.
# - - - - - - - - - -
# Original Sentence: sounds like a fact which has been blown out of all proportion - possibly by the pro-gun side attempting to ridicule it. it is a fact, however, that the presence of a gun can increase aggression levels in individuals.see other times i have brought this up, here (to the end of the thread) and here (again, that post till the end of the thread).
# Masked Positive Sentence: <mask> <mask> a <mask> which has been <mask> out of all <mask> - possibly by the pro-gun side attempting to ridicule it. it is a fact, however, that the presence of a gun can increase aggression levels in individuals.see other times i have brought this up, here (to the end of the thread) and here (again, that post till the end of the thread).
# Masked Negative Sentence: sounds like a fact which has been blown out of all proportion - possibly by the pro-gun side attempting to <mask> it. it is a fact, however, that the presence of a <mask> can <mask> <mask> <mask> in individuals.see other times i have brought this up, here (to the end of the thread) and here (again, that post till the end of the thread).
# - - - - - - - - - -
# Original Sentence: and if we can actually doing anything about it. from what i hear on the fringes, the debate should not be about how to change or stop it, but how to change to deal with it and what we should expect as society adapts to a change in climate.
# Masked Positive Sentence: and if we can <mask> doing <mask> about it. from what i <mask> on the fringes, the <mask> should not be about how to <mask> or stop it, but how to change to deal with it and what we should expect as society adapts to a change in climate.
# Masked Negative Sentence: and if we can actually doing anything about it. from what i hear on the fringes, the debate should not be about how to <mask> or <mask> it, but how to <mask> to <mask> with it and what we should <mask> as society adapts to a change in climate.
# - - - - - - - - - -
# Original Sentence: what else would you expect from the people who created a god in their own image?
#
#  your thinking here is right, religion has a long history of being egocentric.
# Masked Positive Sentence: what <mask> <mask> you <mask> from the <mask> who <mask> a god in their own image? your thinking here is right, religion has a long history of being egocentric.
# Masked Negative Sentence: what else would you expect from the people who created a god in their own image? your <mask> here is right, <mask> has a <mask> <mask> of being egocentric.
# - - - - - - - - - -
# Original Sentence: well, first, i did say "the fact that you and i cannot understand this doesn't make it impossible." secondly, how is no god possible? third, a person being 100% something and 100% something else isn't entirely impossible. there are people all over the world who change from 100% idiotic to 100% non-idiotic all the time. lastly, there are many things we don't understand... so what's your point in restating what i said?
# Masked Positive Sentence: well, first, i did <mask> "the <mask> that you and i cannot <mask> this doesn't <mask> it impossible." secondly, how is no <mask> possible? third, a person being 100% something and 100% something else isn't entirely impossible. there are people all over the world who change from 100% idiotic to 100% non-idiotic all the time. lastly, there are many things we don't understand... so what's your point in restating what i said?
# Masked Negative Sentence: well, first, i did say "the fact that you and i cannot <mask> this doesn't make it impossible." secondly, how is no god possible? third, a person being 100% something and 100% something <mask> isn't <mask> impossible. there are <mask> all over the <mask> who change from 100% idiotic to 100% non-idiotic all the time. lastly, there are many things we don't understand... so what's your point in restating what i said?
# - - - - - - - - - -
# Original Sentence: bet the crime rate skyrockets,but i wonder what happens if you (officers)just
#  put a bullet in them, you know for resisting arrest?
#
#  who does that pinhead mayor remind you of?emoticon_rolleyes
# Masked Positive Sentence: <mask> the <mask> <mask> skyrockets,but i <mask> what <mask> if you (officers)just put a bullet in them, you know for resisting arrest? who does that pinhead mayor remind you of?emoticon_rolleyes
# Masked Negative Sentence: bet the <mask> <mask> skyrockets,but i wonder what happens if you (officers)just <mask> a <mask> in them, you <mask> for resisting arrest? who does that pinhead mayor remind you of?emoticon_rolleyes
# - - - - - - - - - -
# Original Sentence: that is what supersport is hoping to do... however, assuming that you are correct in your interpretation, he has no chance of doing it so well.
# Masked Positive Sentence: that is what <mask> is <mask> to do... however, <mask> that you are correct in your interpretation, he has no <mask> of doing it so well.
# Masked Negative Sentence: that is what supersport is hoping to do... however, assuming that you are <mask> in your interpretation, he has no <mask> of doing it so well.
# - - - - - - - - - -
# Original Sentence: yes, to follow his commandments to love god and to love one another.
# Masked Positive Sentence: yes, to <mask> his <mask> to <mask> god and to <mask> one another.
# Masked Negative Sentence: yes, to follow his commandments to <mask> <mask> and to <mask> <mask> another.
# - - - - - - - - - -
# Original Sentence: you have a habit of constantly posting statements by anti-gun officials. and when these statements and theories are called into question and challenged, you have nothing to post in defense.
# Masked Positive Sentence: you have a <mask> of <mask> <mask> <mask> by anti-gun officials. and when these <mask> and theories are called into question and challenged, you have nothing to post in defense.
# Masked Negative Sentence: you have a <mask> of <mask> posting statements by anti-gun officials. and when these statements and <mask> are <mask> into <mask> and challenged, you have nothing to post in defense.
# - - - - - - - - - -
# Original Sentence: agreed that they are still the same species, much like the "13 species" of darwin's finches, and i have no problem with evolution in that respect. i can even see the plausibility of different subspecies evolving eventually into different species if they are geographically separated for a sufficiently long time. but i still don't see where evolution, in that sense of the term, can account for dozens of species of monkeys occupying the same patch of rainforest, or dozens of species of gazelles occupying the same patch of grassland.
# Masked Positive Sentence: <mask> that they are <mask> the same species, <mask> <mask> the "13 species" of darwin's finches, and i have no <mask> with evolution in that respect. i can even see the plausibility of different subspecies evolving eventually into different species if they are geographically separated for a sufficiently long time. but i still don't see where evolution, in that sense of the term, can account for dozens of species of monkeys occupying the same patch of rainforest, or dozens of species of gazelles occupying the same patch of grassland.
# Masked Negative Sentence: agreed that they are <mask> the same species, much like the "13 species" of darwin's finches, and i have no <mask> with <mask> in that respect. i can even <mask> the plausibility of different subspecies evolving eventually into different <mask> if they are geographically separated for a sufficiently long time. but i still don't see where evolution, in that sense of the term, can account for dozens of species of monkeys occupying the same patch of rainforest, or dozens of species of gazelles occupying the same patch of grassland.
# - - - - - - - - - -
# Original Sentence: no, it requires pretty much the same amount of faith, as if faith could be quantified.
#
#  .
# Masked Positive Sentence: no, it <mask> <mask> <mask> the same <mask> of faith, as if <mask> could be quantified. .
# Masked Negative Sentence: no, it requires pretty much the same amount of faith, as if <mask> <mask> be quantified. .
# - - - - - - - - - -
# Original Sentence: again that is a poor analogy. congress does not have any powers not included in the constitution. quite the opposite, it specifically says that any powers not included in the constitution is defaulted to the states and congress is additionally prohibited from taking any more authority not named in the constitution.since there is no specific naming article saying congress does not have the power to ban manufacturing weapons, in fact it does not. according to the 10th amendment:the powers not delegated to the united states by the constitution, nor prohibited by it to the states, are reserved to the states respectively, or to the people.thus you have another poor analogy. congress does not have the right to ban manufacture of guns.
# Masked Positive Sentence: again that is a <mask> analogy. <mask> does not have any <mask> not <mask> in the constitution. <mask> the opposite, it specifically says that any powers not included in the constitution is defaulted to the states and congress is additionally prohibited from taking any more authority not named in the constitution.since there is no specific naming article saying congress does not have the power to ban manufacturing weapons, in fact it does not. according to the 10th amendment:the powers not delegated to the united states by the constitution, nor prohibited by it to the states, are reserved to the states respectively, or to the people.thus you have another poor analogy. congress does not have the right to ban manufacture of guns.
# Masked Negative Sentence: again that is a <mask> analogy. <mask> does not have any <mask> not included in the constitution. quite the opposite, it specifically says that any <mask> not included in the <mask> is defaulted to the states and congress is additionally prohibited from taking any more authority not named in the constitution.since there is no specific naming article saying congress does not have the power to ban manufacturing weapons, in fact it does not. according to the 10th amendment:the powers not delegated to the united states by the constitution, nor prohibited by it to the states, are reserved to the states respectively, or to the people.thus you have another poor analogy. congress does not have the right to ban manufacture of guns.
# - - - - - - - - - -
# Original Sentence: see above. nothing has been demonstrated that convinces me that god has been ruled out of all these issues. he probably isn't active in all situations, but there's nothing that says he (or even satan) are totally inconsequential either.
# Masked Positive Sentence: <mask> above. <mask> has been <mask> that <mask> me that <mask> has been ruled out of all these issues. he probably isn't active in all situations, but there's nothing that says he (or even satan) are totally inconsequential either.
# Masked Negative Sentence: see above. <mask> has been demonstrated that convinces me that god has been ruled out of all these issues. he probably isn't <mask> in all situations, but there's <mask> that <mask> he (or <mask> satan) are totally inconsequential either.
# - - - - - - - - - -
# Original Sentence: i think shortej is not a creationist. he/she never said so, and started off by saying he/she accepts evolution and maintains her catholic beliefs. (i have a hunch its "she")
# Masked Positive Sentence: i <mask> <mask> is not a creationist. he/she <mask> <mask> so, and <mask> off by saying he/she accepts evolution and maintains her catholic beliefs. (i have a hunch its "she")
# Masked Negative Sentence: i think shortej is not a creationist. he/she never said so, and started off by <mask> he/she <mask> <mask> and <mask> her <mask> beliefs. (i have a hunch its "she")
# - - - - - - - - - -
# Original Sentence: because apes, monkeys and chimps are on different paths. you wouldn't expect a shark to evolve into a barracuda-like animal. things evolve to fill niches, we currently fill a niche, there is nothing pushing apes, chimps or other primates to fill a niche that is occupied.
# Masked Positive Sentence: because apes, <mask> and <mask> are on <mask> paths. you wouldn't <mask> a <mask> to evolve into a barracuda-like animal. things evolve to fill niches, we currently fill a niche, there is nothing pushing apes, chimps or other primates to fill a niche that is occupied.
# Masked Negative Sentence: because apes, monkeys and <mask> are on different paths. you wouldn't expect a <mask> to evolve into a barracuda-like animal. things evolve to <mask> niches, we <mask> <mask> a niche, there is nothing pushing apes, chimps or other primates to fill a niche that is occupied.
# - - - - - - - - - -
# Original Sentence: so what if he dislikes science? if he believes something else, he has the right to believe that way. my problem here is that he shows more closed-mindedness to the viewpoints of others.
# Masked Positive Sentence: so what if he <mask> science? if he <mask> <mask> else, he has the <mask> to <mask> that way. my problem here is that he shows more closed-mindedness to the viewpoints of others.
# Masked Negative Sentence: so what if he dislikes science? if he believes something else, he has the right to <mask> that way. my <mask> here is that he <mask> more closed-mindedness to the <mask> of others.
# - - - - - - - - - -
# Original Sentence: this isn't discrimination because the adult once did have have the right to live in a womb until it could live otherwise. once out of the womb and living on his/her own this right has been exhausted because there is no need to be living in the womb. much like you can drive but this 'right' is exhausted when you are drunk or too old to see anything.
# Masked Positive Sentence: this isn't <mask> because the <mask> once did have have the <mask> to <mask> in a <mask> until it could live otherwise. once out of the womb and living on his/her own this right has been exhausted because there is no need to be living in the womb. much like you can drive but this 'right' is exhausted when you are drunk or too old to see anything.
# Masked Negative Sentence: this isn't <mask> because the adult once did have have the right to live in a <mask> until it could live otherwise. once out of the <mask> and <mask> on his/her own this right has been <mask> because there is no need to be living in the womb. much like you can drive but this 'right' is exhausted when you are drunk or too old to see anything.
# - - - - - - - - - -
# Original Sentence: it depends on your intention and your methods. of course, things that don't have some sort of physical manifestation that can be measured can't be studied by science. science is naturalistic. scientific data can only include that which can be observed and quantified by natural means. i read it in a book of mythology isn't scientific.
# Masked Positive Sentence: it <mask> on your <mask> and your methods. of course, <mask> that don't have some <mask> of <mask> manifestation that can be measured can't be studied by science. science is naturalistic. scientific data can only include that which can be observed and quantified by natural means. i read it in a book of mythology isn't scientific.
# Masked Negative Sentence: it depends on your intention and your methods. of course, things that don't have some sort of physical manifestation that can be measured can't be studied by science. <mask> is naturalistic. <mask> <mask> can only <mask> that which can be <mask> and quantified by natural means. i read it in a book of mythology isn't scientific.
# - - - - - - - - - -
# Original Sentence: when someone lacks the ability to understand and the ganas to try, then it doesn't make sense. however, if you understood any of it, it would be different. after all, you repeat over and over again how you don't understand.
# Masked Positive Sentence: when <mask> <mask> the <mask> to <mask> and the <mask> to try, then it doesn't make sense. however, if you understood any of it, it would be different. after all, you repeat over and over again how you don't understand.
# Masked Negative Sentence: when someone lacks the ability to <mask> and the ganas to try, then it doesn't make sense. however, if you <mask> any of it, it <mask> be different. after all, you <mask> over and over again how you don't understand.
# - - - - - - - - - -
# Original Sentence: cars are a privilege, your gun isn't. show me evidence that would support the registration of your first amendment rights being constitutional.
# Masked Positive Sentence: <mask> are a privilege, your <mask> isn't. <mask> me <mask> that <mask> support the registration of your first amendment rights being constitutional.
# Masked Negative Sentence: cars are a privilege, your gun isn't. show me evidence that would <mask> the <mask> of your <mask> <mask> <mask> being constitutional.
# - - - - - - - - - -
# Original Sentence: and you just did what you chastise me for in your next sentence
# Masked Positive Sentence: and you just did what you <mask> me for in your next sentence
# Masked Negative Sentence: and you just did what you <mask> me for in your <mask> <mask>
# - - - - - - - - - -
# Original Sentence: the original molecule had some lipolytic function, but removing some amino acids from it, in the right place, made it fit better into the substrate, and thereby greatly increased its functionality. barbarian observes:we thought it would take roughly a million years for bacteria to evolve enzymes capable of digesting nylon (because the compound is so different than any they were able to digest) but it took less than a century. .
# Masked Positive Sentence: the <mask> <mask> had some <mask> function, but <mask> some <mask> acids from it, in the right place, made it fit better into the substrate, and thereby greatly increased its functionality. barbarian observes:we thought it would take roughly a million years for bacteria to evolve enzymes capable of digesting nylon (because the compound is so different than any they were able to digest) but it took less than a century. .
# Masked Negative Sentence: the original molecule had some lipolytic function, but <mask> some amino acids from it, in the right place, made it fit better into the substrate, and thereby greatly increased its functionality. <mask> observes:we <mask> it <mask> <mask> roughly a million years for bacteria to evolve enzymes capable of digesting nylon (because the compound is so different than any they were able to digest) but it took less than a century. .
# - - - - - - - - - -
# Original Sentence: hundreds of thousands of atheist scientists do too, since common ancestry with apes harmonizes perfectly with the absence of a creator. they're seldom asked to answer about that confusion, however.
# Masked Positive Sentence: <mask> of <mask> of <mask> <mask> do too, <mask> common ancestry with apes harmonizes perfectly with the absence of a creator. they're seldom asked to answer about that confusion, however.
# Masked Negative Sentence: hundreds of thousands of <mask> scientists do too, since common ancestry with apes <mask> <mask> with the <mask> of a creator. they're <mask> asked to answer about that confusion, however.
# - - - - - - - - - -
# Original Sentence: i think that the bad guys will be happy if any gun control law goes into effect, because then there will be less chance of the victum having a weapon for their defense, and the crime rate will rise!!!!!!!!!!!!!!!!!!!!!!
# Masked Positive Sentence: i <mask> that the <mask> <mask> will be <mask> if any <mask> control law goes into effect, because then there will be less chance of the victum having a weapon for their defense, and the crime rate will rise!!!!!!!!!!!!!!!!!!!!!!
# Masked Negative Sentence: i think that the <mask> guys will be happy if any gun control law goes into effect, because then there will be <mask> <mask> of the <mask> having a <mask> for their defense, and the crime rate will rise!!!!!!!!!!!!!!!!!!!!!!
# - - - - - - - - - -
# Original Sentence: because....expansion occurs after heat is added. how can a expansion occur with a prior cause? you're saying the reaction and cause happen at the same time. show me an example that does that.
# Masked Positive Sentence: because....expansion <mask> after <mask> is added. how can a <mask> <mask> with a <mask> cause? you're saying the reaction and cause happen at the same time. show me an example that does that.
# Masked Negative Sentence: because....expansion occurs after heat is added. how can a expansion <mask> with a prior cause? you're <mask> the <mask> and <mask> <mask> at the same time. show me an example that does that.
# - - - - - - - - - -
# Original Sentence: and we do. in some phyla, most of the partially-formed examples still exist. you can find them in mollusks, for example.
#
#  http://www.pnas.org/content/vol104/suppl_1/images/large/zpq0120756920001.jpeg
# Masked Positive Sentence: and we do. in some phyla, most of the partially-formed <mask> <mask> exist. you can find them in mollusks, for example. http://www.pnas.org/content/vol104/suppl_1/images/large/zpq0120756920001.jpeg
# Masked Negative Sentence: and we do. in some phyla, most of the partially-formed examples still exist. you can <mask> them in mollusks, for example. http://www.pnas.org/content/vol104/suppl_1/images/large/zpq0120756920001.jpeg
# - - - - - - - - - -
# Original Sentence: actually, i can not accept that claim. before then, the absolutely youngest ever surviving fetus was deliver at 19 weeks, 6 days. 12 weeks would be a worldwide sensation. i would recommend that you double-check your source. viability is still defined as the age at which 50% survive, which still is at around 24 weeks gestation/26 weeks pregnancy.
# Masked Positive Sentence: actually, i can not <mask> that claim. before then, the <mask> <mask> <mask> <mask> fetus was deliver at 19 weeks, 6 days. 12 weeks would be a worldwide sensation. i would recommend that you double-check your source. viability is still defined as the age at which 50% survive, which still is at around 24 weeks gestation/26 weeks pregnancy.
# Masked Negative Sentence: actually, i can not accept that claim. before then, the absolutely youngest ever surviving fetus was deliver at 19 weeks, 6 days. 12 <mask> <mask> be a worldwide sensation. i <mask> <mask> that you double-check your source. <mask> is still defined as the age at which 50% survive, which still is at around 24 weeks gestation/26 weeks pregnancy.
# - - - - - - - - - -
# Original Sentence: if that were true, why are there millions of miscarriages each year? i don't believe a word of it.
# Masked Positive Sentence: if that were true, why are there <mask> of <mask> each year? i don't <mask> a word of it.
# Masked Negative Sentence: if that were true, why are there millions of miscarriages each year? i don't <mask> a <mask> of it.
# - - - - - - - - - -
# Original Sentence: it's not a literal account unless you interpret it that way.
# Masked Positive Sentence: it's not a <mask> <mask> unless you <mask> it that way.
# Masked Negative Sentence: it's not a literal account <mask> you <mask> it that way.
# - - - - - - - - - -
# Original Sentence: if! but here's the thing, mexico is making absolutely no attempt to truly stomp out the drug cartels, they're catering to them! various political figures and police officers are on the take, they're getting massive amounts of bribe money from the cartels, stopping them would prove detrimental.
# Masked Positive Sentence: if! but here's the thing, <mask> is <mask> <mask> no <mask> to <mask> stomp out the drug cartels, they're catering to them! various political figures and police officers are on the take, they're getting massive amounts of bribe money from the cartels, stopping them would prove detrimental.
# Masked Negative Sentence: if! but here's the thing, mexico is making absolutely no attempt to truly <mask> out the <mask> cartels, they're catering to them! <mask> <mask> figures and <mask> officers are on the take, they're getting massive amounts of bribe money from the cartels, stopping them would prove detrimental.
# - - - - - - - - - -
# Original Sentence: well, if they've re-established control in new orleans(and it seems they have), then taking a gun away from someone carrying it on the street would be what the police normally do in any city. if they were taking it away from peoples' homes, and not letting them keep them, that would be over and above what they normally do. (i'm very pro-2nd amendment, so don't get me wrong here. i'm just pointing out that taking guns away from people happens in every city every day)i also think that it's kind of disingenuous to complain about the military coming in--just a week ago everyone was criticizing the govt. for not sending in the military. now people are criticizing them for doing it???
# Masked Positive Sentence: well, if they've re-established <mask> in <mask> orleans(and it <mask> they have), then <mask> a <mask> away from someone carrying it on the street would be what the police normally do in any city. if they were taking it away from peoples' homes, and not letting them keep them, that would be over and above what they normally do. (i'm very pro-2nd amendment, so don't get me wrong here. i'm just pointing out that taking guns away from people happens in every city every day)i also think that it's kind of disingenuous to complain about the military coming in--just a week ago everyone was criticizing the govt. for not sending in the military. now people are criticizing them for doing it???
# Masked Negative Sentence: well, if they've re-established control in new orleans(and it seems they have), then <mask> a gun <mask> from someone carrying it on the street would be what the police normally do in any city. if they were <mask> it <mask> from peoples' homes, and not letting them keep them, that would be over and above what they normally do. (i'm very pro-2nd amendment, so don't get me <mask> here. i'm just pointing out that taking guns away from people happens in every city every day)i also think that it's kind of disingenuous to complain about the military coming in--just a week ago everyone was criticizing the govt. for not sending in the military. now people are criticizing them for doing it???
# - - - - - - - - - -
# Original Sentence: because if you let gays marry because it is an alternitve way the equal protection says that if you let one happen you have to let the others have that right to. but that is not really my point my real point is that if we let this happend it will ruin marriage in this country, marriage is a bond between a man and a women and if we let gays marry this country will be ruining that tradition thus making this country more secular then it all ready is. and we have to stop that.
# Masked Positive Sentence: because if you <mask> <mask> <mask> because it is an <mask> <mask> the equal protection says that if you let one happen you have to let the others have that right to. but that is not really my point my real point is that if we let this happend it will ruin marriage in this country, marriage is a bond between a man and a women and if we let gays marry this country will be ruining that tradition thus making this country more secular then it all ready is. and we have to stop that.
# Masked Negative Sentence: because if you <mask> <mask> <mask> because it is an alternitve way the equal protection says that if you <mask> one happen you have to <mask> the others have that right to. but that is not really my point my real point is that if we let this happend it will ruin marriage in this country, marriage is a bond between a man and a women and if we let gays marry this country will be ruining that tradition thus making this country more secular then it all ready is. and we have to stop that.
# - - - - - - - - - -
# Original Sentence: just isn't the case in countries with nationalised health care, yet those countries also have a large number of pharmaceutical companies that are based there.
# Masked Positive Sentence: just isn't the <mask> in <mask> with <mask> <mask> care, <mask> those countries also have a large number of pharmaceutical companies that are based there.
# Masked Negative Sentence: just isn't the case in <mask> with nationalised health care, yet those <mask> <mask> have a <mask> <mask> of pharmaceutical companies that are based there.
# - - - - - - - - - -
# Original Sentence: are you saying that an argument that is inconsistent with science should not be called unscientific, or are you saying that it should not be rejected because it is unscientific?
# Masked Positive Sentence: are you <mask> that an <mask> that is <mask> with <mask> should not be called unscientific, or are you <mask> that it should not be rejected because it is unscientific?
# Masked Negative Sentence: are you <mask> that an <mask> that is <mask> with science should not be <mask> unscientific, or are you <mask> that it should not be rejected because it is unscientific?
# - - - - - - - - - -
# Original Sentence: you have to remember that those christians believe that the laws of god superceed those of man. that thier allegiance is to god and his laws above those of the constitution. they also believe that all should be subject to gods by force if nesesary.
# Masked Positive Sentence: you have to <mask> that those <mask> <mask> that the <mask> of <mask> superceed those of man. that thier allegiance is to god and his laws above those of the constitution. they also believe that all should be subject to gods by force if nesesary.
# Masked Negative Sentence: you have to remember that those christians <mask> that the <mask> of <mask> superceed those of man. that thier <mask> is to <mask> and his laws above those of the constitution. they also believe that all should be subject to gods by force if nesesary.
# - - - - - - - - - -
# Original Sentence: it is all repeated time after time, and time again then again. but you are correct. here is one of the links to those studies. emoticonxsmilie http://www.4forums.com/political/gun...tml#post354115but what do we do about this? http://works.bepress.com/cgi/viewcon...dennis_culhane which is a study of criminals shooting criminals but it is hoped that people will think it is about law abiding concealed carry. this is not representative of law-abiding concealed carry or legal gun ownership in any way. and we have this.guns and death - firearms research - harvard injury control research center - harvard school of public healthso lets look at the actual crime figures to see if any of this holds water.  according to this 1999 article  there were 250 million guns in circulation in 1999.   total nics background checks november 30, 1998 - june 30, 2009
# Masked Positive Sentence: it is all <mask> <mask> after time, and <mask> again then again. but you are correct. here is <mask> of the <mask> to those studies. emoticonxsmilie http://www.4forums.com/political/gun...tml#post354115but what do we do about this? http://works.bepress.com/cgi/viewcon...dennis_culhane which is a study of criminals shooting criminals but it is hoped that people will think it is about law abiding concealed carry. this is not representative of law-abiding concealed carry or legal gun ownership in any way. and we have this.guns and death - firearms research - harvard injury control research center - harvard school of public healthso lets look at the actual crime figures to see if any of this holds water. according to this 1999 article there were 250 million guns in circulation in 1999. total nics background checks november 30, 1998 - june 30, 2009
# Masked Negative Sentence: it is all <mask> time after time, and time again then again. but you are correct. here is one of the links to those studies. emoticonxsmilie http://www.4forums.com/political/gun...tml#post354115but what do we do about this? http://works.bepress.com/cgi/viewcon...dennis_culhane which is a study of criminals <mask> criminals but it is hoped that people will think it is about law abiding concealed carry. this is not <mask> of law-abiding concealed carry or legal gun ownership in any way. and we have this.guns and <mask> - <mask> research - harvard injury control research center - harvard school of public healthso lets look at the actual crime figures to see if any of this holds water. according to this 1999 article there were 250 million guns in circulation in 1999. total nics background checks november 30, 1998 - june 30, 2009
# - - - - - - - - - -
# Original Sentence: okay, you are right... we need a definition for a 'hole,' as it is a bit of a subjective concept. allow me to define 'hole' like this: the void created by the intentional destruction of something already in existence. using 'hole' with this definition makes alcorn's statement (minus the word 'terrible') a true fact in the physical realm. and it precludes any of your other ideas from creating 'holes,' since they all deal with potentiality, not reality.
# Masked Positive Sentence: okay, you are right... we <mask> a <mask> for a 'hole,' as it is a <mask> of a <mask> concept. <mask> me to define 'hole' like this: the void created by the intentional destruction of something already in existence. using 'hole' with this definition makes alcorn's statement (minus the word 'terrible') a true fact in the physical realm. and it precludes any of your other ideas from creating 'holes,' since they all deal with potentiality, not reality.
# Masked Negative Sentence: okay, you are right... we need a <mask> for a 'hole,' as it is a bit of a subjective concept. allow me to define 'hole' like this: the void created by the intentional <mask> of something already in existence. <mask> 'hole' with this <mask> <mask> alcorn's statement (minus the word 'terrible') a true fact in the physical realm. and it precludes any of your other ideas from creating 'holes,' since they all deal with potentiality, not reality.
# - - - - - - - - - -
# Original Sentence: religion: commitment or devotion to religious faith or observance
#
#  religious: relating to or manifesting faithful devotion to an acknowledged ultimate reality or diety
#
#  therefore we can conclude that atheism and agnosticism are religions.
# Masked Positive Sentence: religion: <mask> or <mask> to <mask> <mask> or <mask> religious: relating to or manifesting faithful devotion to an acknowledged ultimate reality or diety therefore we can conclude that atheism and agnosticism are religions.
# Masked Negative Sentence: religion: commitment or <mask> to religious faith or observance religious: relating to or manifesting <mask> <mask> to an <mask> <mask> reality or diety therefore we can conclude that atheism and agnosticism are religions.
# - - - - - - - - - -
# Original Sentence: i'd say there were a lot of stones going both ways.
#
#  do you know the rev. well enough to be able to make that claim, that he's a bigot? or is it he represents the system?
# Masked Positive Sentence: i'd <mask> there were a <mask> of <mask> <mask> both ways. do you <mask> the rev. well enough to be able to make that claim, that he's a bigot? or is it he represents the system?
# Masked Negative Sentence: i'd say there were a lot of stones going both ways. do you know the rev. <mask> <mask> to be <mask> to <mask> that claim, that he's a bigot? or is it he <mask> the system?
# - - - - - - - - - -
# ...
# Masked Negative Sentence: where is the government in this? clinicians made a clinical decision, and hid behind a non-mandatory guideline, which was set by other more senior clinicians, expert in their field. assuming the woman's very detailed <mask> of the <mask> <mask> of <mask> is accurate, <mask> it was god's way of telling this unmarried mother that after five previous miscarriages, she still wasn't getting the message.
# - - - - - - - - - -
# Original Sentence: which ones? ineffective how?   i'd guess the laws weren't struck down simply because too many people broke them.
# Masked Positive Sentence: which ones? <mask> how? i'd <mask> the <mask> weren't struck down simply because too many people broke them.
# Masked Negative Sentence: which ones? <mask> how? i'd guess the laws weren't <mask> down <mask> because too <mask> <mask> broke them.
# - - - - - - - - - -
# Original Sentence: why?   if the government made a law tomorrow that declared all brain surgeons would now be making the average wages of a high school janitor, how many brain surgeons do you think would continue their practice?
# Masked Positive Sentence: why? if the <mask> <mask> a <mask> <mask> that <mask> all brain surgeons would now be making the average wages of a high school janitor, how many brain surgeons do you think would continue their practice?
# Masked Negative Sentence: why? if the government made a law tomorrow that <mask> all <mask> <mask> <mask> now be making the average <mask> of a high school janitor, how many brain surgeons do you think would continue their practice?
# - - - - - - - - - -
# Original Sentence:  nonsense and lies that bertvan spewed is it that you want me to elaborate on?or did you want me to elaborate on some of the falsehoods and lies of yours that i have challenged? are you actually up to dealing with challenges to your spewed falsehoods  or will you run from that?" yes, all of that. prove it has any basis in fact and that berts claims cannot be true. talk and attacks are cheap but proof of anything substantial and real is few and far between by you. i'll see you uh, never? because all of the ridiculous assertions and claims you make are unprovable by any reasonable standard.
# Masked Positive Sentence: <mask> and <mask> that <mask> <mask> is it that you <mask> me to elaborate on?or did you want me to elaborate on some of the falsehoods and lies of yours that i have challenged? are you actually up to dealing with challenges to your spewed falsehoods or will you run from that?" yes, all of that. prove it has any basis in fact and that berts claims cannot be true. talk and attacks are cheap but proof of anything substantial and real is few and far between by you. i'll see you uh, never? because all of the ridiculous assertions and claims you make are unprovable by any reasonable standard.
# Masked Negative Sentence: <mask> and lies that bertvan spewed is it that you want me to elaborate on?or did you want me to elaborate on some of the falsehoods and lies of yours that i have challenged? are you actually up to dealing with challenges to your spewed falsehoods or will you run from that?" yes, all of that. prove it has any basis in fact and that <mask> <mask> cannot be true. <mask> and <mask> are cheap but proof of anything substantial and real is few and far between by you. i'll see you uh, never? because all of the ridiculous assertions and claims you make are unprovable by any reasonable standard.
# - - - - - - - - - -
# Original Sentence: yeah, lets tax those rich greedy jerks!!! i mean really, why be equal when you want something for free right??? screw freedom i want my healthcare!!!
# Masked Positive Sentence: yeah, <mask> <mask> those <mask> <mask> jerks!!! i <mask> really, why be equal when you want something for free right??? screw freedom i want my healthcare!!!
# Masked Negative Sentence: yeah, lets tax those rich <mask> jerks!!! i mean really, why be <mask> when you <mask> <mask> for <mask> right??? screw freedom i want my healthcare!!!
# - - - - - - - - - -
# Original Sentence: yeah. it's snowing sooner here in the midwest. i think the next ice age is coming.
# Masked Positive Sentence: yeah. it's <mask> <mask> here in the midwest. i think the next ice <mask> is coming.
# Masked Negative Sentence: yeah. it's snowing sooner here in the midwest. i <mask> the <mask> <mask> <mask> is coming.
# - - - - - - - - - -
# Original Sentence: you don't see protesters walking around going "i wanna marry my dog" or "beastiality rocks" do you?!
# Masked Positive Sentence: you don't <mask> <mask> <mask> <mask> <mask> "i wanna marry my dog" or "beastiality rocks" do you?!
# Masked Negative Sentence: you don't see protesters walking around going "i wanna <mask> my dog" or "beastiality rocks" do you?!
# - - - - - - - - - -
# Original Sentence: you draw very interesting conclusions my friend.   if this is your standpoint then what is the purpose of a government?
# Masked Positive Sentence: you <mask> very <mask> <mask> my friend. if this is your <mask> then what is the <mask> of a government?
# Masked Negative Sentence: you draw very interesting conclusions my friend. if this is your <mask> then what is the <mask> of a government?
# - - - - - - - - - -
# Original Sentence: you haven't posted a challenge yet. including this post.   would i fit the bill?   sure, but about what? what's your resolution?   for instance, you might say "resolved: creation and evolution are equally valid interpretations of empirical evidence".   now, personally i'd say that's still too vague because 'creation' drags in all kinds of issues that evolution doesn't speak to (eg abiogenesis, cosmology etc), and 'evolution' could mean common descent, the theory of evolution, etc etc.   so we might kick the idea around for a bit and narrow it down to "resolved: hypotheses of special creation of species and common descent are equally well supported by empirical evidence".   or, perhaps it's the age of the earth you want to focus on: "resolved: all available evidence is consistent with a 6-10,000 year old earth"   i can't do this for you, feindslayer; make up your mind and present a proper challenge.
# Masked Positive Sentence: you haven't <mask> a <mask> yet. <mask> this post. <mask> i <mask> the bill? sure, but about what? what's your resolution? for instance, you might say "resolved: creation and evolution are equally valid interpretations of empirical evidence". now, personally i'd say that's still too vague because 'creation' drags in all kinds of issues that evolution doesn't speak to (eg abiogenesis, cosmology etc), and 'evolution' could mean common descent, the theory of evolution, etc etc. so we might kick the idea around for a bit and narrow it down to "resolved: hypotheses of special creation of species and common descent are equally well supported by empirical evidence". or, perhaps it's the age of the earth you want to focus on: "resolved: all available evidence is consistent with a 6-10,000 year old earth" i can't do this for you, feindslayer; make up your mind and present a proper challenge.
# Masked Negative Sentence: you haven't posted a <mask> yet. including this post. would i fit the bill? sure, but about what? what's your resolution? for instance, you <mask> say "resolved: <mask> and <mask> are <mask> valid interpretations of empirical evidence". now, personally i'd say that's still too vague because 'creation' drags in all kinds of issues that evolution doesn't speak to (eg abiogenesis, cosmology etc), and 'evolution' could mean common descent, the theory of evolution, etc etc. so we might kick the idea around for a bit and narrow it down to "resolved: hypotheses of special creation of species and common descent are equally well supported by empirical evidence". or, perhaps it's the age of the earth you want to focus on: "resolved: all available evidence is consistent with a 6-10,000 year old earth" i can't do this for you, feindslayer; make up your mind and present a proper challenge.
# - - - - - - - - - -
# Original Sentence: you mean you are as biologically ignorant and as easily refuted as the thread originator? yes, we knew that already. why all the big letters?
# Masked Positive Sentence: you <mask> you are as <mask> <mask> and as <mask> <mask> as the thread originator? yes, we knew that already. why all the big letters?
# Masked Negative Sentence: you mean you are as biologically <mask> and as easily <mask> as the <mask> originator? yes, we <mask> that already. why all the <mask> letters?
# - - - - - - - - - -
# Original Sentence: you will soon learn, my friend, that fundies have very, very short memories when it comes to refutations of their arguments...
# Masked Positive Sentence: you will <mask> learn, my friend, that <mask> have very, very short memories when it comes to refutations of their arguments...
# Masked Negative Sentence: you will soon learn, my friend, that fundies have very, very <mask> <mask> when it <mask> to <mask> of their arguments...
# - - - - - - - - - -
# Original Sentence: you're right, why not simply kill these people in the shortest amount of time possible. i got it! we can advertise each killing (hanging, rock slaying, guillotine, etc.) weeks in advance, kinda like moves, and show it on pay-per-view. you can buy tickets to watch the show live as well. i mean c'mon, if we're going to have the death penalty we might as well utilize in the most gruesome, cost efficient, and swift method possible. right? that is how punishment was executed a few centuries ago.   honestly, how you feel is how a lot of people culturally conceive such offenders. in regards to the death penalty debate, it falls along a continuum between morality and scientific reasoning.
# Masked Positive Sentence: you're right, why not <mask> <mask> these <mask> in the <mask> <mask> of time possible. i got it! we can advertise each killing (hanging, rock slaying, guillotine, etc.) weeks in advance, kinda like moves, and show it on pay-per-view. you can buy tickets to watch the show live as well. i mean c'mon, if we're going to have the death penalty we might as well utilize in the most gruesome, cost efficient, and swift method possible. right? that is how punishment was executed a few centuries ago. honestly, how you feel is how a lot of people culturally conceive such offenders. in regards to the death penalty debate, it falls along a continuum between morality and scientific reasoning.
# Masked Negative Sentence: you're right, why not simply <mask> these <mask> in the shortest amount of time possible. i got it! we can advertise each <mask> (hanging, rock slaying, guillotine, etc.) weeks in advance, kinda like moves, and show it on pay-per-view. you can buy tickets to watch the show live as well. i mean c'mon, if we're going to have the <mask> <mask> we might as well utilize in the most gruesome, cost efficient, and swift method possible. right? that is how punishment was executed a few centuries ago. honestly, how you feel is how a lot of people culturally conceive such offenders. in regards to the death penalty debate, it falls along a continuum between morality and scientific reasoning.
# - - - - - - - - - -
# Original Sentence: you're the one who needs to get a grip. lots could get worse, but not for the reasons you're stating.   but i take it you're finally admitting that (actually) 50 million uninsured human beings who could die or go bankrupt is a big problem.
# Masked Positive Sentence: you're the <mask> who <mask> to <mask> a grip. <mask> <mask> get worse, but not for the reasons you're stating. but i take it you're finally admitting that (actually) 50 million uninsured human beings who could die or go bankrupt is a big problem.
# Masked Negative Sentence: you're the one who needs to get a grip. lots <mask> get worse, but not for the reasons you're stating. but i take it you're finally <mask> that (actually) 50 <mask> <mask> <mask> beings who could die or go bankrupt is a big problem.
# - - - - - - - - - -
# Original Sentence:  as their having guns doesn't serve the state.\"--heinrich himmlerfor pledging their support of nazi ideals  we proudly award \"yes\" the medal of holocaust and genocide. congratulations  you're now a supporter of hitler." and you win the pink panties award!i got news for you punk - my family fled the nazi's on foot in wwii
# Masked Positive Sentence: as their having <mask> doesn't <mask> the state.\"--heinrich <mask> <mask> their <mask> of nazi ideals we proudly award \"yes\" the medal of holocaust and genocide. congratulations you're now a supporter of hitler." and you win the pink panties award!i got news for you punk - my family fled the nazi's on foot in wwii
# Masked Negative Sentence: as their having guns doesn't serve the state.\"--heinrich himmlerfor pledging their support of <mask> ideals we proudly <mask> \"yes\" the medal of <mask> and genocide. congratulations you're now a <mask> of hitler." and you <mask> the pink panties award!i got news for you punk - my family fled the nazi's on foot in wwii
# - - - - - - - - - -
# Original Sentence: depends on when the baby bird died.   run along little boy..let the adults debate.
# Masked Positive Sentence: <mask> on when the <mask> <mask> died. <mask> along little boy..let the adults debate.
# Masked Negative Sentence: depends on when the baby bird died. run <mask> <mask> boy..let the <mask> debate.
# - - - - - - - - - -
# Original Sentence: ok, sheesh, to clarify, women who arent aborting their babys are pregnant more oftan than not, the women who are having abortons have to have them several times a year.
# Masked Positive Sentence: ok, sheesh, to clarify, <mask> who <mask> <mask> their <mask> are pregnant more oftan than not, the <mask> who are having abortons have to have them several times a year.
# Masked Negative Sentence: ok, sheesh, to clarify, <mask> who arent aborting their babys are <mask> more <mask> than not, the <mask> who are having <mask> have to have them several times a year.
# - - - - - - - - - -
# Original Sentence: so..   eh??   hows this sound?   will it fly with conservatives and progressives?   i think so.   -mosheh thezion
# Masked Positive Sentence: so.. eh?? <mask> this sound? will it <mask> with conservatives and progressives? i think so. -mosheh thezion
# Masked Negative Sentence: so.. eh?? hows this sound? will it fly with <mask> and progressives? i <mask> so. -mosheh <mask>
# - - - - - - - - - -
# Original Sentence: i think we should put to a vote, the right of the religious extremists, to vote at all. what say ye?   if the majority agrees, they have no say in anything anymore. isn't that the way steeeeeve says it should be done? put it to a vote?
# Masked Positive Sentence: i <mask> we should <mask> to a vote, the <mask> of the <mask> extremists, to <mask> at all. what say ye? if the majority agrees, they have no say in anything anymore. isn't that the way steeeeeve says it should be done? put it to a vote?
# Masked Negative Sentence: i think we should <mask> to a vote, the right of the religious extremists, to <mask> at all. what <mask> ye? if the majority agrees, they have no <mask> in <mask> anymore. isn't that the way steeeeeve says it should be done? put it to a vote?
# - - - - - - - - - -
# Original Sentence: you have a blob of tissue in your "but(sic)"? sorry dude, that has to suck.   perhaps you're really referring to hemorrhoids? you do know that those aren't really blobs of tissue, right? they're really the swelling and inflammation of veins.
# Masked Positive Sentence: you have a <mask> of <mask> in your "but(sic)"? <mask> dude, that has to suck. <mask> you're <mask> referring to hemorrhoids? you do know that those aren't really blobs of tissue, right? they're really the swelling and inflammation of veins.
# Masked Negative Sentence: you have a <mask> of <mask> in your "but(sic)"? <mask> dude, that has to suck. perhaps you're <mask> referring to hemorrhoids? you do <mask> that those aren't really blobs of tissue, right? they're really the swelling and inflammation of veins.
# - - - - - - - - - -

# %%
dfnew = pd.DataFrame({"text": text_data_original, "maskedPosSentence": masked_pos_sentences, "maskedNegSentence": masked_neg_sentences})
dfnew
# Out:
#                                                    text  \
# 0     If that's true, then Freedom of Speech is doom...
# 1     Neener neener - is it time to go in from the p...
# 2     Just like the plastic gun fear, the armour pie...
# 3     So geology is a religion because we weren't he...
# 4     Well done Monty. Mark that up as your first ev...
# ...                                                 ...
# 6515  depends on when the baby bird died.   run alon...
# 6516  ok, sheesh, to clarify, women who arent aborti...
# 6517  so..   eh??   hows this sound?   will it fly w...
# 6518  I think we should put to a vote, the right of ...
# 6519  You have a blob of tissue in your "but(sic)"? ...
#
#                                       maskedPosSentence  \
# 0     if that's true, then <mask> of <mask> is doome...
# 1     <mask> <mask> - is it <mask> to go in from the...
# 2     just <mask> the <mask> <mask> fear, the <mask>...
# 3     so <mask> is a <mask> because we weren't here ...
# 4     <mask> <mask> monty. <mask> that up as your fi...
# ...                                                 ...
# 6515  <mask> on when the <mask> <mask> died. <mask> ...
# 6516  ok, sheesh, to clarify, <mask> who <mask> <mas...
# 6517  so.. eh?? <mask> this sound? will it <mask> wi...
# 6518  i <mask> we should <mask> to a vote, the <mask...
# 6519  you have a <mask> of <mask> in your "but(sic)"...
#
#                                       maskedNegSentence
# 0     if that's true, then freedom of speech is doom...
# 1     neener neener - is it time to <mask> in from t...
# 2     just like the <mask> gun fear, the armour pier...
# 3     so <mask> is a religion because we weren't her...
# 4     well done monty. mark that up as your <mask> <...
# ...                                                 ...
# 6515  depends on when the baby bird died. run <mask>...
# 6516  ok, sheesh, to clarify, <mask> who arent abort...
# 6517  so.. eh?? hows this sound? will it fly with <m...
# 6518  i think we should <mask> to a vote, the right ...
# 6519  you have a <mask> of <mask> in your "but(sic)"...
#
# [6520 rows x 3 columns]

# %% [markdown]
# ## 4)
# "These two masked sentences are fed into the pre-trained generation model to fulfill the generation procedure.
# 𝑨{𝑎1, ..., 𝑥2, ..., 𝑥𝑛−1, ..., 𝑎𝑜 } = 𝐵𝐴𝑅𝑇 ( [𝑚]1, 𝑥2, ..., 𝑥𝑛−1, [𝑚]𝑛 )----(1)
# Thus, we will obtain two reborn sentences
# 𝐴 = {𝑎1, 𝑎2, ..., 𝑎𝑜 } and
# 𝐵 = {𝑏1, 𝑏2, ..., 𝑏𝑝 }."

# %%
# %pip install transformers
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.42.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.15.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.23.5)
# Requirement already satisfied: numpy<2.0,>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.5.15)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.3)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.7.4)

# %%
def generate_reborn_sentences(masked_sentences):
    tokenizer = BartTokenizer.from_pretrained("facebook/bart-base")
    model = BartForConditionalGeneration.from_pretrained("facebook/bart-base")

    i = 0
    reborn_sentences = []
    for masked_sentence in masked_sentences:
        inputs = tokenizer(masked_sentence, return_tensors="pt")
        generated_encoded = model.generate(inputs['input_ids'])
        reborn_sentence = tokenizer.batch_decode(generated_encoded, skip_special_tokens=True)[0]
        reborn_sentences.append(reborn_sentence)
        i = i + 1
        if (i % 100 == 0):
            print(f'Processed {i} sentences')

    return reborn_sentences

# %%
from google.colab import userdata
userdata.get('huggingface')
# Out:
# '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'

# %%
import os
os.environ["HF_TOKEN"] = "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"

# %%
reborn_pos_sentences = generate_reborn_sentences(masked_pos_sentences)

reborn_neg_sentences = generate_reborn_sentences(masked_neg_sentences)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.72k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/558M [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1249: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# Processed 100 sentences
# Processed 200 sentences
# Processed 300 sentences
# Processed 400 sentences
# Processed 500 sentences
# Processed 600 sentences
# Processed 700 sentences
# Processed 800 sentences
# Processed 900 sentences
# Processed 1000 sentences
# Processed 1100 sentences
# Processed 1200 sentences
# Processed 1300 sentences
# Processed 1400 sentences
# Processed 1500 sentences
# Processed 1600 sentences
# Processed 1700 sentences
# Processed 1800 sentences
# Processed 1900 sentences
# Processed 2000 sentences
# Processed 2100 sentences
# Processed 2200 sentences
# Processed 2300 sentences
# Processed 2400 sentences
# Processed 2500 sentences
# Processed 2600 sentences
# Processed 2700 sentences
# Processed 2800 sentences
# Processed 2900 sentences
# Processed 3000 sentences
# Processed 3100 sentences
# Processed 3200 sentences
# Processed 3300 sentences
# Processed 3400 sentences
# Processed 3500 sentences
# Processed 3600 sentences
# Processed 3700 sentences
# Processed 3800 sentences
# Processed 3900 sentences
# Processed 4000 sentences
# Processed 4100 sentences
# Processed 4200 sentences
# Processed 4300 sentences
# Processed 4400 sentences
# Processed 4500 sentences
# Processed 4600 sentences
# Processed 4700 sentences
# Processed 4800 sentences

# %%
print("Reborn Sentences for Masked Positive Sentences:")
for i, reborn_sentence in enumerate(reborn_pos_sentences):
    print(f"Reborn Sentence {i + 1}: {reborn_sentence}")

# %%
print("\nReborn Sentences for Masked Negative Sentences:")
for i, reborn_sentence in enumerate(reborn_neg_sentences):
    print(f"Reborn Sentence {i + 1}: {reborn_sentence}")

# %%
dfnew["rebornPosSentence"] = reborn_pos_sentences
dfnew["rebornNegSentence"] = reborn_neg_sentences
dfnew

# %% [markdown]
# # Sentences Representation
# "We embed the original sentence 𝑥 and its corresponding reborn texts 𝐴 and 𝐵
# into 𝑑-dimentional embedding 𝑯𝑡 ∈ R𝑑
# via pre-trained BERT-base:
# 𝑯𝑥, 𝑯𝐴, 𝑯𝐵 = 𝐵𝐸𝑅𝑇 (𝑥), 𝐵𝐸𝑅𝑇 (𝐴), 𝐵𝐸𝑅𝑇 (𝐵)."

# %%
def embed_sentences(sentences):
    tokenizer = AutoTokenizer.from_pretrained("princeton-nlp/sup-simcse-bert-base-uncased")
    model = AutoModel.from_pretrained("princeton-nlp/sup-simcse-bert-base-uncased")

    i = 0
    embeddings = []
    for sentence in sentences:
        inputs = tokenizer(sentence, return_tensors="pt", padding=True, truncation=True)
        with torch.no_grad():
            outputs = model(**inputs).last_hidden_state.mean(dim=1)
        embeddings.append(outputs)
        i = i + 1
        if (i % 100 == 0):
            print(f'Processed {i} sentences')

    return torch.stack(embeddings)

# %%
x_embeddings = embed_sentences(text_data)

A_embeddings = embed_sentences(reborn_pos_sentences)

B_embeddings = embed_sentences(reborn_neg_sentences)

# %%
for i, sentence in enumerate(text_data):
    print(f"Embedding for Original Lowercase Sentence {i + 1} ({sentence}):")
    print(x_embeddings[i])
    print("- - - - - - - - - -")

# %%
for i, sentence in enumerate(reborn_pos_sentences):
    print(f"Embedding for Reborn Positive Sentence {i + 1} ({sentence}):")
    print(A_embeddings[i])
    print("- - - - - - - - - -")

# %%
for i, sentence in enumerate(reborn_neg_sentences):
    print(f"Embedding for Reborn Negative Sentence {i + 1} ({sentence}):")
    print(B_embeddings[i])
    print("- - - - - - - - - -")

# %%
dfnew["xEmbedding"] = x_embeddings.tolist()
dfnew["AEmbedding"] = A_embeddings.tolist()
dfnew["BEmbedding"] = B_embeddings.tolist()
dfnew

# %% [markdown]
# # Sarcastic Utterances Detection
# ## 1)
# "We utilize cosine similarity to measure the similarity between representations of original sentence 𝐻𝑥
# and generation texts 𝐻𝐴/𝐻𝐵.
#
# Then we use the following equation to calculate a difference score of each sentence:
# diff = sim(𝐻𝑥, 𝐻𝐴) < 𝑡ℎ𝑟𝑒𝑠ℎ𝑜𝑙𝑑 || sim(𝐻𝑥, 𝐻𝐵) < 𝑡ℎ𝑟𝑒𝑠ℎ𝑜𝑙𝑑
# where || means "or" logical operator."

# %%
def calculate_difference_scores(x_embeddings, A_embeddings, B_embeddings, threshold):
    i = 0
    diff_scores = []
    for x_emb, A_emb, B_emb in zip(x_embeddings, A_embeddings, B_embeddings):
        sim_Hx_HA = cosine_similarity(x_emb, A_emb)
        sim_Hx_HB = cosine_similarity(x_emb, B_emb)

        diff = (sim_Hx_HA < threshold) or (sim_Hx_HB < threshold)
        diff_scores.append(diff)
        i = i + 1
        if (i % 100 == 0):
            print(f'Processed {i} embeddings')

    return diff_scores

# %%
threshold = 0.755

diff_scores = calculate_difference_scores(x_embeddings, A_embeddings, B_embeddings, threshold)
diff_scores

# %% [markdown]
# ## 2)
# "Since the sarcastic utterances are influenced more than normal texts during the masking and generation procedure,
# the difference score of sarcastic texts should be greater than a non-sarcastic one.
#
# If we have a threshold value which separates sarcastic texts and normal texts,
# we can yield the prediction 𝑦 by:
# 𝑦 = I(diff)."

# %%
predicted_labels = [int(diff) for diff in diff_scores]
print(predicted_labels)
print(sum(predicted_labels))

# %%
labels = ["sarc" if diff else "notsarc" for diff in diff_scores]
print(labels)

# %%
dffinal = pd.DataFrame({"text": text_data, "class": label_data, "prediction": labels})
dffinal

# %% [markdown]
# # Main Experiment Results

# %%
true_labels = [1 if pred == "sarc" else 0 for pred in df["class"]]
print(true_labels)
print(predicted_labels)

accuracy = accuracy_score(true_labels, predicted_labels)
precision = precision_score(true_labels, predicted_labels)
f1 = f1_score(true_labels, predicted_labels)

print("Accuracy:", accuracy)
print("Precision:", precision)
print("F1 Score:", f1)

# %%
conf_matrix = confusion_matrix(true_labels, predicted_labels)

print("Confusion Matrix:")
print(conf_matrix)
